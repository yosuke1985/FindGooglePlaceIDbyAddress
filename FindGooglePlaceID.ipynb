# %% [markdown]
# ## Google Place API
#
# ### https://developers.google.com/places/web-service/intro?hl=ja
# ### https://developers.google.com/places/web-service/search?authuser=1&hl=ja
#
# ### https://developers.google.com/places/ios-api/place-id?authuser=1&hl=ja
#
# ### https://console.cloud.google.com/
#
#
# ## Python Google Place
#
# ### https://github.com/slimkrazy/python-google-places

# %% [markdown]
# # 初期設定

# %%
import pandas as  pd
from googleplaces import GooglePlaces, types, lang
file = open('/Users/yosuke/Github/FindGooglePlaceIDbyAddress/data/GooglePlaceAPIKey.txt', 'r')  
APIKEY = file.read() 

pd = pd.read_csv("/Users/yosuke/Github/FindGooglePlaceIDbyAddress/data/tabelog_over_3.6.csv")
name = []
place_id = []
google_places = GooglePlaces(APIKEY)

# %%
query_result.raw_response
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CrQCJgEAAPObHrY3YzUG6_WQl9qvRgHFkg7hXhs8xUUboqyDCkgf3ukEE2aklZ6D3s4HOfCAjJtWDlqVUGRgHgKkDT6fLnsT7kzdzvLI53BLTPBVY4mKb8ywffg6z8QBMjEoZMtaWBaHjBxkIaZ15AKyt8fndof40mWcm5dUrdMxs9ZcMoyLIdbEDNAwIoBW_C7E0Jqk2WVeMbFCSCkARCGh1i_xuJ-O3iVpqgABsxUvrqvmWLLoXQO3U4Sb2-BOEOr7I9knBA1iQBCD2rYDg0it69oaWPRSE44La2KGlxSH_EUqbSg2kx2dr5gTAX_5i5nnn5usuQY2jxn2PVcP-tn4toGImX4AzF3Tv2_KqmOm-oXN90zN7HcRlahzEaF6pN7_7MRPbe9PBcUQPagoSejjd7z0lFISEPzeSw8NI_d421SUCehNiFEaFB4xNImxA78LnsuG87qDI3isznYN',
#  'results': [{'geometry': {'location': {'lat': Decimal('51.5202235'),
#      'lng': Decimal('-0.0740232')},
#     'viewport': {'northeast': {'lat': Decimal('51.52161052989272'),
#       'lng': Decimal('-0.07268012010727777')},
#      'southwest': {'lat': Decimal('51.51891087010728'),
#       'lng': Decimal('-0.07537977989272221')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'acfa9a465c3081aec87cf46e06d1d04cdcaa7c77',
#    'name': 'Poppies Fish & Chips, Spitalfields',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 800,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113720139114503177031/photos">Poppies Fish &amp; Chips, Spitalfields</a>'],
#      'photo_reference': 'CmRaAAAA-tuQ3bBMf9mgVRW_T6QZBZsOvUfC2O8hQribWkuFgPprgY3S8lSz6xvRx2_6Ma6BQdaHdalaz8j6hpEFOHcSeyZPtbd5f1VjiFH6zF7NQdi8luOq60YHqHBf98qIZEwbEhAXpigGmStKFRHQvX_TQH6OGhT4TLDQB97yGBiiWwjDkW7U9p8_ng',
#      'width': 1200}],
#    'place_id': 'ChIJX7eIgrYcdkgRJtmJIysIZVc',
#    'plus_code': {'compound_code': 'GWCG+39 London Congestion Charging Zone, London, UK',
#     'global_code': '9C3XGWCG+39'},
#    'price_level': 1,
#    'rating': Decimal('4.3'),
#    'reference': 'CmRbAAAA5RSxYSfdyo7zENmsPjqcRddE75iZYsFbu3Y3QOoT_VdYezj-e5TV8nx8C4fNCZhqEjrOzZkCw90tAUk4GigRsCoGqlvIsR4ULEPfTBupVzYDwKyWGHdDSifvIeBh9lRWEhAhFT8wLBs5rHzA2mJwDfGlGhSyXLLfITRTRv-IY9ALF8zoR1-ipQ',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': '6-8 Hanbury St, London'},
#   {'geometry': {'location': {'lat': Decimal('51.5409757'),
#      'lng': Decimal('-0.1439713')},
#     'viewport': {'northeast': {'lat': Decimal('51.54226062989272'),
#       'lng': Decimal('-0.1425830201072778')},
#      'southwest': {'lat': Decimal('51.53956097010727'),
#       'lng': Decimal('-0.1452826798927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'e0715c3d882f1db32231494d012b7459d7fd8ab9',
#    'name': 'Poppies Fish and Chips Camden',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101703475998391445096/photos">Ivana Mercuriali</a>'],
#      'photo_reference': 'CmRaAAAAW9vKNaSD2nX-hfml1wflalgDe-usnlaiKTfLkMKgfTPt5e8tr_znKN4vjwSzr0au5cc1iie-nDun87Z-hITTJfT7bYH8dCZKeSkaytFefCYZTUV0oNHn7qva4Y1gDAYeEhDZGAqTvcvRoOrh5fg7c1iOGhReMq89_N51S5x4XsC9lLxFbODQcw',
#      'width': 5312}],
#    'place_id': 'ChIJGZ-kgeEadkgRrmwbc4LrXGI',
#    'plus_code': {'compound_code': 'GVR4+9C Camden Town, London, UK',
#     'global_code': '9C3XGVR4+9C'},
#    'price_level': 1,
#    'rating': Decimal('4.3'),
#    'reference': 'CmRbAAAAltZCqf0X_eaAi_WC1Gsevg9yWq0gJ-qnzWz2mIcVoWSRBbalDD-y1qMTYoOmx5JAbkVi7yggUtMG9OpKydBSWFJCrlsSPXbQCzoZFxFmsk9KeUPBgwP7I25UxNs3LHpMEhCeSkmvMthyQnITKxNaG0BLGhSnS08QdTfMgnjd6mSRZmHWg9rxYA',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': '30 Hawley Cres, London'},
#   {'geometry': {'location': {'lat': Decimal('51.516583'),
#      'lng': Decimal('-0.187945')},
#     'viewport': {'northeast': {'lat': Decimal('51.51795807989272'),
#       'lng': Decimal('-0.1865039201072778')},
#      'southwest': {'lat': Decimal('51.51525842010728'),
#       'lng': Decimal('-0.1892035798927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'a3ffdcb1013a65fb4b4f2937eaf73b842afa1e32',
#    'name': "Hobson's Fish & Chips",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3307,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108347313474104880678/photos">Hobson&#39;s Fish &amp; Chips</a>'],
#      'photo_reference': 'CmRaAAAAx8eBcgmJ8_QZe8bqKPE10ia8KUMgg6UhC8COu4t6fr36WzMuFCvZ20V7qehzC71YzheJcg_PUQ7fs9cxsozYmaVstC3z3m3OnwbRKV7tnla5yGg6_PwFuZ1FYhiT6KRNEhAzqIxk7fTPk64rTalkl_a9GhTtJub79V2q3UBHt6LI9qgkMU01HQ',
#      'width': 5022}],
#    'place_id': 'ChIJi1a_naoadkgRpmgQ8gWTT54',
#    'plus_code': {'compound_code': 'GR86+JR Hallfield Estate, London, UK',
#     'global_code': '9C3XGR86+JR'},
#    'rating': Decimal('4.3'),
#    'reference': 'CmRbAAAAIOuts8A3CbBORAYY-1jDjm7lOI4kRkM8G6-XlBpqemlOUJH7ilpOsa-p896DmLxhlky8mofCb2SFDp74AG0G5Hm5jRIdm0pS4TaH-MpF5OeGtJ1agrFvbQ7GFbTwe3f6EhBz3kZGT6DMbo6CgxWAIxEUGhRsrlX9Ba-vQ3hYIFg5gKLVNdLdBw',
#    'scope': 'GOOGLE',
#    'types': ['meal_delivery',
#     'meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': '9 Porchester Rd, London'},
#   {'geometry': {'location': {'lat': Decimal('51.470954'),
#      'lng': Decimal('-0.210788')},
#     'viewport': {'northeast': {'lat': Decimal('51.47228547989272'),
#       'lng': Decimal('-0.2095138701072778')},
#      'southwest': {'lat': Decimal('51.46958582010728'),
#       'lng': Decimal('-0.2122135298927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '516c26014819a47f89857f0f7ba3f2700f4a6cea',
#    'name': 'Fishers',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101456829970215111932/photos">A Google User</a>'],
#      'photo_reference': 'CmRaAAAA_POwAhc1Jx-baw0wAMKt2YS-wW8dDwshowYv1jMyB8nCDF3E2SLVB_Mie_QPDi0hinmkdV_NjBNRNY7JXd08KiMN3tNTryHJtIG0fxrQXKT0XvuBUkbjc-zVyJiYCmoGEhDYonhIStxhOP13Hr4iTFpjGhQarar1928-X_pxQJBCyEhgu6QV1g',
#      'width': 4032}],
#    'place_id': 'ChIJbfhNMHUPdkgRuFpD4GATdQQ',
#    'plus_code': {'compound_code': 'FQCQ+9M Fulham, London, UK',
#     'global_code': '9C3XFQCQ+9M'},
#    'rating': Decimal('4.8'),
#    'reference': 'CmRbAAAASbj8ewvdozs-sTbxI8VHEhTKGlZXs1d0NSspub9uWwDiMCPAzC22RfPXBA9RVJtAMTHZmmQzY-k06lLRRraOefk0jYe18d769X5Cq5hdYjdr66_qItm2joCKRqACwTOOEhAnxM6ok0H7BZNP2vRxG4hBGhRYyd51BeAjNr3EzFbHPPN-e-mtkw',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': '19 Fulham High St, London'},
#   {'geometry': {'location': {'lat': Decimal('51.546799'),
#      'lng': Decimal('-0.158716')},
#     'viewport': {'northeast': {'lat': Decimal('51.54819152989272'),
#       'lng': Decimal('-0.1573169701072778')},
#      'southwest': {'lat': Decimal('51.54549187010728'),
#       'lng': Decimal('-0.1600166298927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'bab53620edb6cf4daf2122ee7f47827d963ba0a5',
#    'name': "Oliver's Fish & Chips",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1026,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117775761624809833603/photos">Oliver&#39;s Fish &amp; Chips</a>'],
#      'photo_reference': 'CmRZAAAAMevEyP2k19FPjQcP175DscSLG2imkdAfsq0F_x1EXTDv2yPZAKsmz7esRokQY09UigP5rAJ_uDHFbkl31AV9UVXJ6YQiqDDXRTGlpzoT1YIUGpNyN5qcLWHC-8yzhcpWEhDkyu52gw-qq-HT0Wxaj19bGhT_sVbUA3DAc1Erxxe_PPnkXnIMZQ',
#      'width': 1248}],
#    'place_id': 'ChIJn8hI__EadkgRUaIJ8jj2CuY',
#    'plus_code': {'compound_code': 'GRWR+PG Belsize Park, London, UK',
#     'global_code': '9C3XGRWR+PG'},
#    'rating': Decimal('3.8'),
#    'reference': 'CmRbAAAALEaUTocF0Miww09gcA3e3OnujBMxmkOwvHAJOklIbzsP86XgOL7QZ5BgGk1AaGodmccO7BwGX-SuzjTal5Z9ewIinbZFAXp6GA1qqJ6ImRxMon2zIhqw0mMcAmELDGQfEhA4aLjPfPhFZBq_ZQWeb1UbGhRfSHtnSgiCiKi1rL1WA2gflA_nqw',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': '95 Haverstock Hill, London'},
#   {'geometry': {'location': {'lat': Decimal('51.5154662'),
#      'lng': Decimal('-0.1266079')},
#     'viewport': {'northeast': {'lat': Decimal('51.51682752989272'),
#       'lng': Decimal('-0.1253420701072778')},
#      'southwest': {'lat': Decimal('51.51412787010728'),
#       'lng': Decimal('-0.1280417298927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'd2525112bb835bcababd2bf202bc50fe3f002b17',
#    'name': "Ben's Fish and Chips",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115974245653876916196/photos">Ben&#39;s Fish and Chips</a>'],
#      'photo_reference': 'CmRaAAAAFxWYanEZWNe4xRE65QLtwjXBV4rL-Wb57t61Ku0bCjmxBPqkwzrafk7qCxNFNp3veH5p7ycIBgzwBrYhc9h99uU7DiMAHPWOuMMYD6BfBiqD_UN0VFM5iDHn06lpT7sGEhAifASu8FPEG1sQIm9lOXbZGhSBa8alQo4MdTGT8Lpqbs27sg_YFw',
#      'width': 1280}],
#    'place_id': 'ChIJoa4D0TIbdkgReCX9s-aeLos',
#    'plus_code': {'compound_code': 'GV8F+59 London Congestion Charging Zone, London, UK',
#     'global_code': '9C3XGV8F+59'},
#    'rating': Decimal('4.2'),
#    'reference': 'CmRbAAAA-BiFoIcZqQT8QCBRO0Jcv6OptwUsVgdiOh_RDE7JZ37rf9d6G4QJnVyEzh-B7z2TFJwx85CHRHrePo2NGmt3lPzTQaet4lkHDJgVds5P1RPVR6ogc01MLGuZVCpxXFmVEhBw7CyrPAgT990DDXejvLE-GhS7sJgaZOUIIkfpE_lm5sL8n-h8eQ',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': '200 Shaftesbury Ave, London'},
#   {'geometry': {'location': {'lat': Decimal('51.508576'),
#      'lng': Decimal('-0.0789175')},
#     'viewport': {'northeast': {'lat': Decimal('51.50993752989271'),
#       'lng': Decimal('-0.07761102010727777')},
#      'southwest': {'lat': Decimal('51.50723787010727'),
#       'lng': Decimal('-0.08031067989272221')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'bf5ab88cff71258010409524df3635f1cb7b001e',
#    'name': 'Josef Fish Bar',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107315737977257512093/photos">Aaron Bayes</a>'],
#      'photo_reference': 'CmRaAAAAcJV34wVe9XaZJdkK7sR6H9tqzr0s1CG9qOUswiOy_ph0iU_9WLWC9z2llwssuDq1-nC5dVNvMjJXQNNqwpmhpwOHZ6PeZ2JHbkj0i4UKmWsb1gayoD0oUERbcMHMwkYmEhC_fn9S0ec1zcZEutTNPt3EGhSVnM5OWcAZ_C99GmYsNcBWlJUdDg',
#      'width': 3024}],
#    'place_id': 'ChIJXd72jE4DdkgRcW9HZS_0QTc',
#    'plus_code': {'compound_code': "GW5C+CC St Katharine's & Wapping, London, UK",
#     'global_code': '9C3XGW5C+CC'},
#    'rating': Decimal('3.9'),
#    'reference': 'CmRbAAAATHEJvxkVujpHq1yYTyYjB5flhMAeNe84i8zx_y5tKUqS34TNysF3ALj9M9SUUBAtsuZbeKsIMzUAtRU6VSXobCqiMpjcdAIqAHqvveYN7S5qOPRb3zV-kf7no2QQ-Hp-EhCJENr3ICI13yYQBHHwB_VuGhRe5BwDx2MBZ76OlRlHVEwzIvcgrw',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': 'Petty Wales, London'},
#   {'geometry': {'location': {'lat': Decimal('51.5029253'),
#      'lng': Decimal('-0.1193358')},
#     'viewport': {'northeast': {'lat': Decimal('51.50427512989273'),
#       'lng': Decimal('-0.1179859701072778')},
#      'southwest': {'lat': Decimal('51.50157547010728'),
#       'lng': Decimal('-0.1206856298927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '02c49ec019f35268b224411251bbcdcb6b8f771e',
#    'name': 'Great British Fish and Chips',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1152,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110009474383680176949/photos">Fabian Klasnic</a>'],
#      'photo_reference': 'CmRaAAAAebrL8lMox8EcJFDwgW99yjdeejGLLd7f6z-o9FCZU-fPLmMFkWH-JEN98PfO_h8thbByfq5AbyL4tvZYvySElJotQAxxEQ8rLStiTiP05LEyUvo8U9swcZUmgdbvdn99EhAjpJzvLuLgn-qcsUAxER4vGhTHfDSrvh01IoDZGbnq_8QWe7iuzw',
#      'width': 2048}],
#    'place_id': 'ChIJ45vrx8cEdkgRndjF0KpLsFI',
#    'plus_code': {'compound_code': 'GV3J+57 Lambeth, London, UK',
#     'global_code': '9C3XGV3J+57'},
#    'rating': Decimal('2.8'),
#    'reference': 'CmRbAAAAm1xfCoIPp10oZQ0e3H4Plxwya_TCLNSHSaNMB3n7D4OQIRdsldyknyIk86Ya1FUhkm92oFHp-lrGW01TtZUK5fgMUlJOXQ5gkx8pWrsQFL_O7MyLO1T19eUCK_4_KAIMEhACHV3z16UHz4GtjvwTfZAAGhRnspgnZOyC8wxXI2M_YTD68gKMnA',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': 'Westminster Bridge Rd, London'},
#   {'geometry': {'location': {'lat': Decimal('51.51023199999999'),
#      'lng': Decimal('-0.197502')},
#     'viewport': {'northeast': {'lat': Decimal('51.51159732989272'),
#       'lng': Decimal('-0.1960671201072778')},
#      'southwest': {'lat': Decimal('51.50889767010727'),
#       'lng': Decimal('-0.1987667798927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '6773c4180ef0ec6656cdb7cfd76c1c238b18b665',
#    'name': 'The Fish House Of Notting Hill',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 608,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110631561894058247933/photos">The Fish House Of Notting Hill</a>'],
#      'photo_reference': 'CmRaAAAAGThjm4G8JAKfSoC2YYzedsAbNPd9VRQbrskUrx9BiC5uNamitlyj3lOChFxLCHK6S7fBiwbFCTIOBbV9LEWGW-tAqeIvr1ZzHEqhVF1pNzbv8yfNmy7prtENm4S_smqpEhCA5RGi317hRqY7MN_RiOCTGhTKnKiYZCNnRNg658ZpoW8jURMgjg',
#      'width': 1080}],
#    'place_id': 'ChIJ-STNj_wPdkgRB0P_xZi2YwM',
#    'plus_code': {'compound_code': 'GR62+3X Kensington, London, UK',
#     'global_code': '9C3XGR62+3X'},
#    'rating': Decimal('4.4'),
#    'reference': 'CmRbAAAA4Vg6hfls7rnj-5jndKAAolrOAZSqmuDirmZAkZGGY6twA1wjqKMhrTA_VPk6fRx893wJeeU41UYX0Lhxe8htX7j6OTF4qv9cWR5G5moE5vtiDlO2cPXH3OQaIt-fqf36EhD3Zqz1pJGemHaTFgeMkH2KGhQnnU8w2BtdbdCXINeVwXoNvZKavQ',
#    'scope': 'GOOGLE',
#    'types': ['meal_delivery',
#     'bakery',
#     'meal_takeaway',
#     'store',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': 'The Fish House, 29 Pembridge Rd, London'},
#   {'geometry': {'location': {'lat': Decimal('51.546569'),
#      'lng': Decimal('-0.055632')},
#     'viewport': {'northeast': {'lat': Decimal('51.54796642989272'),
#       'lng': Decimal('-0.05429007010727779')},
#      'southwest': {'lat': Decimal('51.54526677010728'),
#       'lng': Decimal('-0.05698972989272221')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '3455ebab4e1dc672230a9fe0f290880734f905a2',
#    'name': 'Sutton and Sons Fish & Chips',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2048,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115020626239535731031/photos">Sutton and Sons Fish &amp; Chips</a>'],
#      'photo_reference': 'CmRaAAAAekrXYCqLg11tEDRktE51By2T91wtEpAGsm8fbj2OdZSET-CkOeq6RllwsvJ3KdsaiXjSh5H9BokxHxNzkjA2cdzZZjLoigU-0px0gi2IzQ_KimbgA2nS7ogk6l7_Pvp4EhCS7tv-VOxgyhUySunY6Q52GhSWUNQ2wAQgTBLV9F0Yq6p6y8k7jQ',
#      'width': 1364}],
#    'place_id': 'ChIJGSXWKvscdkgRWK8sRPaQC9M',
#    'plus_code': {'compound_code': 'GWWV+JP Hackney, London, UK',
#     'global_code': '9C3XGWWV+JP'},
#    'rating': 4,
#    'reference': 'CmRbAAAAZ4RFJaWsVkpXOmQtHu2cgR1qQGKXxXrK6Ndn-DaBdCesOBg5uq38KjPbskFpENndcpELAbDv0Eo5vNM5gWkUdK6ihtSmBE_2ErUaqjplwnw4Pq6ZxMNqmwGXC0WF9acMEhBUuHTkxN20ZPbulJSdAkK_GhQOvlyAQ8uIEIHDxHIHdVbR2hMT6g',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': '240 Graham Rd, London'},
#   {'geometry': {'location': {'lat': Decimal('51.514834'),
#      'lng': Decimal('-0.125309')},
#     'viewport': {'northeast': {'lat': Decimal('51.51617292989273'),
#       'lng': Decimal('-0.1238344201072778')},
#      'southwest': {'lat': Decimal('51.51347327010728'),
#       'lng': Decimal('-0.1265340798927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'da51233b8235420861e4a5cf60a98851f13228a7',
#    'name': 'Rock and Sole Plaice',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105345856816834178315/photos">Nundou</a>'],
#      'photo_reference': 'CmRaAAAAHZpY5vCUo45D6ixkjR9g4UZPCMvWYJuWpVgoXoAfnMO_DfUh7h6kQ1qnHPIXPNseFk9nGOTPeEs6SI_jzrBDimGeW_ot2wkT5rCeczvUpuMO1h5leitBOAhtvab03FziEhBjZCb01NY56QTdw4acXNE0GhSyHBccpsUABqjvPkT0nyttVIMYtQ',
#      'width': 4032}],
#    'place_id': 'ChIJ6wsgLTMbdkgRObEIyzQf10g',
#    'plus_code': {'compound_code': 'GV7F+WV London Congestion Charging Zone, London, UK',
#     'global_code': '9C3XGV7F+WV'},
#    'price_level': 1,
#    'rating': 4,
#    'reference': 'CmRbAAAADwCdkahmdwO1aP9-jDs7_V1sDGWLJ7CgCStyFc47ct3XiP2xFtjX_pIw3FDojhC1cWSasICKY-yGNr9-u1fBcCG9Jj-t1Xqw8RGsYhRdzuUVrqvSMHs4gr5xBUWoUL6TEhBdhSPOm9NWLDBSrlw_gSPeGhTxZmw3ikF11XRs2XSlPNpdQwkrlA',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': '45-49 Endell St, London'},
#   {'geometry': {'location': {'lat': Decimal('51.5169125'),
#      'lng': Decimal('-0.1728106')},
#     'viewport': {'northeast': {'lat': Decimal('51.51829112989272'),
#       'lng': Decimal('-0.1714087201072778')},
#      'southwest': {'lat': Decimal('51.51559147010727'),
#       'lng': Decimal('-0.1741083798927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '2d5729301df5f448b6fb7f725f52c3d3005c5b89',
#    'name': "Micky's Fish & Chips",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 413,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111156056387931152354/photos">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAGHFbNBo6VWlO6hP_sfuPkVYZdQQJpaTFA0BSoKjYD72inVlyz7VMEIuSADz7lGA7zimd91kZ6lFjsEylunvqrVY8K_50s8lbsS2AmOv3LijU0A6J6AGZEVtm2MtFyKF4EhA6ASBBBiONuYvXOKhVgwVfGhTqlPQqctXtfFA2AlQczMU5n6Tk9A',
#      'width': 550}],
#    'place_id': 'ChIJuXHeBLMadkgRdaZ33XZZspM',
#    'plus_code': {'compound_code': 'GR8G+QV Paddington, London, UK',
#     'global_code': '9C3XGR8G+QV'},
#    'rating': Decimal('3.9'),
#    'reference': 'CmRbAAAAp78uUIU-tWZCfxl-E1t7zj2COy4H72lCDshPUj7HKLVkBxe7-jN3BeDriD4U4pvrs-DjRHykQguI_-ZZsnz1jUlChTuW045OxI-mdcWGlNMUwbE-AdjPnIxKhR7nPm-IEhDx0Bs25EdcKL08V4hwVX1DGhRIxzs0T0nnQ_DDWTTSzM4GPvF2OQ',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': '29 Norfolk Pl, London'},
#   {'geometry': {'location': {'lat': Decimal('51.5165109'),
#      'lng': Decimal('-0.07496029999999999')},
#     'viewport': {'northeast': {'lat': Decimal('51.51786072989272'),
#       'lng': Decimal('-0.07361047010727777')},
#      'southwest': {'lat': Decimal('51.51516107010728'),
#       'lng': Decimal('-0.07631012989272221')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '43029b78b00c4f252b6197a1035f38412769a8f6',
#    'name': 'Happy Days fish & chips',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1837,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108322329337197298760/photos">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAUtIB8amCkyVeqQRbZkp2BlblnX0h47PZzFV09QN8nLMg5nPT_0S23KPL-VTbs_mdESv0HIr2BAiEBsciCG1QdHaQ3Hc4voq1JtVCvD_Ji197tfyf7qsuKzraYAieOLEdEhB3QKVXUq07xyFKhVkvFjUjGhRMh63mCJ3Gqxcr5PJF8Q8YnHNAGw',
#      'width': 3264}],
#    'place_id': 'ChIJGzBdlrQcdkgRdxWH8XqOP-8',
#    'plus_code': {'compound_code': 'GW8G+J2 London Congestion Charging Zone, London, UK',
#     'global_code': '9C3XGW8G+J2'},
#    'rating': Decimal('4.3'),
#    'reference': 'CmRbAAAAukCmCYW6mGS2WYQTqBlHglxKqXOnnJ7yV9tXKDs-JhSB2WjnC_Y4WWQ_SRhmKaoT_-eX7m-B4DGTRIo60JZRzvbZ67FAKLOqEj3TCmqpopEekb4L3KWImKmADkqvy-hxEhAOv3O4_-o2HT_sRhGFjCFMGhSO0ieloGeEB8LsqkJTyre-Dr36kg',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': '44 -46 Goulston street, London'},
#   {'geometry': {'location': {'lat': Decimal('51.487695'),
#      'lng': Decimal('-0.1411474')},
#     'viewport': {'northeast': {'lat': Decimal('51.48908897989272'),
#       'lng': Decimal('-0.1398142701072778')},
#      'southwest': {'lat': Decimal('51.48638932010728'),
#       'lng': Decimal('-0.1425139298927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'b3e3615f0cc1efba2d22dc4acaf60433a2cb63e8',
#    'name': 'Pimlico Traditional Fish & Chips',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113795129168498000286/photos">Al Bigalex6</a>'],
#      'photo_reference': 'CmRaAAAAnXzyejCYyXCcVdDU-g0-0nkjNXC8EgQM7RBTVX6RpWfc-JwhLGjAKg1C5dj5d5G8SPpug3jhc8-j1NLUeBHA3Rxpt6HjE7mY3efORI02cZW4utGuqcpe3ta9-2o2FNVtEhApQA0vmNyOICVOES30QSsdGhTL-faet7JVVLHze7iqrBqmhCmlcQ',
#      'width': 5312}],
#    'place_id': 'ChIJ13iW7R0FdkgRbeLbYNW0dJA',
#    'plus_code': {'compound_code': 'FVQ5+3G Pimlico, London, UK',
#     'global_code': '9C3XFVQ5+3G'},
#    'rating': Decimal('4.3'),
#    'reference': 'CmRbAAAAN1grj4MqE4t9h7k59vzd7Q_-qMo2abb0MKK44VIHpv5NlVvZGwQXN9SJur9JzHhfls4QZqesEYCA1a3c-5Se110KCpsbC5UabyeIyilYxdS8pf5R04d9PV3xlYK6Q1sAEhAwlyzg6x4bAe0xPtnBDkOUGhTCviCwCJsPOsPm1dCsOo6Nb14SQQ',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': '103 Lupus St, London'},
#   {'geometry': {'location': {'lat': Decimal('51.5216583'),
#      'lng': Decimal('-0.1575309')},
#     'viewport': {'northeast': {'lat': Decimal('51.52302842989273'),
#       'lng': Decimal('-0.1560693201072778')},
#      'southwest': {'lat': Decimal('51.52032877010728'),
#       'lng': Decimal('-0.1587689798927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '11e7c31c4ff5e63f3035a921741aa84300a72a5e',
#    'name': 'Holmes Fish and Chips',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103181796608472089043/photos">Jennie Tu</a>'],
#      'photo_reference': 'CmRaAAAAYG_RL0MyPFM7BZtOAlB5zstwMPcjY1zul3WS8e6xOtu71X3eXcPgNJqdd8vpzSIMOOdW_u8kV3DLem5U284wscrNFU7nxZqnjSR3vdixVVFWhlGax-cKXDgaEn5BZ2zwEhCno-rZOCm6ZDP_Lav7ObcUGhQVCEdkApQw7RbEjeY_VXfmDt4kZQ',
#      'width': 4032}],
#    'place_id': 'ChIJaQTVwM4adkgRIiyjKltNcAE',
#    'plus_code': {'compound_code': 'GRCR+MX Marylebone, London, UK',
#     'global_code': '9C3XGRCR+MX'},
#    'rating': Decimal('2.7'),
#    'reference': 'CmRbAAAAKuMFHvZ3qanFEaoGO-b7RTp0t1dBJIt3oXeCVxWGH9DM85LxE260sZ-uaswgSzyk4tVYeA78-kfPCfCLh99M8x0xcTGtMJYGavfAMGlG-dp-cMEmPK26YAdH1mhUK7ZNEhCq8c7YaGsyUT7FkF_0Nz7lGhTLlswBGGrIKnR-ez3TynqPFGB1ZQ',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': '123 Baker St, London'},
#   {'geometry': {'location': {'lat': Decimal('51.5335543'),
#      'lng': Decimal('-0.1093253')},
#     'viewport': {'northeast': {'lat': Decimal('51.53486087989272'),
#       'lng': Decimal('-0.1079660701072778')},
#      'southwest': {'lat': Decimal('51.53216122010728'),
#       'lng': Decimal('-0.1106657298927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '2436c5da35c23b65acd4399c275e6709401bfcfa',
#    'name': 'The Crown Fish & Chip Bar',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107194509413349445109/photos">Chris Starkey</a>'],
#      'photo_reference': 'CmRZAAAAGAnmNBXnS1fzsibn0z1M3hLpeSCz3KpheomG5Xl6yc5vzqWvFXzD1gFpHBbvWedHfE5EUObGh58Qkg3CtON7npdPDzWchocObqwQOaKIaHmNaRZcyKigPhGyAAlbt-RSEhAo6_q4sxWq78S5wkJ0nVSjGhSf3sj12tdV9q1rCltX96hh1uIWWA',
#      'width': 3120}],
#    'place_id': 'ChIJM3FeUkIbdkgR8rvVJOFqDEY',
#    'plus_code': {'compound_code': 'GVMR+C7 London Congestion Charging Zone, London, UK',
#     'global_code': '9C3XGVMR+C7'},
#    'rating': Decimal('3.7'),
#    'reference': 'CmRbAAAAr3Z0a6EPqlXftUwvqglPdGapzy1s6Ds6mWqu7QgF9ljrLFN6FUrIg611oxWOuWAZwH3MlhjLGhzgrKPsEeHgDr5vtZmW_el1yXnhBig9Wvj_qBqedOZYS4eMCuKRvcKIEhDCGUfPmIJt-ohSMX8igMthGhSQCg5nopymj_7ChAjd3LJSTZhVjg',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': '20 Chapel Market, London'},
#   {'geometry': {'location': {'lat': Decimal('51.5153659'),
#      'lng': Decimal('-0.1375995')},
#     'viewport': {'northeast': {'lat': Decimal('51.51673587989272'),
#       'lng': Decimal('-0.1362170701072778')},
#      'southwest': {'lat': Decimal('51.51403622010728'),
#       'lng': Decimal('-0.1389167298927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'a2b9f1d66f9cbd3ba957b27ae2c6e0512d57c164',
#    'name': 'Golden Union',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113108178010213795598/photos">Tomasz Bobrowski</a>'],
#      'photo_reference': 'CmRaAAAAVERzsAClgjU_303dEHArAlfySceDXNJYvVaXDHe9Fpapg_2gxrOAz5H0Vn71VY1ejGkd2BLrQgGykDeOQ0N3R9Y62mxA62rGgdU7ZuY9NMBqP42TKjj6PBDFd-TgBhaqEhCyFQRZoH33NZBkIXEbr62sGhRVcv_f-311tto9XKxsPZ7KOkVNbQ',
#      'width': 4032}],
#    'place_id': 'ChIJLZnILisbdkgR1ok3oOdfcl4',
#    'plus_code': {'compound_code': 'GV86+4X Soho, London, UK',
#     'global_code': '9C3XGV86+4X'},
#    'rating': Decimal('4.3'),
#    'reference': 'CmRbAAAAbQilGA8saa7cqlddT5OObaEs-z5C4pP3Dl67MrB_O5e9VOq158Lhek3OGtMSSTcttDiF7on6l_NDREuYzReOdcV9RT4RyD3RGdiiDagyuYbUwUDQWk7UuH5OdbHrcthsEhDDxWJr7ZdkC-xwn_ZQs_OFGhS_OaQiQxEP3e00WDxvtReLPaMJCQ',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': '38 Poland St, London'},
#   {'geometry': {'location': {'lat': Decimal('51.398301'),
#      'lng': Decimal('-0.091069')},
#     'viewport': {'northeast': {'lat': Decimal('51.39960582989272'),
#       'lng': Decimal('-0.08968967010727778')},
#      'southwest': {'lat': Decimal('51.39690617010727'),
#       'lng': Decimal('-0.09238932989272221')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '2f28018839047b210884193015afe0626388c904',
#    'name': 'Doneagles Fish and Chip Restaurant',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107162602736311473705/photos">naif iseri</a>'],
#      'photo_reference': 'CmRaAAAAUmb14m5ie6g1fiKhlaWrsVmN8yR3Djzn_XSw7UTO_yvd4f9sbKaNZvEezGAiZGoEFwY_udkKKL0Ri7_gqgrZUuKINkN-Bb54bVL8JbT374g3Ip9jB8Kx0FLOmyBm7uzNEhBKolDUvMw0MMALrdXwuI62GhQ0_8LdM1CLxZ8pQDYv5FTbvqj2zg',
#      'width': 5312}],
#    'place_id': 'ChIJC4sXtTwBdkgRfjAEgGj-gPU',
#    'plus_code': {'compound_code': '9WX5+8H Thornton Heath, United Kingdom',
#     'global_code': '9C3X9WX5+8H'},
#    'rating': Decimal('4.1'),
#    'reference': 'CmRbAAAAxae6xehRTDTkQwQtgkiwVgQ1zb4Ip7cLzoeDquqrKdE22If0Q9fP9qD-w-oIIH5wU3bc2iKbtK9BcWIZ-_kTSFXXCGJFgRQWA0rlJiqQRQD3zR7Lt6HOklpcw9Go-IEhEhBDLGOcbPXxX_0k6IpaL02aGhThz7yVzbdTj0fRBEuNNFbb6rZsMw',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': '31 Whitehorse Ln, London'},
#   {'geometry': {'location': {'lat': Decimal('51.35095459999999'),
#      'lng': Decimal('-0.03804449999999999')},
#     'viewport': {'northeast': {'lat': Decimal('51.35230442989271'),
#       'lng': Decimal('-0.03669467010727778')},
#      'southwest': {'lat': Decimal('51.34960477010727'),
#       'lng': Decimal('-0.03939432989272221')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '904d8085ada13dd7d4b7d5ce64fb5fff656b668c',
#    'name': 'McDermotts Fish & Chips Ltd',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106206299887312619326/photos">Katryna Craigen</a>'],
#      'photo_reference': 'CmRaAAAAW71ONegUrKYmlA0zgAIOkZh17-Vm8ESx3jNlB9zQCUcAT1p0cqRJ0BUWjrf5zPTykpIFctRiFIPs0eAYVsYa7QSv0zb-CYCdBY71wh6NSV3lTdmf5mgOJ42FSfR0dYCGEhAsQ2nsK7veZKYs414YOr0mGhQskMyECIZaXj768Cj9TuRFqc9-mw',
#      'width': 4032}],
#    'place_id': 'ChIJaZzBCnkAdkgRNHOs5snGmcE',
#    'plus_code': {'compound_code': '9X26+9Q Croydon, United Kingdom',
#     'global_code': '9C3X9X26+9Q'},
#    'rating': Decimal('4.7'),
#    'reference': 'CmRbAAAA9FUlrBwZPJ_61ebFTGxohmlWy1QkJ3utETjwKsAFbvJBZ3WDYeeoA12pWHkunp-HtXpy1l3s4iWwNRRe7f4p1ZuHCrqoXigYhsgI8UcEbMqIVQ_GeKxJmoM6ooW3x6FoEhBgHon1cuFLcWdmmhu9RShcGhQFgtBsdQ22jFtjyTxfVzkt3HoJag',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': '5-7 The Forestdale Centre, Featherbed Lane, Croydon'},
#   {'geometry': {'location': {'lat': Decimal('51.5227185'),
#      'lng': Decimal('-0.165802')},
#     'viewport': {'northeast': {'lat': Decimal('51.52410552989272'),
#       'lng': Decimal('-0.1643835701072778')},
#      'southwest': {'lat': Decimal('51.52140587010727'),
#       'lng': Decimal('-0.1670832298927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '13f96a067610d08b4cf2d87f3f93baeef419d759',
#    'name': 'The Sea Shell of Lisson Grove',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1586,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115644855879760634317/photos">The Sea Shell of Lisson Grove</a>'],
#      'photo_reference': 'CmRaAAAAEDNMkYasviFAfFLXrXKhgXUnESRQyMrD7XXMket9tB1WyMSo6lcuEZInZTdnUjNyy0GoXEnY8XC5esTz79qdQwuWzA3hrMdCVL6_zwza8qNlnr7NlGtXy2RJ6iAI66tTEhAeTGRsaGzlJ7O2rMvsec-IGhQlkr2PTVW-juI0XBHIwRtXSI7wkA',
#      'width': 2378}],
#    'place_id': 'ChIJZ7rcNLYadkgR9MFSAbGgQu4',
#    'plus_code': {'compound_code': 'GRFM+3M Marylebone, London, UK',
#     'global_code': '9C3XGRFM+3M'},
#    'price_level': 1,
#    'rating': Decimal('4.2'),
#    'reference': 'CmRbAAAAPPG_NoTb8tQGnXssQKxOrVTaVDIHfzengSB_TuzBw0olqd2lp0jLFfG5eBRnDNbLowOAmnkTDEBJUlJLzYZYc-vBBN_rD_7iK00u3U8FfpZptZOC1CzF1Pldr3DakjAWEhCLUCzpzc1mnRGxHZz9FiUHGhRsO2AxFbVN1jYnSqlBuh4D3PyaMQ',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': '49-51 Lisson Grove, London'}],
#  'status': 'OK'}

# %% [markdown]
# # Google Place API

# %%
def get(s):
    info = []
    for i, v in s.iteritems():
        info.append(v)
#     parametors => https://developers.google.com/places/web-service/search?authuser=1&hl=ja

    print(info)
    print("yes")
    query_result = google_places.nearby_search(lat_lng = {'lat': info[1], 'lng': info[2]},\
                                              radius=1000,keyword = info[0],language = 'ja',\
                                              types=[types.TYPE_FOOD])
    
    if len(query_result.places) == 1:
        print(query_result.raw_response['results'][0]["name"])
        name.append(query_result.raw_response['results'][0]["name"])
        print(query_result.raw_response['results'][0]["place_id"])
        place_id.append(query_result.raw_response['results'][0]["place_id"])

    else:
        name.append("No Data")
        print("couldn't get")
        place_id.append("No Data")
        print("couldn't get")
    
    
    
pd.iloc[0:1000][["name","latitude","longitude"]].apply(lambda x: get(x), axis=1)

original = pd.head()
# Out:
# ['鮨 一幸', 43.05526972, 141.3534469]
# yes
# 鮨 一幸
# ChIJ8aNdJ3HVCl8Rxd_Bglm1_Jw
# ['田ざわ', 41.7861, 140.7605289]
# yes
# 天ぷら 田ざわ
# ChIJ1-NfLGX0nl8RcqLqXOh4LCQ
# ['すし宮川', 43.05328472, 141.3248686]
# yes
# すし宮川
# ChIJq6o2ZuopC18R-IYrrMOFUWI
# ['鮨菜 和喜智', 43.05202806, 141.3228031]
# yes
# 鮨菜和喜智
# ChIJh7LFi-kpC18Rk8CQKeLzSEc
# ['壽山', 43.04999889, 141.35709690000002]
# yes
# 壽山
# ChIJ2Yw3LoYpC18Rruc9BvhRWmc
# ['鮨みなと', 43.76649528, 142.3608331]
# yes
# 鮨みなと
# ChIJAQAt2A3mDF8RjI2xohP8FMk
# ['寿し ひでたか', 43.05005722, 141.3572922]
# yes
# 寿し ひでたか
# ChIJl2M3OYYpC18Ryn1TYf8S6z4
# ['鮨処 有馬', 43.05431056, 141.3553186]
# yes
# 鮨処 有馬
# ChIJaQ7d7YQpC18RGaROi9_Jg-I
# ['焼肉ひび屋', 41.87646372, 140.6580086]
# yes
# ひび屋
# ChIJpSPldcn5nl8RBQslRPhqVAw
# ['レストラン・モリエール', 43.05494306, 141.3152789]
# yes
# モリエール
# ChIJ14UhkcMpC18RYEwgnUQ8T10
# ['味道広路', 43.05741139, 141.7994056]
# yes
# 味道広路 (あじどころ)
# ChIJvRuG-NjLdF8R7jnzkquJRbw
# ['ミシェル・ブラス トーヤ ジャポン', 42.58901889, 140.7641358]
# yes
# ミシェル・ブラス トーヤジャポン
# ChIJaZnE7Mz8n18ROheQ7SN7mrY
# ['梅乃寿司', 41.78401889, 140.76738419999998]
# yes
# さくら通り 梅乃寿司
# ChIJQT5BBWP0nl8Re4RlGntsr5o
# ['saveur', 43.05388917, 141.35756809999998]
# yes
# saveur サヴール
# ChIJRSMvZYQpC18RGVnDx2Tq-b4
# ['バローレ', 43.55056083, 142.520465]
# yes
# VALORE
# ChIJJ05LrivPDF8RQFQoedO37Go
# ['伊勢鮨', 43.19819917, 140.9990653]
# yes
# couldn't get
# couldn't get
# ['麺屋 彩未', 43.03279722, 141.3856189]
# yes
# 麺屋 彩未
# ChIJ8QvxwkgqC18RzLwtQHUynbc
# ['酒房しんせん', 43.05105556, 141.3584289]
# yes
# 酒房しんせん
# ChIJyYryYYYpC18RMnPzPXVoq6Y
# ['薄野 鮨金', 43.05342917, 141.35623969999997]
# yes
# 薄野 鮨金
# ChIJO2L3WoQpC18RVFrCz-LGNkI
# ['レストラン・マッカリーナ', 42.76286083, 140.78148810000002]
# yes
# レストラン・マッカリーナ
# ChIJ48uI6A2tCl8RLuFM2xltaqs
# ['十勝川温泉 三余庵', 42.93131222, 143.30144330000002]
# yes
# 十勝川温泉 三余庵
# ChIJiYzy_3-ic18Rzjr4vMiyu44
# ['オーベルジュ・ド・リル サッポロ', 43.05244556, 141.31818940000002]
# yes
# オーベルジュ ド リル サッポロ
# ChIJ3cVpe8IpC18R9_v6oY2YRh8
# ['眞', 43.03628, 141.30645969999998]
# yes
# 眞
# ChIJSxqJzgTWCl8Rv-NuDzFp8gM
# ['成吉思汗 大黒屋 5丁目支店', 43.76701298, 142.3610535]
# yes
# 成吉思汗 大黒屋 五丁目支店
# ChIJRf7PMgzmDF8Rm_3HyHkvjn0
# ['グルマンズ\u3000いとう', 43.05007389, 141.3534406]
# yes
# グルマンズいとう
# ChIJl1GOtIgpC18RXUgqu2AGNK8
# ['こまつ', 43.04166861, 141.3106525]
# yes
# こまつ
# ChIJ-2wUiB3WCl8Rjsf0aFapVeQ
# ['だるま 本店', 43.05138417, 141.3561375]
# yes
# 成吉思汗だるま 本店
# ChIJbQQV34UpC18RgzQI7TQon1g
# ['独酌\u3000三四郎', 43.76580194, 142.3602289]
# yes
# 独酌 三四郎
# ChIJ5zitbQ7mDF8RuXf2UocQpwg
# ['郷土料理 おが', 43.0539775, 141.35821030000002]
# yes
# 郷土料理 おが
# ChIJjfD-PoUpC18RKEs7knCDZYE
# ['五十嵐', 43.05693917, 141.3605094]
# yes
# couldn't get
# couldn't get
# ['すし屋のさい藤', 43.05038167, 141.3575186]
# yes
# すし屋のさい藤
# ChIJ9ahtbYYpC18RIH3NvuNsyEc
# ['群来膳', 43.19251972, 141.0049233]
# yes
# 群来膳
# ChIJq6oeh1HgCl8RmhDGKbEEVbY
# ['Ｌａ\u3000Ｃｕｃｉｎａ\u3000ＶＥＮＴＩＴＲＥ', 41.78996958, 140.7689285]
# yes
# La Cucina VENTITRE
# ChIJd2ta22f0nl8RFPyScmMNAfE
# ['麺屋 高橋', 43.00966694, 141.4239383]
# yes
# 麺屋 高橋
# ChIJ30yccd0qC18RlHsevuRWxKU
# ['ドゥ・エルミタアヂュ', 43.05431806, 141.3553231]
# yes
# couldn't get
# couldn't get
# ['美国観光ハウス', 43.29658444, 140.6029256]
# yes
# 美国観光ハウス
# ChIJlU4uFwT3Cl8RKGo6vRZq3AU
# ['麺屋 菜々兵衛', 43.04700306, 141.4496417]
# yes
# 麺屋 菜々兵衛
# ChIJhyR-yoYrC18RTPBCLgLjdVs
# ['MEN-EIJI HIRAGISHI BASE', 43.0269275, 141.3700364]
# yes
# 麺eiji平岸ベース
# ChIJucxAR2oqC18Re_jRy-QfVhM
# ['コートドール', 43.05561083, 141.3158675]
# yes
# コートドール
# ChIJr-5x8cMpC18RE14Vils4K9c
# ['鈴木食堂', 43.38258222, 145.8177767]
# yes
# 鈴木食堂
# ChIJ79gk4UgvbF8RyE11QZ5AFpw
# ['二代目 佐平次', 41.79135111, 140.7549686]
# yes
# 二代目 佐平次
# ChIJ_2OI2W30nl8RKXl1X2YKCl0
# ['ラ・サンテ', 43.05780889, 141.3196906]
# yes
# ラ・サンテ
# ChIJS-3l3sUpC18RKTD7qd7vAfU
# ['ル・ミュゼ', 43.04741806, 141.302725]
# yes
# ル ミュゼ
# ChIJRw3Fj98pC18R6KQr4gyo-FY
# ['AKI NAGAO', 43.05397139, 141.3579744]
# yes
# アキ ナガオ/AKI NAGAO
# ChIJiULtcIQpC18Rb7FjRDdL7Xk
# ['あかん鶴雅別荘\u3000鄙の座', 43.43054944, 144.1017858]
# yes
# あかん鶴雅別荘 鄙の座
# ChIJc2Jn4NaFcl8RnEehj7-YUxQ
# ['おしどり', 43.04642361, 141.357135]
# yes
# couldn't get
# couldn't get
# ['くりや', 43.0397375, 141.4180733]
# yes
# くりや
# ChIJzQM3SrsrC18RKLi1b06gGIw
# ['金寿司', 43.06326139, 141.3704017]
# yes
# couldn't get
# couldn't get
# ['ザ\u3000バー\u3000ナノ', 43.05388026, 141.3576864]
# yes
# The Bar Nano
# ChIJQzj5b4QpC18RRvM4XmG9hsM
# ['Restaurant MiYa－Vie', 43.04758528, 141.32706389999998]
# yes
# couldn't get
# couldn't get
# ['バー・プルーフ', 43.05407278, 141.3576403]
# yes
# バープルーフ
# ChIJv57FeoQpC18R8V_BrzNaaVU
# ['ビブレ', 43.62120565, 142.45003380000003]
# yes
# couldn't get
# couldn't get
# ['天ぷらあら木', 43.05006694, 141.3572997]
# yes
# 天ぷら あら木
# ChIJG79FOYYpC18ROd2h5DgUOG0
# ['すし屋 高大', 43.19301972, 141.0017989]
# yes
# すし屋 高大
# ChIJJ8OGuVPgCl8RhhJuJ5z2ygM
# ['鮨おおね田', 42.10453719, 140.57478600000002]
# yes
# 鮨おおね田
# ChIJDeLIC_Cun18RnHL-OOtTHR8
# ['鮨ノ蔵', 43.05536972, 141.35526000000002]
# yes
# 鮨ノ蔵
# ChIJuVnHo4QpC18R2184jUbAsMg
# ['うに むらかみ 函館本店', 41.76932861, 140.72792890000002]
# yes
# うにむらかみ 函館本店
# ChIJLYj9jaHznl8RnjMijaCw4qE
# ['ファイ', 43.05536278, 141.3536328]
# yes
# ファイ
# ChIJpRU4y4QpC18RpnrZ180vllM
# ['ラ・ブリック', 43.06295722, 141.3654739]
# yes
# ラ・ブリック
# ChIJqVjv4nApC18RdSqzNOE__ws
# ['あま屋', 42.33663111, 142.3710836]
# yes
# お料理 あま屋
# ChIJo38ac-PKdV8RW0WOodA7Frs
# ['フレンチレストラン ミクニ サッポロ', 43.06534944, 141.3548472]
# yes
# ミクニ サッポロ
# ChIJi4jaWWogdV8R6hoLAel92ps
# ['鮨処 北の華', 42.81956056, 141.6493925]
# yes
# 鮨処 北の華
# ChIJ_fDxY6UgdV8RdAXBYAofDZg
# ['鮨処うえの', 43.05135972, 141.35881669999998]
# yes
# 鮨処うえの
# ChIJ1SH-i4YpC18RNf_-zSShUbw
# ['meli melo', 43.05478139, 141.35789309999998]
# yes
# méli mélo メリメロ
# ChIJOYkjw-4pC18RGPau6e-qoMA
# ['らーめん佳', 43.02721194, 141.39916330000003]
# yes
# らーめん佳
# ChIJMUj0NlEqC18R96wuYOjIm6A
# ['みさき', 43.35349889, 140.46834109999998]
# yes
# couldn't get
# couldn't get
# ['シロクマ食堂', 43.20395917, 141.0026044]
# yes
# シロクマ食堂
# ChIJN7B2wrbhCl8RRAbh_cTW_RY
# ['鮨一', 43.09092083, 141.32482969999998]
# yes
# 鮨一
# ChIJmYWCI_IoC18RFP3y1QjOsUg
# ['2001 BAR Moon Light', 43.76622083, 142.3635531]
# yes
# 2001 BAR Moon Light
# ChIJP2UBmg3mDF8REs1r4FBexZQ
# ['炭焼豚丼 空海', 42.91681389, 141.5751497]
# yes
# 炭焼豚丼 空海
# ChIJkcPoGa_XdF8RUkNpFakU0MY
# ['裏参道牛肉店', 43.05309861, 141.3274411]
# yes
# 裏参道牛肉店
# ChIJPZXH_OopC18RUq2nhnyq5wQ
# ['クロッキオ', 43.05384222, 141.3500861]
# yes
# オステリア クロッキオ
# ChIJN3Gp8I8pC18RAcIRMaMhAbo
# ['フラテッロ・ディ・ミクニ', 43.79639639, 142.8273897]
# yes
# フラテッロ・ディ・ミクニ
# ChIJDa7akvEiDV8Ro0nwy_PzX2s
# ['花小路 さわ田', 43.04999028, 141.3570986]
# yes
# 花小路さわ田
# ChIJS5pdQIYpC18R5DGAmsdI424
# ['フレンチレストラン カザマ', 43.05389778, 141.34250169999999]
# yes
# フレンチレストラン カザマ
# ChIJJ07bC5EpC18RhO32CorraBw
# ['望楼ノグチ登別', 42.49723417, 141.14479359999999]
# yes
# 望楼 NOGUCHI 登別
# ChIJ6YGECt1mdV8RHJnf1aV_IR0
# ['エノテカ・ラ・リコルマ', 41.80257778, 140.7545531]
# yes
# エノテカ・ラ・リコルマ
# ChIJmcMgvj30nl8R75J9BbDE08I
# ['Teze', 43.05314333, 141.35405169999999]
# yes
# Teze
# ChIJSXB1CIUpC18RSXg3GttX9uY
# ['手打蕎麦のたぐと', 43.07422083, 141.2882869]
# yes
# 手打蕎麦のたぐと
# ChIJtexmezkoC18RzBy0KrJ6mMM
# ['ブーランジェリー\u3000ジン', 42.75080889, 140.7797392]
# yes
# ブーランジェリー ジン
# ChIJcfuA0CGtCl8R3F3lm-RaYO8
# ['さっぽろジンギスカン 本店', 43.051277500000005, 141.35362419999998]
# yes
# さっぽろジンギスカン本店
# ChIJhwg_94UpC18RF0j8TEmLd_o
# ['宝すし', 43.18944389, 141.00194030000003]
# yes
# 宝すし
# ChIJE569w1bgCl8RPzb5L8HH1g4
# ['魚菜', 43.05441691, 141.354406]
# yes
# couldn't get
# couldn't get
# ['酒房きばらし', 43.04967306, 141.3545028]
# yes
# 㐂ばらし
# ChIJo8hw6ogpC18RaRQ2JyB9Pe4
# ['野武士', 43.05128305, 141.35839109999998]
# yes
# 野武士
# ChIJ_____4QpC18RpZ5O4L_BIPY
# ['TAKAO', 43.05082222, 141.32655390000002]
# yes
# TAKAO
# ChIJ8fJF7-spC18RLtJAgoTDEFI
# ['ロワゾー・パー・マツナガ', 41.78834722, 140.76796919999998]
# yes
# L'oiseau par Matsunaga 『ロワゾー・パー・マツナガ』
# ChIJcZd0jGb0nl8RuDwhZMavEiw
# ['175°DENO担担麺 本店', 43.05642861, 141.35163359999999]
# yes
# 175°DENO 担担麺 本店
# ChIJuaE6F5spC18RC8Z0ksvCCYU
# ['蕎麦切り 春のすけ', 43.06830139, 141.3629461]
# yes
# 蕎麦切り 春のすけ
# ChIJGyVR63IpC18ReQoUw-UozvM
# ['パティスリーシイヤ', 43.06095083, 141.3274158]
# yes
# パティスリーシイヤ
# ChIJCyTcU7kpC18R2KId42riabo
# ['いただきます。', 43.05149333, 141.3556181]
# yes
# ジンギスカン 羊飼いの店 『いただきます。』
# ChIJkWU54IUpC18RILG14Mo_wmM
# ['喰い処 鮭番屋', 42.99325472, 144.3659314]
# yes
# 喰い処 鮭番屋
# ChIJX0JxAYM9cl8RoHvWMGb1xSQ
# ['リストランテ カノフィーロ', 43.05591472, 141.3604547]
# yes
# RISTORANTE CANOFILO
# ChIJy0Zn_oIpC18RbN86KoIPnao
# ['そば切 雨耕庵', 43.068034999999995, 141.27403080000002]
# yes
# そば切 雨耕庵
# ChIJ3Vqf-CYoC18RedwXU9YCvho
# ['ホルモン 銀牙', 43.05378056, 141.35863559999999]
# yes
# ホルモン銀牙
# ChIJF--LdIQpC18RLh0aizHlGEw
# ['風遊斎', 43.02186944, 141.4768556]
# yes
# 沖縄そば風遊斎
# ChIJ___TUUUrC18R3Ty4lw3bCkQ
# ['中国料理 美麗華', 43.05190056, 141.3689872]
# yes
# 美麗華
# ChIJ9xcpboApC18RuSENYA-OAB4
# ['lien', 43.05501722, 141.3297408]
# yes
# couldn't get
# couldn't get
# ['千春鮨 札幌店', 43.051155, 141.3583375]
# yes
# 千春鮨 すすきの
# ChIJ-0LqfIYpC18REUNcGEw1do4
# ['対照', 43.05174337, 141.35679]
# yes
# すし処・対照
# ChIJfVBZ1oUpC18R35KtPW7q0sA
# ['つかさ', 41.78774222, 140.7532969]
# yes
# couldn't get
# couldn't get
# ['麺や けせらせら', 43.12820972, 141.35857439999998]
# yes
# 麺や けせらせら
# ChIJe5IaH18vC18Ryk6aRRFYJ8Q
# ['エグ・ヴィヴ', 43.20261667, 140.8731289]
# yes
# エグ・ヴィヴ（Aigues Vives）
# ChIJWZtEGRLkCl8RcJIKKDxS6Lo
# ['麺や 麗', 42.83439917, 141.6561314]
# yes
# 麺や麗
# ChIJo4nIH63YdF8RNLF6RC1NDmg
# ['手打ちうどん寺屋', 43.06588639, 141.29880469999998]
# yes
# 手打うどん 寺屋
# ChIJXbQsRzMoC18REC4Hvim5QcM
# ['ラビスタ函館ベイ', 41.76511972, 140.7225628]
# yes
# ラビスタ函館ベイ
# ChIJixHcrKfznl8R_WyY3JnQfQA
# ['一文字カリー店', 43.03279472, 141.43651530000002]
# yes
# 一文字咖喱店
# ChIJU2fHCwsrC18RAehBLiEwRHI
# ['ピッツェリア ダ マッシモ', 43.04569111, 141.4500156]
# yes
# ピッツェリア・ダ・マッシモ
# ChIJq6p1XoErC18RZN2lC6kPZB0
# ['ブランジェリー ラ・フォンティヌ・ドゥ・ルルド', 43.0518225, 141.29651030000002]
# yes
# ブランジェリー ラ・フォンティヌ・ドゥ・ルルド
# ChIJNYxtadgpC18RMnHmdqrskSo
# ['阿佐利 本店', 41.75793222, 140.7235189]
# yes
# すき焼き 阿さ利本店
# ChIJx1B0IATznl8RN24duWJy8WI
# ['成吉思汗\u3000だるま 4・4二階亭', 43.05244556, 141.3561139]
# yes
# 成吉思汗 だるま4・4店 二階亭
# ChIJH3jxyoUpC18RHY7ebMwazag
# ['いし豆', 42.77659944, 140.7880939]
# yes
# 手打ち蕎麦 いし豆 石臼挽き
# ChIJWZQCsGWtCl8RD8Q6LxV8v1o
# ['BLANC', 43.05122111, 141.35645219999998]
# yes
# couldn't get
# couldn't get
# ['ル・ジャンティオム', 43.05188028, 141.3503267]
# yes
# ル・ジャンティオム
# ChIJUZbDmI8pC18RGusGnj4jaOk
# ['コルツ', 41.785985, 140.75437780000001]
# yes
# コルツ
# ChIJ9fq0nHD0nl8RaXb3G7XdG98
# ['棗', 43.05316278, 141.3540883]
# yes
# couldn't get
# couldn't get
# ['登別温泉郷 滝乃家', 42.49208722, 141.1456656]
# yes
# 登別温泉郷 滝乃家
# ChIJPZ_2ccRmdV8RBqpqFfPASqs
# ['定山渓第一寶亭留\u3000翠山亭', 42.96480417, 141.1657194]
# yes
# 定山渓第一寶亭留 翠山亭
# ChIJV7UyiyHSCl8Rz2mQ5LxF6g0
# ['鮨西光', 43.05233222, 141.35820859999998]
# yes
# 鮨 西光
# ChIJ6bhSnYYpC18ReX697qsoM6M
# ['テアトロ ディ マッサ', 43.05369389, 141.3501681]
# yes
# テアトロ ディ マッサ
# ChIJ316JU4UpC18R9zaCXgno5fU
# ['望楼ノグチ函館', 41.77611787, 140.7878398]
# yes
# 望楼ＮＯＧＵＣＨＩ函館
# ChIJFS2uzpP0nl8RbEdhU-J4nUg
# ['鮨処 美な味', 41.76208056, 140.7216156]
# yes
# 鮨処 美な味
# ChIJ3zZS9Afznl8RLexeyJElwNo
# ['Rojiura Curry SAMURAI. 平岸店', 43.03761833, 141.37500500000002]
# yes
# Rojiura Curry SAMURAI. 平岸店
# ChIJWRje-TQqC18Rr8rbEh-TQe8
# ['手打蕎麦いちむら', 42.8612625, 140.7278625]
# yes
# 手打蕎麦 いちむら
# ChIJ6a57T2-wCl8RK4ESlCnCQ3s
# ['そば屋 けん豆', 43.03191741, 141.3804227]
# yes
# そば屋けん豆
# ChIJsUkgUUYqC18R85cHzzHEmiQ
# ["Maison de h-l'E´ridan", 43.0459239, 141.3075104]
# yes
# Maison de h-l'E´ridan
# ChIJl91EQ-ApC18RhFMG4CPBAg8
# ['湯宿 だいいち', 43.5851441, 144.726561]
# yes
# 湯宿だいいち
# ChIJAxNUPLkKbV8R-sxqGktRVkw
# ['アキヒサ ハンダ', 43.05413469, 141.3581827]
# yes
# Wine Restaurant Akihisa Handa
# ChIJ4zw2d4QpC18Rzx0wfn18sgs
# ['ゴーシェ', 43.05356645, 141.3502455]
# yes
# couldn't get
# couldn't get
# ['カミムラ', 42.85669128, 140.7087709]
# yes
# KAMIMURA レストラン
# ChIJ1fkbwA2wCl8RI1xs1_F19AU
# ['鮨 おくの', 43.55456111, 141.90953969999998]
# yes
# 鮨 おくの
# ChIJbUQs19mYDF8RJlDrsu9pZo0
# ['温味', 43.04423111, 141.35569809999998]
# yes
# 温味
# ChIJf2kYeoQpC18RYZA-o5_mo6o
# ['ぱんちょう', 42.91677306, 143.2072569]
# yes
# 元祖 豚丼のぱんちょう
# ChIJ-Wrdi0CZc18RkQQqqRv9mXY
# ['函館うに むらかみ 日本生命札幌ビル店', 43.06217069, 141.3543033]
# yes
# 函館うに むらかみ 日本生命札幌ビル店
# ChIJ9a9vKJ4pC18RDdPwRNvPVPo
# ['煮干らぁめん なかじま', 43.09949111, 141.3451225]
# yes
# 煮干らぁめん なかじま
# ChIJF6_3pcYoC18Rc-7rMX7ygCk
# ['我流麺舞 飛燕', 43.0209825, 141.3605497]
# yes
# 我流麺舞 飛燕
# ChIJ3UpEknEqC18RWuc8ocnzDp0
# ['ラーメン 木曜日', 43.046125, 141.34099469999998]
# yes
# ラーメン木曜日
# ChIJVzCORfMpC18RMCeDTRBoVb0
# ['テルツィーナ', 43.06253194, 141.3654297]
# yes
# couldn't get
# couldn't get
# ['士別バーベキュー', 43.05393806, 141.3506397]
# yes
# 士別バーベキュー
# ChIJacRlUIUpC18R58DpeEVS6SE
# ['蕎麦喰い処 利めい庵', 43.00504139, 141.326285]
# yes
# 利めい庵
# ChIJ2RReAr3VCl8RvVSFL5G5SiQ
# ['蕎麦屋 此花', 42.95898194, 141.2865381]
# yes
# 蕎麦屋 此花
# ChIJEe_kt2HTCl8RqLtklSGCPZU
# ['鮨処木はら', 41.772135, 140.7912583]
# yes
# 鮨処 木はら
# ChIJlSCIb5b0nl8RtJKkY8HwAcI
# ['しろ', 43.04990139, 141.32513390000003]
# yes
# couldn't get
# couldn't get
# ['ゆるり家', 43.05190028, 141.35857030000003]
# yes
# 手作り創作 ゆるり家
# ChIJ6bhSnYYpC18RmXQpxXqZCMs
# ['レストラン・バスク', 41.782695000000004, 140.7618881]
# yes
# レストラン・バスク
# ChIJD-8_jHz0nl8RF4ao-W5xDMY
# ['バーマデューロ', 43.05370351, 141.3586335]
# yes
# BAR MADURO
# ChIJG1JedIQpC18RQLkhuOBkDl0
# ['蔵鵡 別邸', 43.05374864, 141.35591619999997]
# yes
# 蔵鵡別邸
# ChIJe1L2WIQpC18RQ5b-qVF4a3A
# ['cocktail bar spoon', 43.76492083, 142.3632101]
# yes
# カクテルバースプーン
# ChIJebyUAhLmDF8Rjzd4WWt91HA
# ['フラノフレンチ', 43.35312167, 142.3607714]
# yes
# couldn't get
# couldn't get
# ['さっぽろ純連 札幌店', 43.01835222, 141.3705736]
# yes
# さっぽろ純連 札幌本店
# ChIJj5njG2UqC18RAiq9rUkZZ1E
# ['雨は、やさしく', 43.06685889, 141.4073139]
# yes
# 雨は、やさしく
# ChIJoxdq5FcpC18RT4odwhBx8jY
# ['いせのじょう', 43.05419917, 141.37222140000003]
# yes
# いせのじょう
# ChIJc0RosX8pC18RVRxuYpRWdOk
# ['元祖\u3000小いけ', 41.75943778, 140.7232239]
# yes
# 元祖 小いけ
# ChIJ55aoWAbznl8R6MW9ciTsThs
# ['カプセルモンスター', 43.05450528, 141.33803830000002]
# yes
# カプセルモンスター
# ChIJqVSoAJQpC18RAyn7Rr8LLu8
# ['たいやき札幌柳屋', 43.11388511, 141.3522252]
# yes
# 札幌柳屋
# ChIJHXngwUwvC18RfQeCzkrqYRA
# ['乃の風リゾート', 42.5635039, 140.8270805]
# yes
# ザレイクビューＴＯＹＡ乃の風リゾート
# ChIJtXR_EJjin18RilaFJxpdQp0
# ['鈴の屋', 43.05172722, 141.3585661]
# yes
# couldn't get
# couldn't get
# ['鮨 田なべ', 43.06339917, 141.3506475]
# yes
# 鮨 田なべ
# ChIJtyk_lJ8pC18RgMvaHw73ws4
# ['GRIS', 43.05400253, 141.3494383]
# yes
# GRIS
# ChIJwQimq5opC18RKfl2iEd4B4w
# ['茶寮 瀧乃家', 43.04893611, 141.3591611]
# yes
# 茶寮 瀧乃家
# ChIJi7W1xocpC18RomITG-F8xTs
# ['すし明', 43.0554169, 141.3603887]
# yes
# すし明
# ChIJy0Zn_oIpC18RPx087RqCv98
# ['だるま 6.4店', 43.05047444, 141.3568142]
# yes
# 成吉思汗 だるま6.4店
# ChIJI4jdNIQpC18RrgscbvMN9jc
# ['おたる政寿司 本店', 43.19155444, 141.0038747]
# yes
# おたる政寿司 本店
# ChIJuUOVZVHgCl8RCUm0xBUU6Cs
# ['開陽亭 すすきの店', 43.05122167, 141.3564042]
# yes
# 開陽亭 すすきの店
# ChIJM5wadIYpC18RNpmBdR51I2g
# ['いずみ食堂', 42.48417528, 142.0693336]
# yes
# いずみ食堂
# ChIJlZRlmhasdV8RaCFz78vYUYY
# ['ボン・ヴィバン', 43.04413389, 141.3606594]
# yes
# Bon Vivant(ボン・ヴィバン)
# ChIJcwMrXCYqC18R91f_49MkYdM
# ['バーやまざき', 43.05383833, 141.3573692]
# yes
# バーやまざき
# ChIJByJTZIQpC18RhKFPOcjGYHo
# ['アンジェリック ヴォヤージュ', 41.765327500000005, 140.7126853]
# yes
# アンジェリック ヴォヤージュ
# ChIJUwoq5K7znl8RBiCEANbCAZg
# ['手打ち蕎麦 こはし', 43.0667075, 141.32484780000001]
# yes
# 手打蕎麦こはし soba
# ChIJIxLvWrApC18RQgE5u_9jzkw
# ['八乃木', 43.09454056, 141.27452639999998]
# yes
# 八乃木
# ChIJEfUZf3YoC18Re7SIOoip3Yw
# ['STEAK&HUMBURG ひげ 6条店', 43.05092556, 141.3585511]
# yes
# couldn't get
# couldn't get
# ['やきにく舎 太好了 すすきの店', 43.05149028, 141.35621559999998]
# yes
# やきにく舎 太好了 すすきの店
# ChIJq7Qm2YUpC18RLQXxx8dQbDQ
# ['馬場ホルモン', 43.76923694, 142.3670639]
# yes
# 馬場ホルモン
# ChIJ6yA40XLmDF8RUz5egNtKY-4
# ['とんかつ くにか', 43.04516111, 141.45490890000002]
# yes
# とんかつくにか
# ChIJQU0wtYErC18R-vdfEM8OCGE
# ['CANTINETTA SALUS', 43.05419111, 141.35793859999998]
# yes
# サリュ
# ChIJf2kYeoQpC18RqS0ONNk6uiQ
# ['そば処 大和', 43.01827806, 141.43733830000002]
# yes
# そば処 大和
# ChIJgx-N3hgrC18R8pw3dDPazlc
# ['札幌成吉思汗 しろくま  札幌本店', 43.05124056, 141.3588689]
# yes
# しろくま 札幌成吉思汗 本店
# ChIJxaD-i4YpC18RkcPDS3Ir6Jk
# ['ギリガンズ アイランド', 42.58904972, 140.76417859999998]
# yes
# ギリガンズアイランド
# ChIJGat1Xg39n18RUyl14oAOYAY
# ['プティ サレ', 43.06135833, 141.35457730000002]
# yes
# プティサレ/P'tit sale'
# ChIJMS3c350pC18RVNerRbz6Woc
# ['さっぽろジンギスカン千歳', 42.81700389, 141.6534703]
# yes
# さっぽろジンギスカン千歳
# ChIJy0tBmqQgdV8RioNuk7YfpAU
# ['フラノ寶亭留', 43.3529225, 142.3607336]
# yes
# フラノ寶亭留
# ChIJt1VzuVVNc18RfmcAErh4hEM
# ['唐草館', 41.75420694, 140.7213989]
# yes
# 唐草館
# ChIJ65Ia-gLznl8R4b-h9wCwrvY
# ['焼肉屋 かねちゃん 至粋亭', 43.05438778, 141.35489119999997]
# yes
# 焼肉屋かねちゃん 至粋亭
# ChIJq6o26YQpC18Rax7IAI4X3do
# ['ザバーナノグールド', 43.05424917, 141.3558219]
# yes
# the bar nano.gould
# ChIJdwAo84QpC18RrqplO7pLciA
# ['しの平', 43.05435194, 141.3543967]
# yes
# しゃぶしゃぶ酒屋 しの平
# ChIJ5Ypd5oQpC18RAdWa9fYeOm4
# ['鮨 まつもと', 43.0523554, 141.3581826]
# yes
# 鮨 まつもと
# ChIJq7-VJoQpC18RuDEn7hKvtg4
# ['いわない温泉高島旅館', 42.94916196, 140.52081669999998]
# yes
# いわない温泉 高島旅館
# ChIJI88Xdq2iCl8Ryh-kuKE1Jys
# ['オーベルジュ エルバステラ', 43.39371363, 142.39515690000002]
# yes
# エルバステラ
# ChIJr2a9cNiyDF8Rw1si83zgb3s
# ['杏ダイニング', 42.86063972, 140.704905]
# yes
# 杏ダイニング／カフェ＆バー An Dining / Cafe&Bar
# ChIJ18NAgwywCl8RkEBWQNwoLik
# ['狼スープ', 43.04408389, 141.3610294]
# yes
# 味噌らーめん専門店 狼スープ
# ChIJG6RwZyYqC18RxuLM7lsomiw
# ['あらとん 本店', 43.06727972, 141.3245158]
# yes
# あら焚き豚骨 あらとん 本店
# ChIJc-RePQUpC18RkD0jGjsocIw
# ['クロック', 43.04125528, 141.3122581]
# yes
# クロック
# ChIJm5IZhOIpC18R1PerRX-gmLs
# ['Japanese Ramen Noodle Lab Q', 43.06096944, 141.3578956]
# yes
# Q
# ChIJCf5HInYpC18RX27ztiKaShw
# ['滋養軒', 41.77051056, 140.7343767]
# yes
# 滋養軒
# ChIJCcIb-57znl8RJdR5NEMh6P0
# ['開陽亭 すすきの2号店', 43.05126222, 141.3534906]
# yes
# 函館 開陽亭 すすきの2号店
# ChIJZWu99YUpC18RSqGdTKMkiP4
# ['海鮮処 函館山', 41.76934611, 140.7358467]
# yes
# 海鮮処函館山
# ChIJeSgfSp7znl8R0Y30FAxOIaE
# ['飲茶はるのそら', 43.05558778, 141.3520797]
# yes
# はるのそら
# ChIJc4_rJZspC18RIMH3-JmbrWc
# ['酒庵 五醍', 43.0500244, 141.35686289999998]
# yes
# 五醍
# ChIJzSGXPIYpC18Rj40TAu66qWw
# ['大勝軒', 41.885, 140.6923858]
# yes
# 大勝軒
# ChIJ4Vr8KRb4nl8R3CWRf1fkXKQ
# ['香るつけ蕎麦\u3000蕎麦花', 42.63295, 141.60226719999997]
# yes
# 香るつけ蕎麦 蕎麦花
# ChIJB1JQ78QQdV8RoMiyDg_lI0g
# ['焼肉屋かねちゃん すすきの本店', 43.05148917, 141.356215]
# yes
# couldn't get
# couldn't get
# ['○鮨', 43.050374299999994, 141.35626069999998]
# yes
# couldn't get
# couldn't get
# ['TATEOKA TAKESHI', 43.05428043, 141.35907580000003]
# yes
# 札幌・すすきのフレンチ TATEOKA TAKESHI
# ChIJITnSmoMpC18RrMdUQo5V6oM
# ['寿司一', 40.82566139, 140.7555561]
# yes
# 寿司一
# ChIJ25PxwOSem18Rfj89a-4YzhM
# ['みなと食堂', 40.5212225, 141.53253030000002]
# yes
# みなと食堂
# ChIJobLoWzNSm18RYSHA-vlPVQA
# ['千陽 本店', 40.50699058, 141.49006530000003]
# yes
# 千陽
# ChIJ-53H5AhSm18Ry_313ddyKRo
# ['ほむら', 40.50568798, 141.43594109999998]
# yes
# ほむら
# ChIJ364RTHBOm18RpU0mUW7pDGA
# ['津軽割烹未来', 40.82520722, 140.744305]
# yes
# 津軽割烹 未来
# ChIJcx3BAR6fm18RbxbDn9tCTZQ
# ['オステリア・エノテカ・ダ・サスィーノ', 40.59820444, 140.4705011]
# yes
# couldn't get
# couldn't get
# ['八重さわ', 40.50163889, 141.5441361]
# yes
# 料理茶や 八重さわ
# ChIJaQUNcFhSm18RBmOblTQm9VQ
# ['川よし', 40.82589222, 140.75009609999998]
# yes
# 川よしうなぎ店
# ChIJja1DvuOem18RmVlRlDkfMy8
# ['海の幸 美味', 40.50633393, 141.49471369999998]
# yes
# 海の幸 美味
# ChIJGQpusw5Sm18R5wqb2rwabso
# ['たかはし中華そば店', 40.617484999999995, 140.4988394]
# yes
# たかはし中華そば店
# ChIJsTczegkBm18RWd-g-MfbAN8
# ['カーサ・デル・チーボ', 40.50493389, 141.5397022]
# yes
# カーサ・デル・チーボ
# ChIJmeIQPVpSm18Rsy-JJGLib5w
# ['はた善', 40.82375667, 140.7479608]
# yes
# はた善
# ChIJz579iOKem18Rwd5A_Q8W_08
# ['ローズガーデン', 40.50537722, 141.4971333]
# yes
# ローズガーデン
# ChIJgz3ccQxSm18RrL-i-Si5kQI
# ['うに処\u3000旅路', 41.18952317, 140.6296156]
# yes
# ラーメン店 旅路
# ChIJ6-6IYOz3m18RF2YExdTaRas
# ['シュトラウス', 40.82381306, 140.74220640000001]
# yes
# ウィーン菓子 シュトラウス
# ChIJCf5B0x2fm18RTJBD8SLgAEM
# ['レストラン山崎', 40.59972222, 140.4738242]
# yes
# レストラン山崎
# ChIJHTODpOkBm18Rx2JIvEjhLAM
# ['海峡荘', 41.54352444, 140.9170081]
# yes
# 海峡荘
# ChIJQ3cmf4mcnl8RXIUzTWMOY7U
# ['アルチェントロ', 40.819196500000004, 140.7457478]
# yes
# アルチェントロ
# ChIJ0zzDZgOfm18RYz478OS1Dmw
# ['菜のはな', 40.82295472, 140.7542725]
# yes
# couldn't get
# couldn't get
# ['寺沢', 39.28304806, 141.1114064]
# yes
# 寺沢 (Terasawa)
# ChIJVYN4y45Ej18RADWIinqdF0g
# ['龍園', 39.13403778, 141.1458886]
# yes
# 龍園
# ChIJ3UfLbHFKj18RsGqV0ouaceM
# ['善', 39.69769306, 141.1526878]
# yes
# couldn't get
# couldn't get
# ['松もと', 39.69944972, 141.14958169999997]
# yes
# 松もと
# ChIJe9963S92hV8RYVpGB-jzNEo
# ['シェムラブルリス', 39.69740167, 141.1626789]
# yes
# シェ・ムラ・ブル・リス
# ChIJU7PzJCd2hV8RODJhmsn8K90
# ['盛楼閣', 39.70002083, 141.14005780000002]
# yes
# 盛楼閣
# ChIJR0WE6zN2hV8R6ydjuAknBkg
# ['中華そば 弥太郎', 39.73883833, 141.12208]
# yes
# 中華そば 弥太郎
# ChIJp-8VKb12hV8RPh8yX4k62ck
# ['菜遊記', 39.6988975, 141.15157]
# yes
# 菜遊記
# ChIJ1wOjmi92hV8RkSsN4BZO5yw
# ['Ristorante SHIKAZAWA', 39.69915528, 141.1496128]
# yes
# リストランテ シカザワ
# ChIJ5QePwy92hV8RI733OrNXNJE
# ['DADA', 39.67074389, 141.1418497]
# yes
# DADA
# ChIJ4Qc3_0CdhV8R-N1DiNh-QwQ
# ['沢内甚句', 39.69967444, 141.1448997]
# yes
# 沢内甚句
# ChIJEbiXvTF2hV8RHCDd5X50mJM
# ['日本料理 対い鶴', 39.70155583, 141.1401769]
# yes
# ホテルメトロポリタン盛岡 日本料理 対い鶴
# ChIJ03SrqDZ2hV8RRckQD1E34gI
# ['シェ・ジャニー', 39.70327556, 141.1413381]
# yes
# シェ・ジャニー
# ChIJ88_aAjd2hV8RaIL0YXeXu6o
# ['千松しま', 38.32429722, 141.0176147]
# yes
# 千松しま
# ChIJVVumhxyFiV8RgNgVMDT85VQ
# ['弘寿司', 38.24093111, 140.8832381]
# yes
# 弘寿司
# ChIJAVjkzHUoil8RKgjhB_A0Iec
# ['クロモリ', 38.24524389, 140.87119719999998]
# yes
# 楽・食・健・美 -KUROMORI-
# ChIJmRdsV24oil8RB5d12jJZ6go
# ['日本料理 e.', 38.25516861, 140.87170559999998]
# yes
# 日本料理e.
# ChIJ4X-N-z4oil8RBN1_j-E1aEc
# ['小判寿司', 38.25615833, 140.8768781]
# yes
# 小判寿司
# ChIJs7AopT0oil8RVLGjWbo5SH8
# ['居酒屋\u3000ちょーちょ', 38.263147499999995, 140.8706092]
# yes
# 居酒屋ちょーちょ
# ChIJpY-mKTAoil8RFd0n5e1WmL0
# ['牛たん料理 閣 ブランドーム店', 38.25840139, 140.8754733]
# yes
# 閣 ブランドーム店
# ChIJax8lgzwoil8RNP2eDVbUqek
# ['米沢牛焼肉 仔虎 仙台駅前店', 38.25967556, 140.8838092]
# yes
# 米沢牛焼肉 仔虎 仙台駅前店
# ChIJORdwzCMoil8REeVlErILpYY
# ['中華そば 嘉一', 38.26474, 140.8718083]
# yes
# 中華そば 嘉一
# ChIJ5eSxWy4oil8ROIK8bTn2jHk
# ['萬み高橋', 38.26164222, 140.87196169999999]
# yes
# 萬み高橋
# ChIJr8sDpzooil8R6TQuoIDHCOU
# ['新料理 都留野', 38.26091222, 140.8748981]
# yes
# 都留野
# ChIJuX-AKyUoil8R1fQD7Mdi6Dc
# ['うな貴', 38.26336417, 140.8724881]
# yes
# うな貴
# ChIJQTTEwC8oil8R03ZU4WACFwQ
# ['ナクレ', 38.25814139, 140.88090580000002]
# yes
# ナクレ
# ChIJlQ6djhMoil8Rw5f96EuA3HA
# ['とんかつ かつせい', 38.25080722, 140.88108469999997]
# yes
# とんかつかつせい
# ChIJIRQJ7BMoil8RIA7vjbe0OgE
# ['福よし', 38.90497222, 141.5807764]
# yes
# 福よし
# ChIJb7pJlFiUiF8RLKu7gFTS2Is
# ['鮨 結委', 38.25576139, 140.88034109999998]
# yes
# 結委 ゆい
# ChIJTccY2Rcoil8RUmm-eVXaY60
# ['炭火焼肉 ぐら', 38.31186944, 141.02890359999998]
# yes
# 炭火焼肉ぐら
# ChIJo2lYqnOFiV8RYldsAhJLDz0
# ['カズノリ イケダ アンディヴィデュエル', 38.25544028, 140.8771386]
# yes
# couldn't get
# couldn't get
# ['梵くら', 38.26152944, 140.86734189999999]
# yes
# 梵くら
# ChIJP70B6TAoil8Rxl6nQ4he5oI
# ['大胡椒', 38.26050333, 140.8741833]
# yes
# 大胡椒
# ChIJe_cq2Dooil8R1i03_Bs5cUg
# ['白雪', 38.25757581, 140.87137030000002]
# yes
# 白雪
# ChIJHc0PWDkoil8R6ZitM5eqyWc
# ['割烹 天ぷら 三太郎', 38.25966278, 140.8703633]
# yes
# 三太郎
# ChIJp5MvQTooil8R1kSfZHGM6-g
# ['すし蓑', 38.26180972, 140.8720814]
# yes
# 蓑
# ChIJ39_wBzAoil8RrH9bbphFtBI
# ['ムラタ', 38.28543222, 141.0133186]
# yes
# MURATA(ムラタ 叢田 ）
# ChIJ0dIW1luPiV8R_vj-NhTQBSI
# ['滋味風味 小豆', 38.31606333, 140.8922581]
# yes
# 仙台市泉区［小豆］和食・おすすめ・人気・日本料理・会席料理・懐石料理・顔合わせ・個室・接待
# ChIJsY98KjOBiV8REle-Ij5cVSU
# ['すし哲', 38.31426944, 141.02449309999997]
# yes
# 塩竃すし哲 本店
# ChIJY0rl5QyFiV8Rgyk8vS3Iv_0
# ['ウェスティンホテル仙台', 38.25366917, 140.87968080000002]
# yes
# ウェスティンホテル仙台
# ChIJ7VvjYhYoil8RJmoOEMdlYwE
# ['旨味太助', 38.26199333, 140.8731867]
# yes
# 旨味 太助
# ChIJJ8ESVSUoil8R6BhzzI5ceYs
# ['フレンチレストラン・プレジール', 38.25605306, 140.8690103]
# yes
# フレンチレストラン プレジール
# ChIJAz9M1Dgoil8RjfLVgaffRmc
# ['源氏', 38.25627611, 140.87673]
# yes
# couldn't get
# couldn't get
# ['塩竈 すし哲 S-PAL仙台店', 38.25613583, 140.88529530000002]
# yes
# 塩竃すし哲 S-PAL仙台店
# ChIJIQAgjxgoil8R_1N6RZNGwAo
# ['廻鮮寿司\u3000塩釜港', 38.30404528, 141.01273469999998]
# yes
# 廻鮮寿司 塩釜港
# ChIJd3GJ_JmFiV8RQ9l2GtGkDlQ
# ['あちゃーる', 38.3330425, 140.85613419999999]
# yes
# あちゃーる
# ChIJZ_V-2wWBiV8R7Z9xeyBI1U0
# ['きく屋', 37.92039083, 140.7666256]
# yes
# couldn't get
# couldn't get
# ['BAR arcenciel', 38.26140806, 140.8731267]
# yes
# BAR arcenciel
# ChIJB4VIsTooil8R7RAxeIbpc1w
# ['湯主一條', 38.02174944, 140.57836830000002]
# yes
# 時音の宿 湯主一條
# ChIJK4CfqtxDil8RmvbFT5cKio8
# ['黒毛和牛 牛正 仙台店', 38.26185056, 140.8737711]
# yes
# 牛正仙台店
# ChIJQxtnTiUoil8R1Mt449GuOcw
# ['寿司正', 38.42078832, 141.3721966]
# yes
# 寿司正
# ChIJ6wt_iDq7iV8R40kiz7bcljE
# ['北辰鮨 仙台駅鮨通り店', 38.25707806, 140.8855603]
# yes
# 北辰鮨仙台駅店
# ChIJIQAgjxgoil8R_OaMTCyseeQ
# ['みずさわ屋', 38.26605639, 140.79375280000002]
# yes
# みずさわ屋
# ChIJD3lXv28pil8RU4jvti0QmY0
# ['杉のや', 38.18382778, 140.8773889]
# yes
# 杉のや
# ChIJr5BY_yAkil8Rt8_D-usj5bc
# ['くまがい', 38.28309667, 140.9172656]
# yes
# couldn't get
# couldn't get
# ['ピッツェリア パドリーノ・デル・ショーザン', 38.27099083, 140.8763278]
# yes
# ピッツェリア・パドリーノ・デル・ショーザン
# ChIJX_3ib4CHiV8RV1n8WHRsRlE
# ['韓国家庭料理 扶餘', 38.25436056, 140.88701830000002]
# yes
# 韓国家庭料理 扶餘
# ChIJOxAR8Rkoil8RCNEJQEaHjPw
# ['仙台牛焼肉 花牛', 38.25345944, 140.8796061]
# yes
# 花牛
# ChIJRaTjYhYoil8RObRldjIOJxI
# ['旨いもの家 いま井', 38.26333306, 140.8723053]
# yes
# 旨いもの家 いま井
# ChIJgaCyxi8oil8RyssVfARIEvo
# ['298nky', 38.26132556, 140.87258219999998]
# yes
# 仙台牛焼肉＆ワイン 298nky
# ChIJg3T7ujooil8RZOJ3FC_qXMs
# ['日本料理 たかむら', 39.71805278, 140.1162033]
# yes
# たかむら
# ChIJOUMeZMPCj18RtHstDW65v4A
# ['酒盃', 39.71938667, 140.1052456]
# yes
# 酒盃
# ChIJnzCMgsXCj18RHZB8FMuMSJ8
# ['秋田 てんぷら みかわ', 39.71386056, 140.1174394]
# yes
# 秋田 てんぷら みかわ
# ChIJ12CFk-nCj18RzU5iJvo_0dM
# ['昔のきりたんぽや', 40.2709575, 140.5627475]
# yes
# 昔のきりたんぽや
# ChIJRffosS7Eml8RehnWEDPqA-o
# ['元祖 むらさき', 40.26765778, 140.5576881]
# yes
# きりたんぽ専門店むらさき
# ChIJoRs2-4HGml8RwFz1LClspJs
# ['すし匠', 39.7138525, 140.11959]
# yes
# すし匠
# ChIJ4weGk-nCj18REyTQRtaGltI
# ['すし兆', 39.71234536, 140.13091740000002]
# yes
# すし兆
# ChIJNcSpypLCj18Rc1I2HEpxFbA
# ['鮨\u3000あら田', 39.67906492, 140.0895882]
# yes
# あら田鮨
# ChIJGTTJb4TDj18RqqPfyWDYwvk
# ['Ｊ一行樹', 39.72045917, 140.13984530000002]
# yes
# Ｊ一行樹
# ChIJ3xu4nZnCj18R6NmOpF0N3O0
# ['f', 39.70928472, 140.12006530000002]
# yes
# f(エッフェ)
# ChIJY3klC-_Cj18RLj5Ae2mODbI
# ['秋田牛玄亭', 39.71375387, 140.1295234]
# yes
# couldn't get
# couldn't get
# ['匠', 39.72582861, 140.1177844]
# yes
# couldn't get
# couldn't get
# ['和食すがわら', 39.71726639, 140.12084219999997]
# yes
# 和食すがわら
# ChIJ3wwpIMDCj18R4MsQPFR6ez4
# ['宝寿司分店', 39.72848639, 140.0869178]
# yes
# 宝寿司分店
# ChIJP4FexjHdj18RxYbRQXaKAJw
# ['麺饗 松韻', 39.38778083, 140.03352969999997]
# yes
# 麺饗 松韻
# ChIJ5VR8VnFSjl8R_6lqwX392XQ
# ['鶴の湯温泉', 39.80236536, 140.7834294]
# yes
# 乳頭温泉郷 鶴の湯温泉
# ChIJMy_IqMJmhV8RwCaBe4s4WKo
# ['心粋厨房 獬', 39.70892389, 140.1248531]
# yes
# 心粋厨房 獬
# ChIJgwQFJu7Cj18RKQaPokiDhqU
# ['たつ福', 39.7206625, 140.1384147]
# yes
# たつ福
# ChIJFZ8Uu5nCj18RsPxM2-NRtvk
# ['ジュエーメ', 39.44816303, 140.5056142]
# yes
# ジュエーメ
# ChIJG4Am7ZWgj18Ri7GnIUip-uk
# ['ル・ヴェール', 39.71312833, 140.1205483]
# yes
# ＢＡＲル・ヴェール
# ChIJodJw3-vCj18RWdWiqifbsKc
# ['鮨駒', 39.38945472, 140.0511056]
# yes
# 鮨駒
# ChIJPbIkR2JSjl8R9ktwi5lr6-Q
# ['天駒', 39.71094361, 140.11931940000002]
# yes
# 鮨天駒
# ChIJtTwjKu_Cj18RNTzUFBz505k
# ['ん。', 39.70948472, 140.1224683]
# yes
# couldn't get
# couldn't get
# ['鳥好', 39.71264583, 140.1298928]
# yes
# 炭火焼 鳥好
# ChIJvd_FLe3Cj18RP8nMvMkx4qU
# ['料亭\u3000濱乃家 本店', 39.71316472, 140.1201364]
# yes
# 料亭 濱乃家
# ChIJffJDYunCj18REO6rgq3na2w
# ['エッサンス', 39.71460694, 140.1379344]
# yes
# エッサンス
# ChIJB5395ZHCj18RMFYHm65y8Vk
# ['和食 なり', 39.71197306, 140.1311564]
# yes
# 和食 なり
# ChIJr8i5Te3Cj18Rzo8gRYESr3Q
# ['天ぷら\u3000酒菜\u3000醍醐', 39.71185429, 140.11836540000002]
# yes
# 天ぷら 酒菜 醍醐
# ChIJq2NzIenCj18RY2vpeVerJ4k
# ['串揚げ 串の実', 39.71185159, 140.1183682]
# yes
# 串揚げ串の実
# ChIJq2NzIenCj18Rv-Pje25qibE
# ['Lady', 39.7138675, 140.12079419999998]
# yes
# レディ
# ChIJhYPPzuvCj18Rq58qE8q-R8Y
# ['割烹 美さわ', 40.26576491, 140.56365569999997]
# yes
# 割烹 美さわ
# ChIJlyPGySrEml8Rju0B5DJQc18
# ['自家製麺 伊藤', 39.59126833, 140.5822111]
# yes
# 自家製麺伊藤
# ChIJgyZMZ1maj18RB9GujcXpz24
# ['そば打ち幸甚', 39.44271944, 140.4842486]
# yes
# そば打ち幸甚
# ChIJ1Y-I87Wgj18RzOnwHFgUK0I
# ['いな穂', 40.22831028, 140.37474640000002]
# yes
# いな穂
# ChIJydIMxTS5ml8RxSUYA09pyL4
# ['徳', 39.71228111, 140.1202092]
# yes
# couldn't get
# couldn't get
# ['とぶ', 39.31182833, 140.57139719999998]
# yes
# 鳥料理 とぶ
# ChIJzVKfV-MPj18RmdUSZmbNiJI
# ['一心寿し', 39.720602500000005, 140.13665890000001]
# yes
# 一心寿し
# ChIJBwn-zJnCj18R5_5T8gNmUmA
# ['腰掛庵', 38.34710611, 140.37596969999998]
# yes
# 腰掛庵
# ChIJPaHbmpfFi18RtmEmfhBlUdI
# ['九兵衛旅館', 38.68973611, 139.77309440000002]
# yes
# 九兵衛旅館
# ChIJuyUcyMIRjF8RXOhME1SNPFc
# ['いしやま寿司', 38.23909722, 140.33943689999998]
# yes
# いしやま寿司
# ChIJA7y_1eO1i18RwbAPGr4rySo
# ['旅館 琴平荘 中華そば処', 38.70329417, 139.6653556]
# yes
# 琴平荘
# ChIJnW2egI4TjF8Rlz4OIDy4YJ8
# ['こい勢', 38.9172675, 139.8460361]
# yes
# こい勢
# ChIJ_Ur8cmCejl8RkHaOs_ctFp8
# ['赤湯ラーメン 龍上海 赤湯本店', 38.04739694, 140.16662250000002]
# yes
# 龍上海 赤湯本店
# ChIJ1dRZE75Vil8Rvnx-rfmcN4k
# ['山形座 瀧波', 38.04527528, 140.1738497]
# yes
# 山形座 瀧波 YAMAGATA THE TAKINAMI
# ChIJhS8C7cBVil8RD6a4eavoH3A
# ['アル・ケッチァーノ', 38.69523944, 139.8371236]
# yes
# アル・ケッチァーノ
# ChIJfdlgRegPjF8R2Gi-NCPRyEE
# ['登起波', 37.91631393, 140.1123135]
# yes
# couldn't get
# couldn't get
# ['出羽屋', 38.42762417, 140.1370072]
# yes
# 山菜料理 出羽屋
# ChIJXYZMn7rri18R3P8d1c7ewxI
# ['あきよし', 38.24521, 140.3328228]
# yes
# あきよし
# ChIJB2h66A62i18REs2-2j68wUA
# ['日本の宿 古窯', 38.14502528, 140.2647475]
# yes
# 日本の宿 古窯
# ChIJuQ5cS7Cyi18RRYGLAA-sHLc
# ['御りょうり屋 伊藤', 38.25076639, 140.3472511]
# yes
# 御りょうり屋 伊藤
# ChIJL91w8_3Ji18RcEcQB_gCGik
# ['花明りの宿 月の池', 38.15724722, 140.2796139]
# yes
# 花明りの宿 月の池
# ChIJu4d_etuyi18R29bhSwRULoI
# ['酒菜一', 38.24558556, 140.3330997]
# yes
# 酒菜一
# ChIJl-Q84g62i18RhOHPzE0sIZg
# ['はたごの心 橋本屋', 38.14524389, 140.2663089]
# yes
# はたごの心 橋本屋
# ChIJ8ZECB7Gyi18RJ9HxiEERyt8
# ['御宿かわせみ', 37.81999333, 140.4569719]
# yes
# 御宿かわせみ
# ChIJxya5NKmJil8R6kjwYaUa9Q0
# ['小判寿司', 37.02499444, 140.3926278]
# yes
# 小判寿司
# ChIJ29nOcCq1IWAR_eiOzoCJSZM
# ['らん亭～ 美日庵', 37.41947056, 140.3741908]
# yes
# 八山田らん亭美日庵
# ChIJD8b81x9tIGAR-3pbKAuWYSI
# ['鮨 いとう', 37.05174083, 140.89437560000002]
# yes
# 鮨いとう
# ChIJ-bMKyPkQIWARZECzHcGGB1Q
# ['とら食堂', 37.10964056, 140.2636994]
# yes
# とら食堂
# ChIJj0GGYbEwIGARbRbaU51iA5A
# ['伊達屋', 37.78132194, 140.44335859999998]
# yes
# 伊達屋
# ChIJv1JtqFKPil8RwfJW1SJjs78
# ['寿司割烹 魚紋', 37.39475639, 140.3892633]
# yes
# 寿司割烹 魚紋
# ChIJq6rlw4ZsIGAR_oZMZvlgmjE
# ['粋・丸新', 37.39838778, 140.3816789]
# yes
# 丸新
# ChIJj33-z4ZsIGARmj7sUw5DcMA
# ['自家製麺 うろた', 37.75285444, 140.4708889]
# yes
# 自家製麺うろた
# ChIJgwIc9c6Fil8RrOrVGGsrHO0
# ['鮨 来多老', 37.39682944, 140.3572189]
# yes
# 鮨 来多老
# ChIJxX-DgslsIGARTUrmk_4hGVA
# ['おとぎの宿米屋', 37.26071028, 140.3312658]
# yes
# おとぎの宿米屋
# ChIJN2X6Zp8_IGARf5YNDtKBpzA
# ['こふく', 37.39337551, 140.38895480000002]
# yes
# こふく
# ChIJm5wASoFsIGARAKKQlHncXFc
# ['いろりの宿 芦名', 37.47251917, 139.96633559999998]
# yes
# いろりの宿 芦名
# ChIJfdQ7nN9U9V8RZcicfrifzf0
# ['天ぷら 佐久間', 37.41450889, 140.3687783]
# yes
# 天ぷら佐久間
# ChIJI2px5d5sIGARayJsfC5lpO4
# ['あ吽', 37.39626222, 140.3877678]
# yes
# あ吽
# ChIJi7BXdoZsIGARSw8U79n6R0w
# ['仁亭', 37.38842361, 140.36526469999998]
# yes
# 仁亭 (じんてい)
# ChIJV2OGzqRsIGARe9nYXQOTdQo
# ['タロカフェ', 37.53052, 140.1125858]
# yes
# TARO CAFE
# ChIJnSmJjlWoil8ROhzZia2jz7k
# ['鶏けん', 37.75149611, 140.4659781]
# yes
# 鶏けん
# ChIJ9WvhGsmFil8R0RbSH8DzXkA
# ['ハッピーベリー', 37.18384417, 140.33703530000003]
# yes
# ハッピーベリー
# ChIJ_U6J6WM4IGARZ1YDXb00Rn8
# ['わき水', 37.42390417, 140.34458030000002]
# yes
# わき水
# ChIJQwxrpckSIGARCHn5J8Rukfo
# ['蕎麦彩膳 隆仙坊', 37.39709028, 140.3846753]
# yes
# 蕎麦彩膳 隆仙坊
# ChIJVVDLhI9sIGARh7OIOC23RBs
# ['食堂なまえ', 37.64278444, 139.87645859999998]
# yes
# 食堂なまえ
# ChIJC3S5rJK2il8RYLuj6pP-C6E
# ['籠太', 37.49192778, 139.93580830000002]
# yes
# 籠太
# ChIJGd8iR6FU9V8R7iID0jjw4CA
# ['もうもう亭', 37.40353333, 140.36252969999998]
# yes
# もうもう亭
# ChIJH9v1d8VsIGARt7TLLGFx6fQ
# ['しおや', 37.75128778, 140.4718806]
# yes
# couldn't get
# couldn't get
# ['味心 すず木', 37.40357778, 140.362085]
# yes
# 味心すず木
# ChIJaf-XfsVsIGARQ8kftcLq7_A
# ['くつろぎ宿 千代滝', 37.47592722, 139.96588]
# yes
# くつろぎ宿 千代滝
# ChIJn3b44ttU9V8RRII1akyhgnA
# ['坂内食堂', 37.64804889, 139.8767214]
# yes
# 坂内食堂 喜多方本店
# ChIJ3_f6q_a2il8RyTaCi3tMOak
# ['正月屋', 37.4022175, 140.3598206]
# yes
# 支那そば 正月屋
# ChIJOREGBs9sIGARDjBXB1iqp5M
# ['くをん', 37.75011722, 140.46118]
# yes
# くをん
# ChIJF5eRzLeFil8RmQm-9o0Jh20
# ['喜一', 37.64428694, 139.8855222]
# yes
# 喜一
# ChIJxZE18u62il8Ri_klTLvmRcY
# ['遊里庵', 37.7907749, 140.44674799999999]
# yes
# 遊里庵
# ChIJpzHTGbiIil8RknEMI_LY38M
# ['磯陣', 37.39586361, 140.38990780000003]
# yes
# 磯陣
# ChIJ3a-1_IZsIGARdysIwqjeISE
# ['慈久庵', 36.67943111, 140.473775]
# yes
# 慈久庵
# ChIJk2aPVyCRIWARIoClcUwumbU
# ['煮干中華ソバ イチカワ', 36.09510611, 140.1116036]
# yes
# 煮干中華ソバ イチカワ
# ChIJv-jK1gwMImARUFPXaNxVENg
# ['鬼怒川 竹やぶ', 35.96246028, 139.95528059999998]
# yes
# 鬼怒川 竹やぶ
# ChIJ_YoctUafGGARTSpza2LKBsI
# ['コジコジ', 36.39767111, 140.4428956]
# yes
# コジコジ
# ChIJue_DC68mImARi9pfaJaeOR8
# ['はりけんラーメン', 36.11601556, 140.1170208]
# yes
# はりけんラーメン 本店
# ChIJjyDonacOImARcbUANxWll4M
# ['らぁめん 喜乃壺', 36.02939167, 140.14414169999998]
# yes
# らぁめん 喜乃壺
# ChIJ2XM35x1zImARXarMWKBBbS4
# ['鯨荘 塩町館', 36.53763861, 140.52614440000002]
# yes
# 塩町館
# ChIJ9zsn5i2GIWARjzC2XFibNrQ
# ['ぬりや 大通り店', 36.37597444, 140.46520890000002]
# yes
# ぬりや 泉町店
# ChIJUXpOX08kImARllmERzXyAX0
# ['喜元門 研究学園駅前店', 36.08047083, 140.0844656]
# yes
# 喜元門 本店
# ChIJbXotk5ULImAR_qHvmFCJOYo
# ['レストラン オオツ', 36.36061556, 140.47796169999998]
# yes
# オオツ（ＯＨＴＳＵ）
# ChIJL2_u4gIlImAR4i8BirPqp6A
# ['木挽庵', 36.411825, 140.5326031]
# yes
# 茨城そば処 木挽庵
# ChIJWzMZWUEvImAR10KjheT8T2A
# ['拉麺人生', 36.02169944, 139.9851394]
# yes
# 人生 拉麺
# ChIJ6wIrBlSgGGARDaymDYUgaPo
# ['手打ちそば 夫婦庵', 36.07289361, 140.1782458]
# yes
# 夫婦庵
# ChIJ296hrVENImARutez6UBmG_I
# ['牛新 東海店', 36.46248944, 140.5753258]
# yes
# 牛新 東海店
# ChIJsw9BlhUpImARyZ6c__1CtBI
# ['熊田家', 35.99758861, 139.9822869]
# yes
# 家系ラーメン 熊田家
# ChIJcfmktdKhGGARdqRLbu3KPFM
# ['はまぐり屋', 36.38591528, 140.6063567]
# yes
# はまぐり屋
# ChIJ7TpqaPktImARNUlh_CQ0H8s
# ['中川楼', 36.37735344, 140.4637623]
# yes
# 中川楼
# ChIJ6zvcakYkImARDJL3__DQ_zQ
# ['麺屋 壱心', 35.9173425, 140.15051640000001]
# yes
# 麺屋壱心
# ChIJE7dlVXtwImARSDZ9g_MaJr8
# ['お宿 浜田館', 36.38055556, 140.6219139]
# yes
# オーシャンフロント お宿 Hamadakan
# ChIJo1Lv6HIyImARn5ytwA5jnac
# ['ちゅう心', 36.31090111, 140.5742847]
# yes
# ちゅう心
# ChIJ3S5nmD4xImARsZQUFkPxm2M
# ['蕎麦処 みかわ', 36.39013972, 140.4607325]
# yes
# 蕎麦処みかわ
# ChIJ51eulyQkImARg_JJFIex_oQ
# ['はざま', 35.90918778, 140.0365758]
# yes
# 中華蕎麦はざま
# ChIJIx0tCTp2ImARyUavSY4uPOE
# ['川蝉', 36.558215000000004, 139.89537719999998]
# yes
# 川蝉
# ChIJ4QsisqFnH2ARf56pLJOTDXE
# ['青竹手打ラーメン 日向屋', 36.3084025, 139.55215280000002]
# yes
# 日向屋
# ChIJ14o5rmo7H2ARswpJ3YeSVyM
# ['青竹手打ちラーメン 大和', 36.2958475, 139.59297719999998]
# yes
# 佐野青竹手打ちラーメン 大和
# ChIJu7rtcTg6H2ARx6dy3GJ4qr8
# ['焼肉グレート 駅前店', 36.55810091, 139.90066069999997]
# yes
# 焼肉グレート 駅前店
# ChIJB3hTP3VnH2AR6BlUETcV3zs
# ['らーめん大金', 36.30465338, 139.5672719]
# yes
# らーめん大金
# ChIJuReoBwY7H2ARPKU-5835Rtk
# ['三たてそば 長畑庵', 36.67076694, 139.7001486]
# yes
# 三たてそば 長畑庵
# ChIJPVo-cFFzH2ARV834Mchlu20
# ['蕎遊庵', 36.33546694, 139.44798169999999]
# yes
# 蕎遊庵
# ChIJNQiIR4ohH2AR0vR5bEt-IR0
# ['鳥常本店', 36.33020556, 139.4562194]
# yes
# 鳥常 本店
# ChIJsynZ3y4iH2ARxZ8PAVERGGk
# ['麺屋 ようすけ', 36.28790222, 139.56729919999998]
# yes
# 麺屋 ようすけ
# ChIJlyAQ8_k6H2AR3Rw0WV9tR4g
# ['手打ち\u3000焔', 36.95893037, 140.03232169999998]
# yes
# 手打 焔
# ChIJf1wgfvcpIGAR8KpVDri9ZfA
# ['焼肉グレート', 36.55885861, 139.88694750000002]
# yes
# couldn't get
# couldn't get
# ['バー・シャモニー', 36.55697083, 139.88658610000002]
# yes
# バー・シャモニー
# ChIJleG4g7xnH2ARd4feG2K4CCs
# ['割烹旅館 湯の花荘', 36.96371806, 139.8298347]
# yes
# 割烹旅館 湯の花荘
# ChIJsSUjs2mQH2AR_GK-8Rj4VC4
# ['山水閣 別邸 回', 37.08508692, 140.01479809999998]
# yes
# 那須別邸 回
# ChIJ7Tme0-SJH2AR3HmagdHhZWw
# ['胡桃亭', 36.84353583, 139.98218280000003]
# yes
# 胡桃亭
# ChIJ3-tGXKB_H2ARMYuViung4rM
# ['麺\u3000藏藏', 36.52746056, 139.9960178]
# yes
# 麺藏藏
# ChIJc2YToRZfH2ARDT1S2bebA7o
# ['ラーメン二郎 栃木街道店', 36.41979862, 139.7980996]
# yes
# ラーメン二郎 栃木街道店
# ChIJ3R8zF3NEH2ARWnvPznBuYgk
# ['魚登久', 36.72083797, 139.6888835]
# yes
# 魚登久
# ChIJ1RopnM4KH2AR5CqbYHP_tSc
# ['鮨おばな', 36.24288639, 139.5413186]
# yes
# 鮨おばな
# ChIJxaPKiQUwH2ARKq5OoeKuJuI
# ['鮨\u3000恵三', 36.23621613, 139.5370234]
# yes
# 鮨恵三
# ChIJhwK_cBswH2ARADRp8Ll0KOU
# ['らーめん芝浜', 36.40087028, 139.3199269]
# yes
# らーめん 芝浜
# ChIJ0dCM5LDjHmARtYkvjzjsq8A
# ['龢', 36.39095972, 139.07516]
# yes
# 龢nagi
# ChIJ81591gTzHmARaaiz_aUzv6Y
# ['支那そば なかじま', 36.33693694, 139.0117178]
# yes
# 支那そば なかじま
# ChIJQSLyTHKNHmAROzSXI8LS4Wk
# ['凡味 そばきり', 36.34728194, 139.0101156]
# yes
# そばきり
# ChIJk2usQA-NHmAR6isZbTzuDxM
# ['すし処 さいとう', 36.42382722, 139.29875249999998]
# yes
# すし処 さいとう
# ChIJMRcLwkLjHmARICoG6PooWFI
# ['手打ちそば\u3000舞鶴', 36.32146214, 139.01242380000002]
# yes
# 手打ちそば 舞鶴
# ChIJm1m8lIKSHmAR4dUZdJz5MbE
# ['和人良', 36.32100767, 139.0082385]
# yes
# 旬彩和人良
# ChIJD2obGn6NHmARd8mX9MPnxGA
# ['もっこす', 36.32056444, 139.0620642]
# yes
# もっこす
# ChIJxSZ1hz7tHmARiC9hxE_9wbA
# ['割鮮 たけ花', 36.38728861, 139.0781861]
# yes
# 割鮮 たけ花
# ChIJ__-TRQLzHmARPy33N_ASGRY
# ['古久家', 36.38553333, 139.0746639]
# yes
# couldn't get
# couldn't get
# ['蒼屋', 36.33067528, 139.0121456]
# yes
# 蒼屋
# ChIJ-9imhXqNHmARhch649hXkT0
# ['中国料理 竜苑', 36.43716278, 139.02304109999997]
# yes
# 中国料理 竜苑
# ChIJr4EfXuCKHmARwoVmm-KQKuw
# ['炭こう', 36.311567499999995, 139.0162881]
# yes
# 炭こう
# ChIJFZCko5GSHmARfvd3nKp4A7Q
# ['おさかな亭', 36.28008308, 139.1950181]
# yes
# おさかな亭
# ChIJoc9-XmXoHmARy4YyqtraKs4
# ['だるま大使 本店', 36.34437, 138.9595061]
# yes
# 豚骨ラーメン だるま大使 本店
# ChIJQ3yWQoOOHmARMhe0r_ErGCk
# ['かつサンド工房 PANTON', 36.35873167, 139.0259117]
# yes
# かつサンド工房 PANTON
# ChIJHesuOiKNHmARhnqHHIrhlTM
# ['風人', 36.34260972, 139.0231908]
# yes
# couldn't get
# couldn't get
# ['くろ松', 36.32416931, 139.0058858]
# yes
# くろ松
# ChIJVVUJzXiNHmAR8cMBu5ej7fQ
# ['つけ麺\u3000弥七', 36.225840000000005, 139.5653639]
# yes
# つけ麺 弥七
# ChIJKfLpwFMwH2ARF63lkcU2Qdc
# ['別邸 仙寿庵', 36.78262361, 138.95977309999998]
# yes
# 別邸 仙寿庵
# ChIJYYiWRIkTHmARWmZDqfqQQhM
# ['清仁軒', 36.32763556, 139.00703280000002]
# yes
# 清仁軒
# ChIJAf7JtnmNHmARm-Y8fNzHcx4
# ['創和 織部', 36.38787306, 139.0730303]
# yes
# 創和 織部
# ChIJl93lnRzzHmAR5y7bsjE_cHg
# ['鮨 猪股', 35.801432500000004, 139.7281575]
# yes
# 鮨 猪股
# ChIJMQPWAnGTGGARK9DuNNJdWg4
# ['中華そば 四つ葉', 35.96503528, 139.4721342]
# yes
# 中華そば 四つ葉
# ChIJe2M7MODQGGAR4gRw120Yd9E
# ['慈げん', 36.14364427, 139.3855]
# yes
# couldn't get
# couldn't get
# ['イタリアン オット', 35.78477, 139.47510669999997]
# yes
# 所沢 イタリアン オット
# ChIJx_xrHYrdGGAR0H-SWQelo9Q
# ['鰻 むさし乃', 35.85403906, 139.663344]
# yes
# 鰻むさし乃
# ChIJG1L-PpvqGGAR3eWUJ1T60gY
# ['うなぎ屋酒坊・画荘 越後屋', 35.7944375, 139.43957749999998]
# yes
# うなぎ屋酒坊・画荘 越後屋
# ChIJV2PGKW7eGGAR53zebIY_FAQ
# ['中華そば よしかわ', 35.99250944, 139.58955780000002]
# yes
# 中華そば よしかわ
# ChIJJ7OVq2vPGGARZzRCzdRRvhA
# ['寿製麺 よしかわ', 35.87283083, 139.47764719999998]
# yes
# 寿製麺よしかわ
# ChIJnezM2JbbGGARj4mvicFr9Lo
# ['よし佳', 35.85658194, 139.66311169999997]
# yes
# よし佳 寿司
# ChIJ87MMSIPqGGARVOoTfYNCD3A
# ['シンフラ', 35.81917, 139.5680392]
# yes
# シンフラ
# ChIJ4SYgyivoGGARkPb-PJKOeNA
# ['ぜんや', 35.79565833, 139.5598086]
# yes
# ぜんや
# ChIJnUnVYkboGGAR6jq5eYHRSYI
# ['弥助鮨', 36.23644611, 139.18993419999998]
# yes
# 弥助鮨
# ChIJiyjPor7CHmARvQaAJ3HGclY
# ['アカシエ', 35.85638, 139.65003969999998]
# yes
# アカシエ
# ChIJfZnVu9XBGGARSZ_3gGN-C0I
# ['京亭', 36.10861222, 139.1986125]
# yes
# 京亭
# ChIJUXmxgPjPHmARQ7teEaDQNKI
# ['negombo33', 35.78431361, 139.4645717]
# yes
# negombo33
# ChIJo5vlrPbdGGARGlq8wu9TfrU
# ['くら川', 35.85453333, 139.65984419999998]
# yes
# くら川
# ChIJs2SZ9IPqGGARcOga36ttZp8
# ['阿左美冷蔵 金崎本店', 36.08124861, 139.1154636]
# yes
# 阿左美冷蔵 金崎本店
# ChIJs3UQ1ATGHmARYl2NIF_Is3M
# ['狼煙', 35.92080667, 139.62537890000002]
# yes
# 狼煙
# ChIJw8cdU7LGGGARUtHfIal3_2c
# ['和風楽麺 四代目 ひのでや', 35.97810139, 139.65522919999998]
# yes
# 和風楽麺 四代目 ひのでや
# ChIJL1ld4rLHGGARNI6Lic7STxk
# ['シャンドワゾー', 35.80181363, 139.7246995]
# yes
# シャンドワゾー
# ChIJvdZl42-TGGARqj6uveJHs0I
# ['喰心-meat Dining-', 35.90170417, 139.6303144]
# yes
# 喰心
# ChIJByA7f2rBGGARWA7nz3GHfO8
# ['メゾン ドゥ アッシュ', 35.97938056, 139.57170580000002]
# yes
# メゾンドゥアッシュ
# ChIJRyveW53PGGARnnKqQcAtECE
# ['うなぎ 浜名', 35.85786917, 139.6546894]
# yes
# うなぎ浜名
# ChIJbdSAvyrAGGAR1xZNbi-x1bw
# ['鮨ふく', 35.85493108, 139.6581124]
# yes
# 鮨ふく
# ChIJyclfZoHqGGARoW8we909YUc
# ['酒場わたなべ', 35.80194583, 139.72058]
# yes
# 酒場わたなべ
# ChIJHXIe6GWTGGAR7gn95YLwnEU
# ['狭山 翁', 35.78324473, 139.4426776]
# yes
# 狭山 翁
# ChIJu2Mo8g7eGGARw0_Ew9xZVGs
# ['つけめん\u3000さなだ', 35.84968139, 139.8860775]
# yes
# つけめん さなだ
# ChIJbdCv2ESaGGARsVWv1uQp0BA
# ['麺処 有彩', 35.81280778, 139.7064292]
# yes
# 麺処・有彩
# ChIJN8LHOqWUGGARdPlRNnhGlDk
# ['麺堂稲葉Kuki Style', 36.07180361, 139.71086330000003]
# yes
# 麺堂 稲葉ｋｕｋｉｓｔｙｌｅ
# ChIJ2zZP5zm2GGARUp0DIK5h3b0
# ['煮干乱舞', 35.94563583, 139.7730289]
# yes
# 煮干乱舞
# ChIJ_-DI14O-GGAR4eXJhNsXyKo
# ['Handicraft Works', 35.80670278, 139.859655]
# yes
# ハンディクラフト ワークス
# ChIJTYhvz6CaGGARo1T_nNE6MdU
# ['こむぎ', 35.88717167, 139.7936258]
# yes
# こむぎ
# ChIJ6XQL_GiWGGARqPe_8ytbWRA
# ['みや', 35.77943222, 139.47481059999998]
# yes
# みや
# ChIJvftHU2HnGGARtFQXinO3aIY
# ['小川菊', 35.917472499999995, 139.4864672]
# yes
# うなぎ 小川菊
# ChIJ61sUvGDaGGARWcr55Cw53VQ
# ['麺屋時茂', 35.82350318, 139.806741]
# yes
# 麺屋時茂
# ChIJUV16fReRGGAR-lyk89Y3Wrk
# ['麺屋 桐龍', 35.86438389, 139.75568940000002]
# yes
# 麺屋 桐龍
# ChIJQRNuCsqVGGARNsP8hXvzcOM
# ['支那そば心麺', 36.02561972, 139.5411767]
# yes
# 支那そば心麺
# ChIJaWT4BwbOGGARkYlkikHNe6I
# ['らーめん\u3000かねかつ', 35.79499389, 139.7152989]
# yes
# らーめん かねかつ
# ChIJy95w5mmTGGARgU0JkKQBANs
# ['自家製麺 竜葵', 35.80051028, 139.7218686]
# yes
# 自家製麺 竜葵
# ChIJzz7bcW-TGGARJnIFDv2cSHY
# ['寛～くつろぎ～', 35.84697444, 139.5386361]
# yes
# 寛～くつろぎ～
# ChIJzZh60inDGGARZGDav0UDd1k
# ['㐂九八', 35.801952500000006, 139.4838744]
# yes
# 㐂九八 ～ garage ～
# ChIJq6o6ZJndGGARgTS17AZ_Icc
# ['讃岐うどん 條辺', 35.87176444, 139.5161542]
# yes
# 讃岐うどん 條辺
# ChIJO51QKqfcGGARQUSvmPZLXX8
# ['次念序', 36.05113472, 139.51354719999998]
# yes
# 次念序
# ChIJizXFK2HSGGARkLtVK1OYsNg
# ['中華そば 幻六', 35.81080639, 139.5895044]
# yes
# 中華そば 幻六
# ChIJF4ucC7_pGGARxKevSnNa4fo
# ['柳麺 呉田', 35.86755806, 139.6503503]
# yes
# 柳麺 呉田 goden
# ChIJV1ZQXczBGGARO4Mq9aVT0kM
# ['アングランパ', 35.89375853, 139.6353806]
# yes
# アングランパ
# ChIJq6oOdA3BGGARs4kQ6m0ieAE
# ['手打うどん 長谷沼', 35.91249806, 139.4847261]
# yes
# 手打うどん 長谷沼
# ChIJD4_xF1zaGGAR4oPYluSRn4Q
# ['オランダ軒', 35.95857694, 139.7186983]
# yes
# オランダ軒
# ChIJ-Uvjl8u4GGARrKldD-lxp8U
# ['cimai', 36.07345324, 139.7329462]
# yes
# cimai pain
# ChIJqbi2AFW2GGARl-dqWOIgOeY
# ['天徳', 35.80784944, 139.87655969999997]
# yes
# 天徳
# ChIJG4KRj7eaGGARBjKEZVON_ZM
# ['たかおか', 35.60550917, 140.1124747]
# yes
# たかおか
# ChIJO-GdZa-EImARAFcD70u1WuA
# ['ウシマル', 35.61545694, 140.4781794]
# yes
# couldn't get
# couldn't get
# ['寿司栄', 35.61267389, 140.13380780000003]
# yes
# 寿司栄
# ChIJu0g2Fc6EImAR-ZSuvXn7seY
# ['中華蕎麦 とみ田', 35.77856833, 139.9041636]
# yes
# 中華蕎麦とみ田
# ChIJYXI0-PuEGGARXIOhhARUK5A
# ['トラットリア・アルベロ', 35.62847556, 140.13594609999998]
# yes
# トラットリア・アルベロ
# ChIJT6b2zOeEImARJBgZZrM-J4M
# ["zoe's", 35.86061861, 139.9775967]
# yes
# ゾエズ（ｚｏｅ’ｓ）
# ChIJSX_2GuGcGGAR1YU-7ngTUvY
# ['クラブ33', 35.63105111, 139.88285109999998]
# yes
# couldn't get
# couldn't get
# ['リストランテ サクラ', 35.60613611, 140.1296908]
# yes
# リストランテさくら
# ChIJAe4PWcuEImAR9iCDDGwZigg
# ['ル・クープル', 35.85824722, 139.9785814]
# yes
# ル・クープル
# ChIJAw2O1d-cGGARALoQa_MDKwg
# ['小暮や', 35.86918556, 140.0408531]
# yes
# 炭火焼鰻 小暮や
# ChIJy3uUnfR3ImAR6Kt0GMIjD10
# ['バックシュトゥーベ ツオップ', 35.82118941, 139.9509964]
# yes
# Zopf
# ChIJH710xE-DGGARaXBEnn0Wl1A
# ['三日月氷菓店', 35.85738611, 139.9760264]
# yes
# 三日月氷菓店
# ChIJ3fqyq-CcGGAR41aGrQn_LHs
# ['京料理かねき', 35.8479325, 139.901414]
# yes
# 京料理かねき
# ChIJiyyl_6qbGGARgeLoTKwcLNY
# ['フランス料理 ル・クール', 35.60567139, 140.1133436]
# yes
# フランス料理 ル・クール Le Coeur
# ChIJIUFSUrKEImARcRNU8pJuiuQ
# ['流山 すず季', 35.88091556, 139.9150411]
# yes
# 更科すず季
# ChIJpZb2iNybGGAR_tizarY_tv0
# ['味処 むさし野', 35.7796375, 139.9214525]
# yes
# 味処 むさし野
# ChIJSyX_MGCEGGARBCukVbJeqZw
# ['ル・パティシエ ヨコヤマ 谷津店', 35.68318167, 140.00760469999997]
# yes
# ル・パティシエ・ヨコヤマ 谷津店
# ChIJXW1kmZN_GGARfi7qyEZRMQ4
# ['濃麺 海月', 35.61253444, 140.1243772]
# yes
# 濃麺 海月
# ChIJhV4dAriEImARKAQ6EZSa7AU
# ['零一弐三', 35.70343278, 139.98508859999998]
# yes
# couldn't get
# couldn't get
# ['プレゼンテ スギ', 35.7093525, 140.2453406]
# yes
# プレゼンテ スギ
# ChIJqYAjediOImAR0lRZChUAqUE
# ['ル・パティシエ ヨコヤマ 大久保店', 35.68336139, 140.04703469999998]
# yes
# ル・パティシエ・ヨコヤマ 大久保店
# ChIJwfUJUkuAImARMvJnyokzKLo
# ['竹やぶ 柏本店', 35.862675, 139.99106809999998]
# yes
# 竹やぶ
# ChIJSzt-rSKdGGAR0nDOgINdfOE
# ['ロクザ', 35.01956833, 139.85728830000002]
# yes
# ROKUZA
# ChIJxZgDhoD3F2ARspfD0ff6F-8
# ['杉田家 千葉店', 35.61592417, 140.1346739]
# yes
# ラーメン杉田家 千葉店
# ChIJBZ6q5s-EImARMsKXTGoEw8w
# ['駿河屋', 35.78138861, 140.32055669999997]
# yes
# couldn't get
# couldn't get
# ['今久', 35.71311194, 140.58857690000002]
# yes
# 今久焼肉
# ChIJEQECOh3kImARonZElE68CUE
# ['レタンプリュス 本店', 35.87003306, 139.9315358]
# yes
# パティスリー レ・タン・プリュス
# ChIJSWas2JGbGGAR1llv82DkTaA
# ['芳野屋', 35.85441389, 139.97964309999998]
# yes
# 芳野屋
# ChIJNyUWNt-cGGARXKto0KS6Z44
# ['お料理なかき', 35.85529889, 139.97875109999998]
# yes
# なかき
# ChIJX_2cG9-cGGARvpG8O4RrB2o
# ['兎に角 松戸店', 35.78259917, 139.9050097]
# yes
# 兎に角 松戸店
# ChIJsaS1TvuEGGARsdVk1mZ2xfc
# ['ルーエプラッツ ツオップ', 35.82115696, 139.9510159]
# yes
# Zopf
# ChIJH710xE-DGGARaXBEnn0Wl1A
# ['手造りそば 打墨庵 加瀬', 35.1447125, 140.07404169999998]
# yes
# 打墨庵 加瀬
# ChIJl_-98DGrImARZODYIstlttI
# ['文菜華', 35.85537551, 139.97887219999998]
# yes
# 中国料理文菜華
# ChIJFavbGt-cGGARiyOB2gGQpN8
# ['The Noodles & Saloon Kiriya', 35.87867833, 139.9196928]
# yes
# The Noodles & Saloon Ｋｉｒｉｙａ
# ChIJ__9YKeibGGAR_hH-pv4yFIU
# ['小料理野本', 35.609542499999996, 140.1213519]
# yes
# 小料理野本
# ChIJnf-BELeEImARHX80Y0YalXs
# ['ちばから', 35.49839444, 140.11576110000001]
# yes
# ちばから
# ChIJ7TtatTqZImARR-mvEtgHYXA
# ['うなぎ割烹山田', 35.88914194, 140.50064440000003]
# yes
# 山田
# ChIJL7pbpej3ImARwGHw_bPshOw
# ['ら～めん 寺子屋 麺倶楽部', 35.86214556, 140.0450142]
# yes
# らーめん 寺子屋 麺倶楽部
# ChIJidpcgiF4ImARjwau4BQe-NM
# ['とんかつ瓢', 35.85697889, 139.9710769]
# yes
# とんかつ 瓢 ～ひさご～
# ChIJX0MK2uecGGAR_iEOlarV0A8
# ['ラ・サレッタ', 35.43550556, 140.3926172]
# yes
# 千葉県白子町の隠れ家イタリアン ラ・サレッタ
# ChIJyw-QsrTHImARPhCGhCprYAc
# ['テイル・オコック', 35.78059861, 139.9045608]
# yes
# テイル・オコック
# ChIJRdNEePuEGGARuHhJtn0BTyE
# ['う奈ぎ道場', 35.80133889, 139.9066603]
# yes
# う奈ぎ道場
# ChIJU346iNqEGGARk3jfgyxPp_I
# ['とら食堂 松戸分店', 35.77300583, 139.9610603]
# yes
# とら食堂 松戸分店
# ChIJX4wyA8KDGGAR4teeAo3ENJ8
# ['人舟', 35.41503556, 140.39524939999998]
# yes
# 人舟
# ChIJhaKaiirGImAR-V4c0BhgGeM
# ['割烹\u3000中むら', 35.14455667, 140.3172064]
# yes
# 割烹中むら
# ChIJAQDP4phJPWARbuthn5QJlyM
# ['Vv', 35.65065639, 140.0548461]
# yes
# Vv
# ChIJ_6ubooeBImARiEjHNlyNiBw
# ['銀寿司', 35.57538807, 140.14448869999998]
# yes
# 銀寿司
# ChIJa1EDFgCbImARg8mvZ4voFEM
# ['塩梅', 35.86100278, 139.9698531]
# yes
# とんかつビフテキ 塩梅
# ChIJAQBEbu-cGGARe6h7PlXOSJ4
# ['つむぎや', 35.85962889, 139.9712494]
# yes
# couldn't get
# couldn't get
# ['ゴッサム', 35.60257, 140.1176169]
# yes
# couldn't get
# couldn't get
# ['こみや', 35.69760833, 139.9903639]
# yes
# couldn't get
# couldn't get
# ['ラーメンケース ケー', 35.68582026, 140.0522901]
# yes
# couldn't get
# couldn't get
# ['オステリア タナロ', 35.78604528, 139.9044044]
# yes
# オステリア タナロ
# ChIJAQCDc-SEGGARrPcL5ybnlTs
# ['川豊 本店', 35.78015833, 140.3200031]
# yes
# 川豊本店
# ChIJF92A2g-LImARpgZ6h_V8mdM
# ['ラーメン二郎 松戸駅前店', 35.78276806, 139.9024664]
# yes
# ラーメン二郎 松戸駅前店
# ChIJhSYTMeOEGGARKidlaVbayBE
# ['さすけ食堂', 35.16404194, 139.82439309999998]
# yes
# さすけ食堂
# ChIJVc8QBvEaGGARUOZ4hMjNBNo
# ['R-S', 35.81640306, 139.9487744]
# yes
# R's
# ChIJv6GlH1uDGGARsrVLfWjZaXw
# ['麺や 福一', 35.775909999999996, 140.3179822]
# yes
# 麺や福一
# ChIJC0D00g2LImARHDt19__rYBc
# ['Boulangerie Queue', 35.72709917, 140.0637811]
# yes
# Boulangerie Queue
# ChIJ74hSrix-ImAR10E2vvEXDO8
# ['キッチン直', 35.69254361, 139.99552580000002]
# yes
# キッチン直
# ChIJg2Nod9t_GGARDXo4Etyd-XU
# ['山田 別館', 35.89043194, 140.48739080000001]
# yes
# 山田うなぎ店別館
# ChIJGQ-Uvtn3ImARC9MHjrtaK-s
# ['13湯麺', 35.79110997, 139.9853715]
# yes
# 13湯麺
# ChIJGQ-F6EuCGGARaTv5yuxVR3s
# ['八角 本店', 35.60748944, 140.1256631]
# yes
# 八角
# ChIJa5krEsqEImARNMa0Hx-qkek
# ['麺屋 むどう', 35.7946916, 139.9682014]
# yes
# 麺屋 むどう
# ChIJC7hifqaDGGARdI-IozE5Gd0
# ['Il Giglio', 35.85358444, 139.97742140000003]
# yes
# Il Giglio
# ChIJsTIzyd6cGGARmCtmwvc7Rgs
# ['中華ソバ 篤々', 35.71148694, 140.1275011]
# yes
# 中華ソバ 篤々 TOKU-TOKU
# ChIJ0ctrIeGGImARXjnPER4qszc
# ['やたいち', 35.85958556, 139.9715381]
# yes
# やたいち
# ChIJIS9WDuacGGAR9g8QNwCFxhA
# ['舟勝', 35.18566889, 140.3689608]
# yes
# 舟勝
# ChIJwzE4LeE1PWARplDs68JXdcM
# ['ラーメン二郎 京成大久保店', 35.68824611, 140.05277809999998]
# yes
# ラーメン二郎 京成大久保店
# ChIJr7BieFKAImARZUoI7y1ptcM
# ['鶏の骨', 35.77602567, 140.3180545]
# yes
# 鶏の骨
# ChIJC0D00g2LImARKQ9KHW_oYgw
# ['SALONE 2007', 35.43993861, 139.6540072]
# yes
# SALONE 2007 (サローネ ドゥエミッレセッテ)
# ChIJXVZFW-JcGGAR49w-GnIy0FU
# ['美かさ', 35.58458278, 139.5933244]
# yes
# 美かさ
# ChIJYRC0oJL2GGARWXxb37rYmj0
# ['イチリン ハナレ', 35.32245969, 139.5551629]
# yes
# イチリン ハナレ
# ChIJV5XcFb9FGGARzDTjgKhzQRo
# ['ラ・ボッテガ・ゴローザ', 35.16167306, 139.10034219999997]
# yes
# ラ・ボッテガ・ゴローザ
# ChIJvbYx0fO8GWARJTpisgA4ZNE
# ['Variante', 35.61014944, 139.57095780000003]
# yes
# Variante
# ChIJPeqvztfwGGAR4lHl8GvNX5U
# ['横浜うかい亭', 35.51129444, 139.45499719999998]
# yes
# 横浜うかい亭
# ChIJ55yo9dH4GGARFQU0SI8UuZU
# ['里葉亭', 35.44230722, 139.6346117]
# yes
# 里葉亭
# ChIJY9sy4fRcGGARw4iYzfav7KM
# ['なか條', 35.44327861, 139.64068500000002]
# yes
# なか條
# ChIJKeLr1_ZcGGARXEWTp2gPqNA
# ['うなぎ亭 友栄', 35.24004139, 139.1292911]
# yes
# うなぎ 友栄
# ChIJiepaooCkGWARFrH4ZzxMmaw
# ['潟潟ヤ', 35.60098944, 139.61928419999998]
# yes
# 潟潟ヤ
# ChIJVbkwuSP0GGARKLvKEUN8y_w
# ['石葉', 35.14752083, 139.0734936]
# yes
# 石葉(せきよう)
# ChIJI7Yfvgi9GWARMUs6fPYsyAY
# ['日本料理 幸庵', 35.33436028, 139.48804030000002]
# yes
# 幸庵
# ChIJed4kijROGGARqHhSU8WCg9Y
# ['スイーツガーデン ユウジアジキ', 35.55760417, 139.5947975]
# yes
# スイーツガーデン ユウジアジキ
# ChIJC76rKmv2GGAR2k8-EKdqvfk
# ['佛蘭西料理 名古屋', 35.32345917, 139.4704472]
# yes
# 佛蘭西料理 名古屋
# ChIJj0TIBkBOGGARuxid2yjgdvE
# ['ヴィノテカサクラ', 35.44478694, 139.6402639]
# yes
# ヴィノテカサクラ
# ChIJHShf-PZcGGAR9L9JAg6zBc4
# ['ソリス アグリトゥーリズモ', 35.25195861, 139.6082961]
# yes
# SOLIS -Agriturismo-
# ChIJz01cxVVHGGAR0ab7zbN_8Ps
# ['シシリヤ', 35.44283639, 139.6425278]
# yes
# シシリヤ
# ChIJmymAuvBcGGAR3nCeCqOcFes
# ['らぁ麺屋 飯田商店', 35.141347499999995, 139.1128544]
# yes
# らぁ麺屋 飯田商店
# ChIJE7th1xK8GWARQxVxqKFd6S0
# ['ete', 35.31152667, 139.54944]
# yes
# エテ 鎌倉
# ChIJxZHQU-hFGGARMn0gRd-On_s
# ['Arashida', 35.31152861, 139.5494408]
# yes
# スペイン料理とワインの店 arashida
# ChIJxZHQU-hFGGARKY7R7yUD8-E
# ['デュ・ヴァン・ハッシシ', 35.43942833, 139.6463511]
# yes
# couldn't get
# couldn't get
# ['リストランテ シーヴァ', 35.30671803, 139.5203191]
# yes
# リストランテ シーヴァ
# ChIJAQAEpkJPGGARO3iSIuAoZN4
# ['オ・プレチェネッラ', 35.46141694, 139.6178814]
# yes
# オ プレチェネッラ
# ChIJdVFZqw5cGGARsqKO5gEolOQ
# ['あざみ野うかい亭', 35.56223444, 139.5555542]
# yes
# あざみ野うかい亭
# ChIJb2_wNgr3GGARTblTDxDevmw
# ['ミッシェル ナカジマ', 35.31873306, 139.5334753]
# yes
# レストランミッシェルナカジマ
# ChIJ6cDYqIlFGGARRmH0VKFpDlk
# ['りょうりにん みわ', 35.43838083, 139.64019580000001]
# yes
# レストランみわ
# ChIJFYVg0PFcGGARh-3SBZBSn3I
# ['らーめん 鶏喰', 35.43192889, 139.6215669]
# yes
# らーめん 鶏喰 （～TRICK～）
# ChIJPXTTFoVcGGAR17hiQlCVvmU
# ['カンブーザ', 35.46589972, 139.62635559999998]
# yes
# カンブーザ
# ChIJCYz6DRFcGGARZSzsSXOFprE
# ['横濱元町 霧笛楼', 35.43710722, 139.65232580000003]
# yes
# 霧笛楼
# ChIJed_pv-FcGGARRWJ5GBKepSg
# ['バー ノーブル', 35.44220583, 139.6364822]
# yes
# Bar Noble
# ChIJ973aafRcGGARni-Kbo_kC40
# ['リオス ボングスタイオ', 35.43799167, 139.6528544]
# yes
# リオス ボングスタイオ
# ChIJifF48OFcGGARSra8ksq6hoA
# ['太田なわのれん', 35.43898278, 139.63061530000002]
# yes
# 牛鍋元祖 太田なわのれん
# ChIJKa7HeItcGGARqIxzWFMn7M4
# ['鮨 おとわ', 35.54812423, 139.487804]
# yes
# 鮨 おとわ
# ChIJuyjusgv5GGARbrNMGkbsfac
# ['鮨裕', 35.32268, 139.4066747]
# yes
# 鮨裕
# ChIJv_3CAodSGGARFekuGpAkXH0
# ['埜庵', 35.31741139, 139.4730094]
# yes
# 埜庵
# ChIJvWxfBENOGGARrxWVUr-HPTM
# ['クラリタ ダ マリッティマ', 35.30727833, 139.4927572]
# yes
# クラリタ ダ マリッティマ
# ChIJLRbo_gJPGGARQOsAwzHraBE
# ['イノウエ グリリア', 35.45523528, 139.6227153]
# yes
# Inoue griglia
# ChIJaRuqdXJcGGARgVL-tbYIB5w
# ['ピュイサンス', 35.55248593, 139.52329550000002]
# yes
# PUISSANCE ピュイサンス
# ChIJAQAXnNH5GGARu1UOKJGpC_0
# ['翆陽 エクシブ箱根離宮', 35.24098028, 139.06434309999997]
# yes
# 中国料理翆陽
# ChIJVf6T-ReiGWARAoe0qrpYWcM
# ['おおはま', 35.31262944, 139.5527942]
# yes
# おおはま
# ChIJtX1JjcJFGGARY-gtjJEELr0
# ['鮨 福原', 35.5905125, 139.6061247]
# yes
# 鮨 福原
# ChIJD9IyOZv2GGARF3CpSYe7MuY
# ['フォセッタ', 35.3194625, 139.509305]
# yes
# TRATTORIA Fossetta
# ChIJteTv6wpPGGARQ_l0NhXHHWQ
# ['らーめん いのうえ', 35.52625222, 139.68048530000002]
# yes
# らーめん いのうえ
# ChIJqYSHQDpeGGARefznZuOWDI8
# ['旬鮮炭火焼 獺祭', 35.33318833, 139.4892136]
# yes
# couldn't get
# couldn't get
# ['スパイス・ツリー', 35.29356528, 139.5784014]
# yes
# スパイスツリー
# ChIJW3TFyoxGGGARmEyeOTeSHoI
# ['MANNA', 35.30979863, 139.54258280000002]
# yes
# manna
# ChIJLwdnOO5FGGAR32HLRyiqOYk
# ['イルネッソ', 35.43656778, 139.6498939]
# yes
# イル ネッソ
# ChIJAXcPwHxXGGAR32j9duLoSZc
# ['寿々喜家', 35.46799194, 139.5793189]
# yes
# 寿々㐂家
# ChIJU0VpY3pZGGARApqOqRIJrBA
# ...
# ['山屋', 37.4453475, 138.85674530000003]
# yes
# 居酒屋山屋
# ChIJNUMEHVOo9V8RDepaOyc-h30
# ['焼酎と手しごと料理の店\u3000まさや', 37.44079333, 138.8540467]
# yes
# 焼酎と手しごと料理の店 まさや
# ChIJtea89Fao9V8R8BR_VLjoPYY
# ['寿し処恵', 37.90380278, 139.0153389]
# yes
# 寿し処恵
# ChIJs8_j9jPI9F8RpgeSs_xxwak
# ['華鳳', 37.877320000000005, 139.31758440000002]
# yes
# 白玉の湯 華鳳
# ChIJyxpgnj8ti18R-skj2eQkiVo
# ['滋魂', 37.9314175, 139.11262250000001]
# yes
# らーめん 滋魂
# ChIJ3Vn6zlnK9F8RZYCWrrxOnkw
# ['福実寿司', 37.4495675, 138.8598531]
# yes
# 福実寿司
# ChIJ5fNKp7Sp9V8RwJHQuIw1kJ8
# ['鮨 登喜和', 37.94618333, 139.3277869]
# yes
# 寿し 登喜和
# ChIJA5AUFnAxi18RKT2jz480sU4
# ['廻転寿司弁慶 新潟ピア万代店', 37.92027611, 139.0642461]
# yes
# 佐渡 廻転寿司 弁慶
# ChIJ8-a5RfXJ9F8RbkPD7zRgbpA
# ['越後一会 十郎', 37.91184722, 139.06241719999997]
# yes
# 越後一会 十郎
# ChIJCRbXKpDJ9F8RVbpgKmuWVnA
# ['むらんごっつぉ', 36.93255278, 138.8113889]
# yes
# むらんごっつぉ
# ChIJl0tBaCUCHmARcUjN2r9MsgQ
# ['寿司安', 37.91510083, 139.04841059999998]
# yes
# 寿司安
# ChIJdeAyh-zJ9F8Rb3SPuAPPFh8
# ['龍馬軒', 37.08848091, 138.2380087]
# yes
# 龍馬軒
# ChIJDxSoJkJx9l8RjDcejrIKroQ
# ['串焼とこころ 克', 37.90909528, 139.0564547]
# yes
# 串焼きとこころ 克
# ChIJQ1SZGJfJ9F8R9SJubV3-0Sw
# ['青島食堂 宮内駅前店', 37.41902889, 138.84402690000002]
# yes
# 青島食堂 宮内駅前店
# ChIJUWBsBLyo9V8Rol85PzklQqw
# ['軍ちゃん 直江津店', 37.16936, 138.2448875]
# yes
# 軍ちゃん 直江津店
# ChIJN_XlOW149l8Rg3ZjSREsPPk
# ['レヴォ', 36.55743389, 137.20702690000002]
# yes
# レヴォ
# ChIJ2Q143TWL918Rrphx5viWTls
# ['鮨人', 36.67410222, 137.21025419999998]
# yes
# 鮨人（すしじん）
# ChIJyWBDikaQ918R1ViSFxCwcvE
# ['リバーリトリート 雅樂倶', 36.557432500000004, 137.2070267]
# yes
# リバーリトリート雅樂倶
# ChIJ2wUN6DWL918RSK_KbS-XRwU
# ['鮨 大門', 36.8233925, 137.40993999999998]
# yes
# 鮨 大門
# ChIJNeZF_6el918R-B4OR4zB2ec
# ['日本料理 山崎', 36.67182286, 137.2040022]
# yes
# 日本料理山崎
# ChIJORK5-jiQ918RTPxhfx-DY90
# ['パティスリージラフ', 36.66561639, 137.2034611]
# yes
# パティスリージラフ
# ChIJ1zP1ujGQ918R9YTLLw2MK3s
# ['貧瞋癡', 36.85264833, 136.98935419999998]
# yes
# 貧瞋癡
# ChIJb02cGc1z918RGc9hFfOuMgA
# ['薪の音', 36.50390167, 136.8925833]
# yes
# 薪の音
# ChIJEWBkHTg7-F8R1TBK36nIn58
# ['だい人', 36.69557667, 137.21320219999998]
# yes
# だい人
# ChIJMzw6nYSQ918RGvYJ0fuKa1k
# ['だい', 36.69455512, 137.213832]
# yes
# couldn't get
# couldn't get
# ['ふじ居', 36.70111137, 137.199429]
# yes
# ふじ居
# ChIJtVU9DHua918RCSjaZujcgl4
# ['寿司栄 華やぎ', 36.67151833, 137.21099919999997]
# yes
# 寿司栄華やぎ
# ChIJI3ccbkiQ918R0u1qK9YjXS4
# ['鮨金', 36.74007778, 137.0182111]
# yes
# 鮨金
# ChIJfdLkC7iC918RNUfEs9BLPTo
# ['冨久屋', 36.68743861, 137.2205706]
# yes
# 冨久屋
# ChIJAYMiC4uQ918RZKINHT_tiuU
# ['松月', 36.75548056, 137.2326331]
# yes
# couldn't get
# couldn't get
# ['鮨 つか田', 36.68920287, 137.2179515]
# yes
# 鮨 つか田
# ChIJO3pHW4mQ918R1UFQi44U0Bg
# ['廻転 とやま鮨 富山きときと空港店', 36.64020278, 137.1924608]
# yes
# 廻転 とやま鮨
# ChIJWR4owkCO918R_e4hKZN4S-s
# ['延楽', 36.81481194, 137.5862492]
# yes
# 延楽
# ChIJ9x0zYhSx918R4YKv8ThpCZo
# ['糸庄', 36.67504361, 137.21428469999998]
# yes
# 糸庄
# ChIJ79OLl0WQ918RCKqY3m9qbS4
# ['寿司栄 掛尾店', 36.66393167, 137.2138075]
# yes
# 寿司栄 掛尾店
# ChIJv_BQVsuR918R1euzbbvoJK4
# ['親爺', 36.69585722, 137.21534]
# yes
# 親爺
# ChIJ7VXGs4SQ918RYpTDNdFCQvc
# ['富山豚食堂かつたま', 36.6688225, 137.2050158]
# yes
# 富山豚食堂かつたま
# ChIJY-rFTzeQ918RYN9dDre6Xkc
# ['中国料理 响鈴', 36.69937444, 137.3389497]
# yes
# 中国料理响鈴(しゃんりん)
# ChIJfyF5PoqW918Rbf3oRl_qFqU
# ['すし処 めくみ', 36.51841278, 136.60492030000003]
# yes
# すし処 めくみ
# ChIJX0k-UI01-F8R5e1WQ2vxaUA
# ['太平寿し', 36.5232725, 136.6077061]
# yes
# 太平寿し
# ChIJyRK4GZQ1-F8RYo4izRMaWuE
# ['SHOKUDO YArn', 36.39061889, 136.48265890000002]
# yes
# SHÓKUDŌ YArn
# ChIJf88l9V1Q-F8RAqjJ6caD2xU
# ['竹千代', 36.55803306, 136.6585992]
# yes
# 竹千代
# ChIJP_WHiIAz-F8RWysT1SfZuyI
# ['小松 弥助', 36.57369222, 136.6531811]
# yes
# 小松弥助
# ChIJqYx5eGkz-F8Rw9AIvyBwGs8
# ['乙女寿司', 36.55826111, 136.6546944]
# yes
# 乙女寿司
# ChIJY8-U4X80-F8RhQBJV0MLEUw
# ['鮨 志の助', 36.56408472, 136.6256686]
# yes
# 志の助
# ChIJmSfxT700-F8RkPdVaD6sxjk
# ['一献', 36.55704083, 136.6565089]
# yes
# 一献
# ChIJ158VCn80-F8Rcj7iSwX8vmw
# ['つる幸', 36.567057500000004, 136.65558330000002]
# yes
# つる幸
# ChIJe3KBwHoz-F8RSyTZIG6dvH0
# ['幸寿し 本店', 37.04144417, 136.97027580000002]
# yes
# 幸寿し 本店
# ChIJ6Q2s_509918Rd6ZsL1BWxNA
# ['鮨 八や', 36.57412111, 136.62021830000003]
# yes
# 鮨八や
# ChIJb2M_eqk0-F8RO2lvwfuUUro
# ['ビーフステーキ専門店\u3000ひよこ', 36.54795389, 136.6687881]
# yes
# ひよこ
# ChIJkdV4mHQ0-F8RthB5ERDn_gk
# ['こいで', 36.57339393, 136.6576983]
# yes
# こいで
# ChIJsbQqcGwz-F8RswZUVqQWdLE
# ['べにや無何有', 36.28585639, 136.3660178]
# yes
# べにや無何有
# ChIJ6ThdKgP3-F8R7Ic_4TV_DTg
# ['マキノ', 36.5576563, 136.6524267]
# yes
# couldn't get
# couldn't get
# ['きく家', 36.55824941, 136.65443280000002]
# yes
# きく家
# ChIJSfIz3n80-F8RfIs2haygM8o
# ['つば甚', 36.55217806, 136.6543475]
# yes
# つば甚
# ChIJJ8XwBXs0-F8RoF3xvk_mQbY
# ['日々魚数寄 東木', 36.57356861, 136.6561817]
# yes
# 東木
# ChIJdVcO7Gsz-F8REjuisjYldiU
# ['鮨木場谷', 36.56966575, 136.6648971]
# yes
# 鮨木場谷
# ChIJhxEPtHMz-F8RCreNgLh9xYU
# ['そらみち', 36.52717389, 136.64150419999999]
# yes
# らーめん そらみち
# ChIJW87dGc01-F8Ryne4h4LKsUU
# ['京祇園ねぎ焼 粉', 36.55872164, 136.65570219999998]
# yes
# 京祇園ねぎ焼 粉
# ChIJVZ-iAIAz-F8RwaWxK9e8wYg
# ['飛', 36.563635, 136.65760780000002]
# yes
# 飛
# ChIJ__8kZnkz-F8R6OlakxGKeZA
# ['いたる 本店', 36.55778806, 136.65891059999998]
# yes
# いたる本店
# ChIJH0dij4Az-F8RX9W0FHnAhJY
# ['御料理 貴船', 36.570135, 136.665115]
# yes
# 貴船
# ChIJexh2VHIz-F8RVOtbdZZQ6LY
# ['日本料理 銭屋', 36.55767472, 136.65298719999998]
# yes
# 日本料理銭屋
# ChIJwf3kKn40-F8RdiKV0u3xhng
# ['山中温泉\u3000花紫', 36.24715444, 136.37896809999998]
# yes
# 山中温泉 花紫
# ChIJN24Qe_nz-F8R9ze6gLGVZN0
# ['味楽 ゆめり', 36.57203761, 136.6550052]
# yes
# 味楽ゆめり
# ChIJY0lyym4z-F8R6tEVpd-V6nc
# ['あらや滔々庵', 36.28550917, 136.3649586]
# yes
# あらや滔々庵
# ChIJFRmM2Rz3-F8RBoprjppaHdQ
# ["Installation Table ENSO L'asymetrie du calme", 36.55474222, 136.6557594]
# yes
# Installation Table ENSO L'asymetrie du calme
# ChIJB9jzrX40-F8RMSy5WY9gQvg
# ['自然派ラーメン 神楽', 36.54255361, 136.66062780000001]
# yes
# 自然派ラーメン 神楽
# ChIJr7X-WRM0-F8RamORYLHQkDU
# ['小料理 鈴木', 36.55870216, 136.6541661]
# yes
# 小料理 鈴木
# ChIJHxwtDIA0-F8R_EXxBhU0ECc
# ['鮨処 あいじ', 36.55672083, 136.6533756]
# yes
# 鮨処あいじ
# ChIJNUXAQH40-F8RXJG_rIJoKrQ
# ['天ぷら 小泉', 36.55466637, 136.65573380000004]
# yes
# 天ぷら小泉
# ChIJ5fwJoH40-F8RSf-888-8VDY
# ['高崎', 36.56036472, 136.6552244]
# yes
# couldn't get
# couldn't get
# ['町家懐石\u3000六花', 36.570649100000004, 136.6505078]
# yes
# 町家懐石 六花
# ChIJY7ChA2Yz-F8RuCI9ykZEeWA
# ['鈴おき', 36.51489735, 136.59252659999999]
# yes
# 鈴おき
# ChIJm88xn3VK-F8RMR0VQEADiYk
# ['バー・エスメラルダ', 36.39924722, 136.45403330000002]
# yes
# Bar Esmeralda （バーエスメラルダ）
# ChIJjW5XpwBR-F8RtDEQmAE9dUg
# ['鮨 みつ川', 36.56912167, 136.6699794]
# yes
# 鮨 みつ川
# ChIJA-bQlXQz-F8RzmDVuOaIRyk
# ['加賀屋', 37.08701083, 136.9176483]
# yes
# couldn't get
# couldn't get
# ['くろ屋', 36.57118722, 136.6517606]
# yes
# くろ屋
# ChIJE3sdt2gz-F8R6vHNXXPoc54
# ['料理旅館 金沢茶屋', 36.57372556, 136.65317969999998]
# yes
# 金沢茶屋
# ChIJL3j1gmkz-F8RkpzfKxbpyzc
# ['弁慶', 36.57313361, 136.65233830000003]
# yes
# 弁慶
# ChIJOWyOCmkz-F8RmyZ4v2DSVhQ
# ['寿司処 松の', 36.71638361, 136.705795]
# yes
# 松の寿し
# ChIJkWt4TffW-V8RyASJNrYj5hA
# ['鮨 歴々 近江町店', 36.567697499999994, 136.6592128]
# yes
# 鮨 歴々 近江町店
# ChIJxTe_XXAz-F8R-OtT4RcLeGc
# ['くりゑンテ 金沢・東山', 36.56851139, 136.6712211]
# yes
# くりゑンテ金沢東山
# ChIJVz7A4HQz-F8RPyzi9bjYbzg
# ['たちばな四季亭', 36.28499083, 136.3636386]
# yes
# たちばな四季亭
# ChIJz2dx_Bz3-F8RSFx5GDor-20
# ['ル ミュゼ ドゥ アッシュ KANAZAWA', 36.55713083, 136.6642239]
# yes
# ル ミュゼ ドゥ アッシュ KANAZAWA
# ChIJ____4IYz-F8RA1bK_KWLvcE
# ['炭火焼肉大阪あじまん', 36.51694056, 136.630255]
# yes
# 炭火焼肉大阪あじまん
# ChIJowbmwN01-F8RLwVofrGJYbQ
# ['すし屋\u3000小桜', 36.57231017, 136.6510941]
# yes
# すし屋 小桜
# ChIJq6qB8Ggz-F8R6gXTFBygoNs
# ['料理 小松', 36.55312944, 136.66012419999998]
# yes
# 料理小松
# ChIJXQ4Dvnk0-F8RQyBrRzqwCpE
# ['浅田屋', 36.5673692, 136.6594681]
# yes
# 浅田屋
# ChIJM2frinAz-F8R-mR5lY3xUY8
# ['ねぶた温泉 輪島 海游 能登の庄', 37.39681528, 136.943515]
# yes
# ねぶた温泉 海游 能登の庄
# ChIJAQBc7xsu8V8RZmVFOmMX1LE
# ['自家製麺 のぼる', 36.56573472, 136.62908810000002]
# yes
# 自家製麺のぼる
# ChIJRc4BZaI0-F8RGwR3SyJB0MY
# ['草庵', 36.44253222, 136.63757890000002]
# yes
# 草庵
# ChIJy_-OWCdG-F8RQ3k0luAJpFo
# ['八十八', 36.55874107, 136.6540217]
# yes
# couldn't get
# couldn't get
# ['金沢犀川温泉 川端の湯宿 滝亭', 36.50961139, 136.6957514]
# yes
# 滝亭
# ChIJhdSMX_s2-F8RMfwox8XcfsY
# ['炭魚酒菜 わなか', 36.5724825, 136.6570261]
# yes
# 炭魚酒菜 わなか
# ChIJ0RCZHGwz-F8R8t4Xl8dm0hU
# ['うきぐさ', 36.55874108, 136.6533966]
# yes
# 季の肴 うきぐさ
# ChIJ7RiXbIA0-F8R0OuLRXi6Xcg
# ['甘納豆かわむら', 36.55360889, 136.6500592]
# yes
# 甘納豆かわむら
# ChIJuRfW53w0-F8Rc6QfflUk-YY
# ['川端鮮魚店', 36.55706944, 136.6547456]
# yes
# 川端鮮魚店
# ChIJ-ftss380-F8RWNt0U1XjVLE
# ['千取寿司 本店', 36.55072417, 136.6761747]
# yes
# 千取寿し本店
# ChIJgTXA14oz-F8Rm-1zlBKB0Gg
# ['はせ川', 36.51295278, 136.6229278]
# yes
# はせ川
# ChIJHccJceQ1-F8RV2KrEQiSTsE
# ['かた田', 36.56734337, 136.6569801]
# yes
# かた田
# ChIJhR4Zn3oz-F8R9qySgtNab8g
# ['川喜', 36.218477500000006, 136.1603533]
# yes
# 川き
# ChIJSa81n1Hv-F8RzA8bo8_LkEA
# ['鮨 十兵衛', 36.07354556, 136.2064844]
# yes
# 鮨十兵衛
# ChIJGymXRAS_-F8RIeRNF8la_zY
# ['めん屋 さる', 36.04393639, 136.1890203]
# yes
# めん屋さる
# ChIJqQgqoje5-F8Rzju91vAmrDc
# ['旬味 泰平', 36.05840278, 136.2190725]
# yes
# 泰平
# ChIJY0KxvOu--F8R-W1rlVxVzmk
# ['こばせ', 35.95101167, 135.9847906]
# yes
# ふるさとの宿 こばせ
# ChIJTWK2z8G0-F8R-OzZs-tCT4Q
# ['望洋樓', 36.22251306, 136.13521310000002]
# yes
# 望洋楼
# ChIJkQkuMAbm-F8RelhZIezRyq4
# ['いわし屋', 36.06247222, 136.2168028]
# yes
# いわし屋
# ChIJUd2ebe---F8RbJ6WmWzRE5U
# ['けんぞう蕎麦', 36.08634194, 136.30068469999998]
# yes
# けんぞう蕎麦
# ChIJi5RLsumV-F8R1eyMRK24BuI
# ['滝の川', 35.90163583, 136.0011611]
# yes
# 地魚もてなし 滝の川
# ChIJMWac8h1N_18RIbySLA0fUsg
# ['OTTO SETTE 星野リゾート リゾナーレ八ヶ岳', 35.86602778, 138.3300986]
# yes
# couldn't get
# couldn't get
# ['キュイエット', 35.72039333, 138.4802672]
# yes
# la Cuelleitte restaurante frances
# ChIJNcFSYKILHGARjLvMbtgAmSU
# ['仙人小屋', 35.90443111, 138.3888233]
# yes
# 仙人小屋
# ChIJGaLiubtqHGAR7ECLLe7s0Ts
# ['湖山亭うぶや', 35.50955107, 138.7718816]
# yes
# 湖山亭うぶや
# ChIJK4evUjdeGWARU3gkvo_nU_4
# ['井筒屋', 35.85957207, 138.3201263]
# yes
# うなぎ専門店 井筒屋
# ChIJ15XYyIdpHGAR-hesqvgj5ng
# ['古守宿一作', 35.83300029, 138.3355759]
# yes
# 古守宿一作
# ChIJDZXpaO5rHGARi9qPRZy7HqE
# ['中村農場', 35.88620095, 138.4223224]
# yes
# couldn't get
# couldn't get
# ['翁', 35.82256944, 138.3564117]
# yes
# 翁
# ChIJq5LFZ3tsHGARvaWrEy9SCrM
# ['ヴィラ・アフガン', 35.90904269, 138.41134309999998]
# yes
# アフガン
# ChIJqQF0DUgVHGARKho_csSlfwY
# ['湖麺屋 リールカフェ', 35.40705028, 138.8910186]
# yes
# 湖麺屋 リールカフェ
# ChIJn7suUsA6IRUR1Z9QUwbZBQ4
# ['キッチン美味小家', 35.67689194, 138.5505031]
# yes
# 美味小家
# ChIJEwb-tJL3G2ARpDyau6mkXJE
# ['専心庵', 35.64738278, 138.5656822]
# yes
# 専心庵
# ChIJe3skPt75G2AREJCiTspVE_U
# ['中華蕎麦うゑず', 35.64755556, 138.5468156]
# yes
# 中華蕎麦うゑず
# ChIJraYb_m33G2ARMOHPuSj916Y
# ['風', 35.650275, 138.7239264]
# yes
# レストラン風
# ChIJpdg9v9dXGWARPfnZDcN9NLM
# ['フォリオリーナ・デッラ・ポルタ・フォルトゥーナ', 36.36279306, 138.59042309999998]
# yes
# フォリオリーナ・デッラ・ポルタ・フォルトゥーナ
# ChIJ_SiX8IjRHWARmlryihp7aTM
# ['柚木元', 35.51627222, 137.8260778]
# yes
# 柚木元
# ChIJy9d2neqZHGARwFeYOT6KszA
# ['蕎麦 ふじおか', 36.71325722, 138.132905]
# yes
# 蕎麦 ふじおか
# ChIJZf6Xj3Ep9l8R0NIwGtOC1kA
# ['ユカワタン', 36.35567833, 138.59142859999997]
# yes
# ブレストンコート ユカワタン
# ChIJ7b6YRSXSHWARU3XXqTyAzOE
# ['せきざわ', 36.70042444, 138.3300725]
# yes
# せきざわ
# ChIJh2vxmueLHWAR36SlCWeMMMA
# ['花仙庵 仙仁温泉 岩の湯', 36.58610806, 138.33185580000003]
# yes
# 仙仁温泉 岩の湯
# ChIJfz4ITiWSHWARCFoFTuJWuuc
# ['うなぎのまつか', 36.22938611, 137.9749533]
# yes
# うなぎのまつか
# ChIJm9ClepIOHWARGVy6N__Jcwc
# ['石臼挽き蕎麦香房 山の実', 36.78369417, 138.45614419999998]
# yes
# 山の実
# ChIJGVvUmbz1HWARXzaQB72xs18
# ['ホテル ブレストンコート', 36.35715717, 138.5918065]
# yes
# 星野リゾート 軽井沢 ホテルブレストンコート
# ChIJn7K8-C_SHWARjOa6jK1h32o
# ['鄙の宿 金宇館', 36.24639167, 138.0007333]
# yes
# 美ヶ原温泉 鄙の宿 金宇館
# ChIJI7iLc7IOHWAR9JSLRvyP11M
# ['旅舎右馬允', 35.55233, 138.0468961]
# yes
# 右馬允(うまのじょう)
# ChIJ5UPLWdSAHGARlbDme_ltsq8
# ['明神館', 36.18275528, 138.0852792]
# yes
# 明神館
# ChIJnwNCENWpHWAR1QWsIeXNL3Y
# ['うずら家', 36.73828328, 138.0887743]
# yes
# 蕎麦処 うずら家
# ChIJHZ_ui74u9l8Ry0pNBkGOHcA
# ['職人館', 36.21106333, 138.3604581]
# yes
# 職人館
# ChIJe_P85N-0HWARnVSM46bI4S0
# ['鮨 いぬかい', 36.23999, 137.94742390000002]
# yes
# 鮨 いぬかい
# ChIJt5vy_dwNHWARsA7Uyc9eXF8
# ['うなぎ 小林', 36.01433722, 138.13006140000002]
# yes
# うなぎ小林
# ChIJHx4OfY9WHGARCgKta4kkp3I
# ['拉麺酒房 熊人', 36.38101528, 138.22920280000002]
# yes
# 拉麺酒房 熊人
# ChIJt-r9xCSjHWARk_3pMkREU6U
# ['旅館 すぎもと', 36.24369361, 138.00373249999998]
# yes
# 旅館すぎもと
# ChIJn93HVrMOHWARg9AANVm8Y9E
# ['わらび野', 35.9320777, 137.6205824]
# yes
# わらび野
# ChIJZ6e8oBcmHWARBfvJUh_eDak
# ['レストラン クララ', 36.05286389, 138.2648725]
# yes
# レストランクララ
# ChIJhaEbwAFPHGARkqmXpr7CZUk
# ['麺道 麒麟児', 36.58084722, 138.15318280000002]
# yes
# 麺道 麒麟児
# ChIJ1TcmmkyeLxURtOBH4E4-7XM
# ['磊庵はぎわら', 36.26063611, 138.46912690000002]
# yes
# 磊庵はぎわら
# ChIJD10WH2nLHWARWGxsi46k4rs
# ['界 松本', 36.25864797, 137.9917907]
# yes
# 星野リゾート 界 松本／Hoshino Resorts KAI Matsumoto
# ChIJI1a5_xoMHWAReGh-A5E-aOk
# ['そばの実', 36.74389045, 138.08093169999998]
# yes
# そばの実
# ChIJxU9C_pIu9l8RROiLQLmH6SY
# ['丸富', 35.72832333, 137.90615280000003]
# yes
# 丸富
# ChIJ6XyGakDtHGARqWtJ_cGrMFI
# ['そば茶屋 極楽坊', 36.74570972, 138.0854081]
# yes
# 極楽坊
# ChIJH9QJ4ewu9l8RjpdV3-ECdMM
# ['エルミタージュ ドゥ タムラ', 36.33494623, 138.6055429]
# yes
# エルミタージュ・ドゥ・タムラ
# ChIJw8bqU6rTHWAR0gDDX_O29ok
# ['ア フェネステッラ', 36.33875444, 138.6055589]
# yes
# couldn't get
# couldn't get
# ['エスパース ソシアル ル サロン', 36.22584667, 137.9754767]
# yes
# エスパース・ソシアル・ル・サロン
# ChIJKxqPQ-0OHWARH4DcoEdZ7l4
# ['住吉屋', 36.9217508, 138.4517423]
# yes
# 野沢温泉 村のホテル 住吉屋
# ChIJ0xEVvC8F9l8RZfO3sI_bkNk
# ['ヴィラデスト ガーデンファーム アンド ワイナリー', 36.38287861, 138.34360969999997]
# yes
# ヴィラデストガーデンファーム アンド ワイナリー
# ChIJMeASPxW5HWARQQvjB1AOWsU
# ['とんかつ 力亭', 36.39444833, 138.2522042]
# yes
# とんかつ 力亭
# ChIJv2jXq9C8HWARoVypOiLnSPs
# ['ダイニングルーム', 36.23959, 137.6315211]
# yes
# couldn't get
# couldn't get
# ['ハルタ 軽井沢', 36.34513667, 138.5934992]
# yes
# haluta karuizawa
# ChIJr9wM1DfSHWARNXedK1_SqjU
# ['蕎麦倶楽部\u3000佐々木', 36.23261842, 137.975142]
# yes
# 蕎麦倶楽部 佐々木
# ChIJuUqMxJEOHWARw3dV4bsB_Hw
# ['山本小屋 ふる里館', 36.22458167, 138.13467419999998]
# yes
# 山本小屋ふる里館
# ChIJz8w55ZKoHWARFetncUCd3KI
# ['ぬのはん', 36.04617418, 138.11638280000003]
# yes
# 布半
# ChIJMXNwRa5VHGAR2DScZ6UX4sg
# ['春欄の宿 さかえや', 36.73162917, 138.4346608]
# yes
# 和の心を愉しむ 渋温泉 春蘭の宿 さかえや
# ChIJ9T2UnIP0HWAR-ryNvbyd6Yw
# ['軽井沢 川上庵', 36.3531925, 138.63696000000002]
# yes
# 川上庵
# ChIJYzpy1oXTHWARy7giKJvCbdM
# ['エンボカ軽井沢 旧軽井沢店', 36.3468975, 138.6372544]
# yes
# エンボカ軽井沢旧軽井沢店
# ChIJ2_W79oHTHWAR43L_T7ffC10
# ['メインバー コート', 36.23037, 137.9719125]
# yes
# メインバーコート
# ChIJl7KtYo4OHWAR_iX4JFDx2tg
# ['レストラン\u3000トエダ', 36.33237928, 138.5951349]
# yes
# TOEDA
# ChIJ0_l_sEnSHWARztiau6Br3Kg
# ['柳家', 35.31494333, 137.3373592]
# yes
# 柳家
# ChIJq6pWUtJRA2ARtKygfg8ao4A
# ['開化亭', 35.42016806, 136.76236530000003]
# yes
# 開化亭
# ChIJh34h3VqpA2ARr5FsRZnPX-8
# ['かたつむり', 35.55689111, 136.70897140000002]
# yes
# 摘草料理かたつむり
# ChIJkfL5xJxRAmARqkyYpWiXHr0
# ['仲佐', 35.80181222, 137.2482175]
# yes
# 仲佐
# ChIJ1-mi3sjbAmARBJPsFDuwpQY
# ['胡蝶庵 仙波', 35.43081833, 136.7473583]
# yes
# 胡蝶庵 仙波
# ChIJeWC2mQisA2ARzP4Wby0kl8I
# ['川原町 泉屋', 35.43270667, 136.7730211]
# yes
# 川原町泉屋
# ChIJF8WQfd-rA2AR-GCXIBZ6cIk
# ['しげ吉', 35.48414639, 136.9016967]
# yes
# couldn't get
# couldn't get
# ['信濃屋', 35.33514056, 137.1291717]
# yes
# 信濃屋
# ChIJl2MoTGNqA2ARnClC7GkPIxo
# ['たか田八祥', 35.41909028, 136.7622525]
# yes
# 日本料理 たか田 八祥
# ChIJK-JIzVqpA2ARHqEihcAEsF4
# ['キュルノンチュエ', 36.13302389, 137.17901830000002]
# yes
# キュルノンチュエ
# ChIJxeSFMB6jAmARtCriJH4aG8s
# ['焼鳥 みずき', 35.41601167, 136.7634414]
# yes
# みずき
# ChIJ0bFFN0SpA2ARa0Rl067KE_U
# ['ツバメヤ 柳ヶ瀬本店', 35.41525111, 136.7622178]
# yes
# couldn't get
# couldn't get
# ['バロッサ', 35.41166028, 136.76193469999998]
# yes
# couldn't get
# couldn't get
# ['らーめんNageyari', 35.40341972, 136.83494309999998]
# yes
# らーめん Nageyari
# ChIJB8iKufMHA2ART1FYFj6MtxI
# ['辻屋', 35.48290694, 136.91843219999998]
# yes
# 辻屋
# ChIJXQCX3BYEA2AR-BqxKXnWMUM
# ['桔梗苑 本店', 35.39547333, 136.75860559999998]
# yes
# 桔梗苑本店
# ChIJnRg9Li-pA2ARnS9hwFsUZP0
# ['料理旅館\u3000奥飛騨山草庵\u3000饗家', 36.23416075, 137.5321146]
# yes
# 山草庵 饗家（きょうや）
# ChIJf8nXC39OHWARhjesNbhASgw
# ['メツゲライ・トキワ', 35.49290889, 136.9016975]
# yes
# メツゲライ・トキワ
# ChIJ9X9_blQBA2ARToWaO_Np_rQ
# ['麺坊ひかり', 35.36443622, 136.7521685]
# yes
# 麺坊ひかり
# ChIJdWMwarOoA2ARpGk8wfLSGmk
# ['トラン・ブルー', 36.13023611, 137.25277419999998]
# yes
# トランブルー -TRAIN BLEU-
# ChIJs1aVFCG7AmARIP9vkzdI-zo
# ['そばきり 萬屋町 助六', 35.48392333, 136.9153781]
# yes
# 助六
# ChIJ87ZDdhoEA2ARVPe4aow0lQk
# ['蕎麦正\u3000まつい', 35.74875278, 136.95925780000002]
# yes
# 蕎麦正まつい
# ChIJtRxq9UHwAmARlSPTYkZAmNA
# ['手打蕎麦 わくり', 35.49688, 137.5070656]
# yes
# 手打蕎麦 わくり
# ChIJE3z5IEm0HGARHwk44_LyhE4
# ['麺屋 白神', 35.48229417, 136.8893264]
# yes
# 麺屋 白神
# ChIJ-UH6WLQGA2ARIE68w0pywD0
# ['てら田', 35.40778472, 136.7602875]
# yes
# てら田
# ChIJXagNiTepA2ARi-9JIxHxLt0
# ['栗きんとん本家\u3000すや 本店', 35.49493583, 137.5089783]
# yes
# すや 本店
# ChIJuWax2ke0HGAR6CT0g5iu7nc
# ['すや 西木', 35.4949425, 137.5163708]
# yes
# couldn't get
# couldn't get
# ['味蔵天国', 36.13666389, 137.2549394]
# yes
# 味蔵天国
# ChIJq6pqwye7AmARVF1ul0VnSyc
# ['ラーメン イロドリ', 35.40715131, 136.79145680000002]
# yes
# ラーメン・イロドリ
# ChIJAQAs-qqpA2ARovrJxGEjgjE
# ['ファンボギ', 35.40811833, 136.7612464]
# yes
# 焼肉旬やさいファンボギ
# ChIJpTjMJjipA2ARnGItF555Wd0
# ['やまだや', 35.32328428, 137.3833804]
# yes
# 十割蕎麦と岩魚 やまだや
# ChIJH3uNDD5SA2AReZHUzNz_viA
# ['飛騨古川\u3000料亭旅館\u3000八ツ三館', 36.22997927, 137.1907237]
# yes
# 八ツ三館
# ChIJVQH2ZuSgAmARUeQBdLjm7_c
# ['りきどう', 35.429295, 136.74758530000003]
# yes
# らぁめん りきどう
# ChIJQ7R6RwasA2ARtkAjVglhrvE
# ['吉田屋 美濃錦', 35.74779833, 136.96061219999999]
# yes
# 美濃錦
# ChIJ0cICcmrwAmARvKnCSqH85Pg
# ['真屋', 35.37265722, 136.5905778]
# yes
# 真屋
# ChIJu-F5k3O0A2ARQ5U6-Mzc0rs

# %%
name
# Out:
# ['鮨 一幸',
#  '天ぷら 田ざわ',
#  'すし宮川',
#  '鮨菜和喜智',
#  '壽山',
#  '鮨みなと',
#  '寿し ひでたか',
#  '鮨処 有馬',
#  'ひび屋',
#  'モリエール',
#  '味道広路 (あじどころ)',
#  'ミシェル・ブラス トーヤジャポン',
#  'さくら通り 梅乃寿司',
#  'saveur サヴール',
#  'VALORE',
#  'No Data',
#  '麺屋 彩未',
#  '酒房しんせん',
#  '薄野 鮨金',
#  'レストラン・マッカリーナ',
#  '十勝川温泉 三余庵',
#  'オーベルジュ ド リル サッポロ',
#  '眞',
#  '成吉思汗 大黒屋 五丁目支店',
#  'グルマンズいとう',
#  'こまつ',
#  '成吉思汗だるま 本店',
#  '独酌 三四郎',
#  '郷土料理 おが',
#  'No Data',
#  'すし屋のさい藤',
#  '鮨 一幸',
#  '天ぷら 田ざわ',
#  'すし宮川',
#  '鮨菜和喜智',
#  '壽山',
#  '鮨みなと',
#  '寿し ひでたか',
#  '鮨処 有馬',
#  'ひび屋',
#  'モリエール',
#  '味道広路 (あじどころ)',
#  'ミシェル・ブラス トーヤジャポン',
#  'さくら通り 梅乃寿司',
#  'saveur サヴール',
#  'VALORE',
#  'No Data',
#  '麺屋 彩未',
#  '酒房しんせん',
#  '薄野 鮨金',
#  'レストラン・マッカリーナ',
#  '十勝川温泉 三余庵',
#  'オーベルジュ ド リル サッポロ',
#  '眞',
#  '成吉思汗 大黒屋 五丁目支店',
#  'グルマンズいとう',
#  'こまつ',
#  '成吉思汗だるま 本店',
#  '独酌 三四郎',
#  '郷土料理 おが',
#  'No Data',
#  'すし屋のさい藤',
#  '群来膳',
#  'La Cucina VENTITRE',
#  '麺屋 高橋',
#  'No Data',
#  '美国観光ハウス',
#  '麺屋 菜々兵衛',
#  '麺eiji平岸ベース',
#  'コートドール',
#  '鈴木食堂',
#  '二代目 佐平次',
#  'ラ・サンテ',
#  'ル ミュゼ',
#  'アキ ナガオ/AKI NAGAO',
#  'あかん鶴雅別荘 鄙の座',
#  'No Data',
#  'くりや',
#  'No Data',
#  'The Bar Nano',
#  'No Data',
#  'バープルーフ',
#  'No Data',
#  '天ぷら あら木',
#  'すし屋 高大',
#  '鮨おおね田',
#  '鮨ノ蔵',
#  'うにむらかみ 函館本店',
#  'ファイ',
#  'ラ・ブリック',
#  'お料理 あま屋',
#  'ミクニ サッポロ',
#  '鮨処 北の華',
#  '鮨処うえの',
#  'méli mélo メリメロ',
#  'らーめん佳',
#  'No Data',
#  'シロクマ食堂',
#  '鮨一',
#  '2001 BAR Moon Light',
#  '炭焼豚丼 空海',
#  '裏参道牛肉店',
#  'オステリア クロッキオ',
#  'フラテッロ・ディ・ミクニ',
#  '花小路さわ田',
#  'フレンチレストラン カザマ',
#  '望楼 NOGUCHI 登別',
#  'エノテカ・ラ・リコルマ',
#  'Teze',
#  '手打蕎麦のたぐと',
#  'ブーランジェリー ジン',
#  'さっぽろジンギスカン本店',
#  '宝すし',
#  'No Data',
#  '㐂ばらし',
#  '野武士',
#  'TAKAO',
#  "L'oiseau par Matsunaga 『ロワゾー・パー・マツナガ』",
#  '175°DENO 担担麺 本店',
#  '蕎麦切り 春のすけ',
#  'パティスリーシイヤ',
#  'ジンギスカン 羊飼いの店 『いただきます。』',
#  '喰い処 鮭番屋',
#  'RISTORANTE CANOFILO',
#  'そば切 雨耕庵',
#  'ホルモン銀牙',
#  '沖縄そば風遊斎',
#  '美麗華',
#  'No Data',
#  '千春鮨 すすきの',
#  'すし処・対照',
#  'No Data',
#  '麺や けせらせら',
#  'エグ・ヴィヴ（Aigues Vives）',
#  '麺や麗',
#  '手打うどん 寺屋',
#  'ラビスタ函館ベイ',
#  '一文字咖喱店',
#  'ピッツェリア・ダ・マッシモ',
#  'ブランジェリー ラ・フォンティヌ・ドゥ・ルルド',
#  'すき焼き 阿さ利本店',
#  '成吉思汗 だるま4・4店 二階亭',
#  '手打ち蕎麦 いし豆 石臼挽き',
#  'No Data',
#  'ル・ジャンティオム',
#  'コルツ',
#  'No Data',
#  '登別温泉郷 滝乃家',
#  '定山渓第一寶亭留 翠山亭',
#  '鮨 西光',
#  'テアトロ ディ マッサ',
#  '望楼ＮＯＧＵＣＨＩ函館',
#  '鮨処 美な味',
#  'Rojiura Curry SAMURAI. 平岸店',
#  '手打蕎麦 いちむら',
#  'そば屋けん豆',
#  "Maison de h-l'E´ridan",
#  '湯宿だいいち',
#  'Wine Restaurant Akihisa Handa',
#  'No Data',
#  'KAMIMURA レストラン',
#  '鮨 おくの',
#  '温味',
#  '元祖 豚丼のぱんちょう',
#  '函館うに むらかみ 日本生命札幌ビル店',
#  '煮干らぁめん なかじま',
#  '我流麺舞 飛燕',
#  'ラーメン木曜日',
#  'No Data',
#  '士別バーベキュー',
#  '利めい庵',
#  '蕎麦屋 此花',
#  '鮨処 木はら',
#  'No Data',
#  '手作り創作 ゆるり家',
#  'レストラン・バスク',
#  'BAR MADURO',
#  '蔵鵡別邸',
#  'カクテルバースプーン',
#  'No Data',
#  'さっぽろ純連 札幌本店',
#  '雨は、やさしく',
#  'いせのじょう',
#  '元祖 小いけ',
#  'カプセルモンスター',
#  '札幌柳屋',
#  'ザレイクビューＴＯＹＡ乃の風リゾート',
#  'No Data',
#  '鮨 田なべ',
#  'GRIS',
#  '茶寮 瀧乃家',
#  'すし明',
#  '成吉思汗 だるま6.4店',
#  'おたる政寿司 本店',
#  '開陽亭 すすきの店',
#  'いずみ食堂',
#  'Bon Vivant(ボン・ヴィバン)',
#  'バーやまざき',
#  'アンジェリック ヴォヤージュ',
#  '手打蕎麦こはし soba',
#  '八乃木',
#  'No Data',
#  'やきにく舎 太好了 すすきの店',
#  '馬場ホルモン',
#  'とんかつくにか',
#  'サリュ',
#  'そば処 大和',
#  'しろくま 札幌成吉思汗 本店',
#  'ギリガンズアイランド',
#  "プティサレ/P'tit sale'",
#  'さっぽろジンギスカン千歳',
#  'フラノ寶亭留',
#  '唐草館',
#  '焼肉屋かねちゃん 至粋亭',
#  'the bar nano.gould',
#  'しゃぶしゃぶ酒屋 しの平',
#  '鮨 まつもと',
#  'いわない温泉 高島旅館',
#  'エルバステラ',
#  '杏ダイニング／カフェ＆バー An Dining / Cafe&Bar',
#  '味噌らーめん専門店 狼スープ',
#  'あら焚き豚骨 あらとん 本店',
#  'クロック',
#  'Q',
#  '滋養軒',
#  '函館 開陽亭 すすきの2号店',
#  '海鮮処函館山',
#  'はるのそら',
#  '五醍',
#  '大勝軒',
#  '香るつけ蕎麦 蕎麦花',
#  'No Data',
#  'No Data',
#  '札幌・すすきのフレンチ TATEOKA TAKESHI',
#  '寿司一',
#  'みなと食堂',
#  '千陽',
#  'ほむら',
#  '津軽割烹 未来',
#  'No Data',
#  '料理茶や 八重さわ',
#  '川よしうなぎ店',
#  '海の幸 美味',
#  'たかはし中華そば店',
#  'カーサ・デル・チーボ',
#  'はた善',
#  'ローズガーデン',
#  'ラーメン店 旅路',
#  'ウィーン菓子 シュトラウス',
#  'レストラン山崎',
#  '海峡荘',
#  'アルチェントロ',
#  'No Data',
#  '寺沢 (Terasawa)',
#  '龍園',
#  'No Data',
#  '松もと',
#  'シェ・ムラ・ブル・リス',
#  '盛楼閣',
#  '中華そば 弥太郎',
#  '菜遊記',
#  'リストランテ シカザワ',
#  'DADA',
#  '沢内甚句',
#  'ホテルメトロポリタン盛岡 日本料理 対い鶴',
#  'シェ・ジャニー',
#  '千松しま',
#  '弘寿司',
#  '楽・食・健・美 -KUROMORI-',
#  '日本料理e.',
#  '小判寿司',
#  '居酒屋ちょーちょ',
#  '閣 ブランドーム店',
#  '米沢牛焼肉 仔虎 仙台駅前店',
#  '中華そば 嘉一',
#  '萬み高橋',
#  '都留野',
#  'うな貴',
#  'ナクレ',
#  'とんかつかつせい',
#  '福よし',
#  '結委 ゆい',
#  '炭火焼肉ぐら',
#  'No Data',
#  '梵くら',
#  '大胡椒',
#  '白雪',
#  '三太郎',
#  '蓑',
#  'MURATA(ムラタ 叢田 ）',
#  '仙台市泉区［小豆］和食・おすすめ・人気・日本料理・会席料理・懐石料理・顔合わせ・個室・接待',
#  '塩竃すし哲 本店',
#  'ウェスティンホテル仙台',
#  '旨味 太助',
#  'フレンチレストラン プレジール',
#  'No Data',
#  '塩竃すし哲 S-PAL仙台店',
#  '廻鮮寿司 塩釜港',
#  'あちゃーる',
#  'No Data',
#  'BAR arcenciel',
#  '時音の宿 湯主一條',
#  '牛正仙台店',
#  '寿司正',
#  '北辰鮨仙台駅店',
#  'みずさわ屋',
#  '杉のや',
#  'No Data',
#  'ピッツェリア・パドリーノ・デル・ショーザン',
#  '韓国家庭料理 扶餘',
#  '花牛',
#  '旨いもの家 いま井',
#  '仙台牛焼肉＆ワイン 298nky',
#  'たかむら',
#  '酒盃',
#  '秋田 てんぷら みかわ',
#  '昔のきりたんぽや',
#  'きりたんぽ専門店むらさき',
#  'すし匠',
#  'すし兆',
#  'あら田鮨',
#  'Ｊ一行樹',
#  'f(エッフェ)',
#  'No Data',
#  'No Data',
#  '和食すがわら',
#  '宝寿司分店',
#  '麺饗 松韻',
#  '乳頭温泉郷 鶴の湯温泉',
#  '心粋厨房 獬',
#  'たつ福',
#  'ジュエーメ',
#  'ＢＡＲル・ヴェール',
#  '鮨駒',
#  '鮨天駒',
#  'No Data',
#  '炭火焼 鳥好',
#  '料亭 濱乃家',
#  'エッサンス',
#  '和食 なり',
#  '天ぷら 酒菜 醍醐',
#  '串揚げ串の実',
#  'レディ',
#  '割烹 美さわ',
#  '自家製麺伊藤',
#  'そば打ち幸甚',
#  'いな穂',
#  'No Data',
#  '鳥料理 とぶ',
#  '一心寿し',
#  '腰掛庵',
#  '九兵衛旅館',
#  'いしやま寿司',
#  '琴平荘',
#  'こい勢',
#  '龍上海 赤湯本店',
#  '山形座 瀧波 YAMAGATA THE TAKINAMI',
#  'アル・ケッチァーノ',
#  'No Data',
#  '山菜料理 出羽屋',
#  'あきよし',
#  '日本の宿 古窯',
#  '御りょうり屋 伊藤',
#  '花明りの宿 月の池',
#  '酒菜一',
#  'はたごの心 橋本屋',
#  '御宿かわせみ',
#  '小判寿司',
#  '八山田らん亭美日庵',
#  '鮨いとう',
#  'とら食堂',
#  '伊達屋',
#  '寿司割烹 魚紋',
#  '丸新',
#  '自家製麺うろた',
#  '鮨 来多老',
#  'おとぎの宿米屋',
#  'こふく',
#  'いろりの宿 芦名',
#  '天ぷら佐久間',
#  'あ吽',
#  '仁亭 (じんてい)',
#  'TARO CAFE',
#  '鶏けん',
#  'ハッピーベリー',
#  'わき水',
#  '蕎麦彩膳 隆仙坊',
#  '食堂なまえ',
#  '籠太',
#  'もうもう亭',
#  'No Data',
#  '味心すず木',
#  'くつろぎ宿 千代滝',
#  '坂内食堂 喜多方本店',
#  '支那そば 正月屋',
#  'くをん',
#  '喜一',
#  '遊里庵',
#  '磯陣',
#  '慈久庵',
#  '煮干中華ソバ イチカワ',
#  '鬼怒川 竹やぶ',
#  'コジコジ',
#  'はりけんラーメン 本店',
#  'らぁめん 喜乃壺',
#  '塩町館',
#  'ぬりや 泉町店',
#  '喜元門 本店',
#  'オオツ（ＯＨＴＳＵ）',
#  '茨城そば処 木挽庵',
#  '人生 拉麺',
#  '夫婦庵',
#  '牛新 東海店',
#  '家系ラーメン 熊田家',
#  'はまぐり屋',
#  '中川楼',
#  '麺屋壱心',
#  'オーシャンフロント お宿 Hamadakan',
#  'ちゅう心',
#  '蕎麦処みかわ',
#  '中華蕎麦はざま',
#  '川蝉',
#  '日向屋',
#  '佐野青竹手打ちラーメン 大和',
#  '焼肉グレート 駅前店',
#  'らーめん大金',
#  '三たてそば 長畑庵',
#  '蕎遊庵',
#  '鳥常 本店',
#  '麺屋 ようすけ',
#  '手打 焔',
#  'No Data',
#  'バー・シャモニー',
#  '割烹旅館 湯の花荘',
#  '那須別邸 回',
#  '胡桃亭',
#  '麺藏藏',
#  'ラーメン二郎 栃木街道店',
#  '魚登久',
#  '鮨おばな',
#  '鮨恵三',
#  'らーめん 芝浜',
#  '龢nagi',
#  '支那そば なかじま',
#  'そばきり',
#  'すし処 さいとう',
#  '手打ちそば 舞鶴',
#  '旬彩和人良',
#  'もっこす',
#  '割鮮 たけ花',
#  'No Data',
#  '蒼屋',
#  '中国料理 竜苑',
#  '炭こう',
#  'おさかな亭',
#  '豚骨ラーメン だるま大使 本店',
#  'かつサンド工房 PANTON',
#  'No Data',
#  'くろ松',
#  'つけ麺 弥七',
#  '別邸 仙寿庵',
#  '清仁軒',
#  '創和 織部',
#  '鮨 猪股',
#  '中華そば 四つ葉',
#  'No Data',
#  '所沢 イタリアン オット',
#  '鰻むさし乃',
#  'うなぎ屋酒坊・画荘 越後屋',
#  '中華そば よしかわ',
#  '寿製麺よしかわ',
#  'よし佳 寿司',
#  'シンフラ',
#  'ぜんや',
#  '弥助鮨',
#  'アカシエ',
#  '京亭',
#  'negombo33',
#  'くら川',
#  '阿左美冷蔵 金崎本店',
#  '狼煙',
#  '和風楽麺 四代目 ひのでや',
#  'シャンドワゾー',
#  '喰心',
#  'メゾンドゥアッシュ',
#  'うなぎ浜名',
#  '鮨ふく',
#  '酒場わたなべ',
#  '狭山 翁',
#  'つけめん さなだ',
#  '麺処・有彩',
#  '麺堂 稲葉ｋｕｋｉｓｔｙｌｅ',
#  '煮干乱舞',
#  'ハンディクラフト ワークス',
#  'こむぎ',
#  'みや',
#  'うなぎ 小川菊',
#  '麺屋時茂',
#  '麺屋 桐龍',
#  '支那そば心麺',
#  'らーめん かねかつ',
#  '自家製麺 竜葵',
#  '寛～くつろぎ～',
#  '㐂九八 ～ garage ～',
#  '讃岐うどん 條辺',
#  '次念序',
#  '中華そば 幻六',
#  '柳麺 呉田 goden',
#  'アングランパ',
#  '手打うどん 長谷沼',
#  'オランダ軒',
#  'cimai pain',
#  '天徳',
#  'たかおか',
#  'No Data',
#  '寿司栄',
#  '中華蕎麦とみ田',
#  'トラットリア・アルベロ',
#  'ゾエズ（ｚｏｅ’ｓ）',
#  'No Data',
#  'リストランテさくら',
#  'ル・クープル',
#  '炭火焼鰻 小暮や',
#  'Zopf',
#  '三日月氷菓店',
#  '京料理かねき',
#  'フランス料理 ル・クール Le Coeur',
#  '更科すず季',
#  '味処 むさし野',
#  'ル・パティシエ・ヨコヤマ 谷津店',
#  '濃麺 海月',
#  'No Data',
#  'プレゼンテ スギ',
#  'ル・パティシエ・ヨコヤマ 大久保店',
#  '竹やぶ',
#  'ROKUZA',
#  'ラーメン杉田家 千葉店',
#  'No Data',
#  '今久焼肉',
#  'パティスリー レ・タン・プリュス',
#  '芳野屋',
#  'なかき',
#  '兎に角 松戸店',
#  'Zopf',
#  '打墨庵 加瀬',
#  '中国料理文菜華',
#  'The Noodles & Saloon Ｋｉｒｉｙａ',
#  '小料理野本',
#  'ちばから',
#  '山田',
#  'らーめん 寺子屋 麺倶楽部',
#  'とんかつ 瓢 ～ひさご～',
#  '千葉県白子町の隠れ家イタリアン ラ・サレッタ',
#  'テイル・オコック',
#  'う奈ぎ道場',
#  'とら食堂 松戸分店',
#  '人舟',
#  '割烹中むら',
#  'Vv',
#  '銀寿司',
#  'とんかつビフテキ 塩梅',
#  'No Data',
#  'No Data',
#  'No Data',
#  'No Data',
#  'オステリア タナロ',
#  '川豊本店',
#  'ラーメン二郎 松戸駅前店',
#  'さすけ食堂',
#  "R's",
#  '麺や福一',
#  'Boulangerie Queue',
#  'キッチン直',
#  '山田うなぎ店別館',
#  '13湯麺',
#  '八角',
#  '麺屋 むどう',
#  'Il Giglio',
#  '中華ソバ 篤々 TOKU-TOKU',
#  'やたいち',
#  '舟勝',
#  'ラーメン二郎 京成大久保店',
#  '鶏の骨',
#  'SALONE 2007 (サローネ ドゥエミッレセッテ)',
#  '美かさ',
#  'イチリン ハナレ',
#  'ラ・ボッテガ・ゴローザ',
#  'Variante',
#  '横浜うかい亭',
#  '里葉亭',
#  'なか條',
#  'うなぎ 友栄',
#  '潟潟ヤ',
#  '石葉(せきよう)',
#  '幸庵',
#  'スイーツガーデン ユウジアジキ',
#  '佛蘭西料理 名古屋',
#  'ヴィノテカサクラ',
#  'SOLIS -Agriturismo-',
#  'シシリヤ',
#  'らぁ麺屋 飯田商店',
#  'エテ 鎌倉',
#  'スペイン料理とワインの店 arashida',
#  'No Data',
#  'リストランテ シーヴァ',
#  'オ プレチェネッラ',
#  'あざみ野うかい亭',
#  'レストランミッシェルナカジマ',
#  'レストランみわ',
#  'らーめん 鶏喰 （～TRICK～）',
#  'カンブーザ',
#  '霧笛楼',
#  'Bar Noble',
#  'リオス ボングスタイオ',
#  '牛鍋元祖 太田なわのれん',
#  '鮨 おとわ',
#  '鮨裕',
#  '埜庵',
#  'クラリタ ダ マリッティマ',
#  'Inoue griglia',
#  'PUISSANCE ピュイサンス',
#  '中国料理翆陽',
#  'おおはま',
#  '鮨 福原',
#  'TRATTORIA Fossetta',
#  'らーめん いのうえ',
#  'No Data',
#  'スパイスツリー',
#  'manna',
#  'イル ネッソ',
#  '寿々㐂家',
#  'クイーン・アリス',
#  '豚星。',
#  '貝ガラ屋',
#  'トラットリア ビコローレ ヨコハマ',
#  '九つ井 本店',
#  'リリエンベルグ',
#  'No Data',
#  '蕎房 猪口屋',
#  '割烹・蕎麦 波と風',
#  'Bihotza',
#  'ラ テンダロッサ',
#  'タケル クインディチ',
#  '御食事処スズキ',
#  '米倉',
#  'たん右衛門',
#  '古今 本店',
#  '茶つぼ',
#  'No Data',
#  'らぁめん鴇(toki)',
#  'シェ ヒャクタケ',
#  '手打ち蕎麦切り 海望',
#  'クオーレフォルテ',
#  'サラマンジェ ド ヨシノ',
#  'トラットリア ダ テレーサ',
#  '焼鳥 美鶏',
#  'らーめん もりや',
#  'オーベルジュ オー・ミラドー',
#  '天然うなぎしま村',
#  '伸喜',
#  'No Data',
#  'あずま炭火焼鳥',
#  '蕎麦 惠土',
#  '一吉丸',
#  'ジェラテリア イル・ブリガンテ',
#  '皇苑',
#  '横浜ラーメン 田上家',
#  '幻董庵',
#  'レストラン潮幸',
#  'エルルカン ビス',
#  'ムール・ア・ラ・ムール',
#  'プランデルブ',
#  'イルマーレ',
#  '梅林',
#  'ポアジェ',
#  '神奈川ステーキレストラン そうま 葉山',
#  'No Data',
#  '和食「空花」',
#  'ピッツェリア スペリアーモ！',
#  '和さび',
#  'ラーメン二郎 横浜関内店',
#  'ラーメン懐や',
#  'ホッピー仙人',
#  'パノラミックレストラン ル・ノルマンディ',
#  'オ・プティ・マタン',
#  '蕎麦 月読',
#  '本格天ぷら料理｜ふく西',
#  'サンジョルジョ',
#  'いとや',
#  '呑蔵',
#  'かまくら一平',
#  'No Data',
#  '地球の中華そば',
#  '啜磨専科',
#  '中村麺三郎商店',
#  '小田原おでん本店',
#  'ken カレー',
#  '三吉橋 小嶋屋',
#  '横浜野田岩',
#  'リストランテ ウミリア',
#  '箱根・翠松園',
#  'セラフィーノ',
#  'No Data',
#  '聘珍樓 横濱本店（ へいちんろう）',
#  'らぁめん夢',
#  'OSTERIA PACE',
#  '華正樓 本店',
#  'ビストロ ラ・ペクニコヴァ',
#  '真砂茶寮',
#  'ふぐ割烹 うえ村',
#  '料理 澤sawa',
#  '杉田家',
#  'くり山',
#  '鎌倉 松原庵',
#  '環２家',
#  '支那そば 流星軒',
#  'ラーメン 末廣家',
#  '丿貫',
#  'No Data',
#  '驊騮',
#  'ローストビーフの店 鎌倉山 本店',
#  'うまいヨ ゆうちゃんラーメン',
#  'ＲＥＧＡ',
#  'シェ・フルール横濱',
#  'つけ麺・らー麺 一酵や',
#  'うな平',
#  '日本料理 鎌倉山倶楽部',
#  '鮨富',
#  'No Data',
#  '和食 瑞木',
#  'ル･マルカッサン ドール',
#  '広典',
#  'ペタル ドゥ サクラ',
#  '寿司はしもと',
#  'ブレッド & サーカス',
#  'カレーハウス 横浜ボンベイ',
#  'トゥーランドット游仙境 横浜店',
#  'Osteria Austro（オステリア アウストロ）',
#  'No Data',
#  '蕎麦ひら井',
#  '鮨長おおさわ',
#  '纜',
#  '一游',
#  '家系総本山 吉村家',
#  'No Data',
#  '萬珍樓 點心舗',
#  '支那そばや本店',
#  'OXYMORON komachi',
#  'らっきょ＆Star',
#  '丸和',
#  '焼き鳥 末広 (野毛)',
#  '厚木家',
#  'ラ・マーレ',
#  'ラーメン二郎 相模大野店',
#  '家系ラーメン とらきち家',
#  '登良屋',
#  'ラーメン星印',
#  'TRATTORIA FRANCO',
#  '麺屋 波 wave',
#  '食彩和牛しげ吉 横浜元町店',
#  'No Data',
#  '渦雷',
#  '煮干しらぁめん 猫トラ亭',
#  '粥菜坊',
#  'つるや',
#  '手打そば 風來蕎',
#  'オシノビストロ',
#  '炭焼喰人',
#  '中華蕎麦 時雨',
#  '登茂吉',
#  'ルサロンドレギューム',
#  '焼き鳥 さいとう',
#  'No Data',
#  'オステリア イル フオッコ',
#  'The Bar CASABLANCA',
#  'ウィーン菓子 ナッシュカッツェ Naschkatze',
#  'レロエ・オヴェスト',
#  'No Data',
#  '弘明寺丿貫',
#  'スリーマティーニ',
#  '釜揚げうどん専門店 もと',
#  'カメイノ食堂',
#  '海石榴（つばき）',
#  '千花庵',
#  '北鎌倉「円」',
#  '蒲焼 國よし',
#  'お料理 とみやま',
#  '鮨まぜき',
#  'タイ料理「クルワ・プリックタイ」',
#  '阿寓',
#  '料亭旅館 いちい亭',
#  '天一坊',
#  '謝甜記 貮号店',
#  'No Data',
#  'アルペンジロー',
#  'ZUND-BAR',
#  'らー麺 本丸亭',
#  '杉作',
#  '塩らー麺 本丸亭 横浜店',
#  'とうふ屋うかい 鷺沼店',
#  'ラーメン二郎 中山駅前店',
#  'カルヴァ',
#  '神洲之華',
#  '獅門酒楼',
#  'ピッツェリアジージー 鎌倉',
#  '麺処 秋もと',
#  'ガネーシュ',
#  'No Data',
#  '横濱家系ラーメン 勝鬨家',
#  'ボージャン',
#  '鎌倉山 横浜スカイビル店',
#  'レオーネ マルチアーノ',
#  '木の花',
#  '愛知屋',
#  'HANZOYA',
#  '粥茶屋 写楽',
#  '一汁五菜',
#  '葉山ホテル音羽ノ森',
#  '箱根イタリ亭',
#  '鮨奈可久・星野',
#  'いち井',
#  '割烹 新多久',
#  '欅苑',
#  '麺屋 あごすけ',
#  '鮨芳',
#  '魚沼の里そば屋 長森',
#  'ミルフィーユ専門店 Parisパイ',
#  '麺の風 祥気',
#  'はつね寿司 本店',
#  '酒肴屋 いっこう',
#  '居酒屋山屋',
#  '焼酎と手しごと料理の店 まさや',
#  '寿し処恵',
#  '白玉の湯 華鳳',
#  'らーめん 滋魂',
#  '福実寿司',
#  '寿し 登喜和',
#  '佐渡 廻転寿司 弁慶',
#  '越後一会 十郎',
#  'むらんごっつぉ',
#  '寿司安',
#  '龍馬軒',
#  '串焼きとこころ 克',
#  '青島食堂 宮内駅前店',
#  '軍ちゃん 直江津店',
#  'レヴォ',
#  '鮨人（すしじん）',
#  'リバーリトリート雅樂倶',
#  '鮨 大門',
#  '日本料理山崎',
#  'パティスリージラフ',
#  '貧瞋癡',
#  '薪の音',
#  'だい人',
#  'No Data',
#  'ふじ居',
#  '寿司栄華やぎ',
#  '鮨金',
#  '冨久屋',
#  'No Data',
#  '鮨 つか田',
#  '廻転 とやま鮨',
#  '延楽',
#  '糸庄',
#  '寿司栄 掛尾店',
#  '親爺',
#  '富山豚食堂かつたま',
#  '中国料理响鈴(しゃんりん)',
#  'すし処 めくみ',
#  '太平寿し',
#  'SHÓKUDŌ YArn',
#  '竹千代',
#  '小松弥助',
#  '乙女寿司',
#  '志の助',
#  '一献',
#  'つる幸',
#  '幸寿し 本店',
#  '鮨八や',
#  'ひよこ',
#  'こいで',
#  'べにや無何有',
#  'No Data',
#  'きく家',
#  'つば甚',
#  '東木',
#  '鮨木場谷',
#  'らーめん そらみち',
#  '京祇園ねぎ焼 粉',
#  '飛',
#  'いたる本店',
#  '貴船',
#  '日本料理銭屋',
#  '山中温泉 花紫',
#  '味楽ゆめり',
#  'あらや滔々庵',
#  "Installation Table ENSO L'asymetrie du calme",
#  '自然派ラーメン 神楽',
#  '小料理 鈴木',
#  '鮨処あいじ',
#  '天ぷら小泉',
#  'No Data',
#  '町家懐石 六花',
#  '鈴おき',
#  'Bar Esmeralda （バーエスメラルダ）',
#  '鮨 みつ川',
#  'No Data',
#  'くろ屋',
#  '金沢茶屋',
#  '弁慶',
#  '松の寿し',
#  '鮨 歴々 近江町店',
#  'くりゑンテ金沢東山',
#  'たちばな四季亭',
#  'ル ミュゼ ドゥ アッシュ KANAZAWA',
#  '炭火焼肉大阪あじまん',
#  'すし屋 小桜',
#  '料理小松',
#  '浅田屋',
#  'ねぶた温泉 海游 能登の庄',
#  '自家製麺のぼる',
#  '草庵',
#  'No Data',
#  '滝亭',
#  '炭魚酒菜 わなか',
#  '季の肴 うきぐさ',
#  '甘納豆かわむら',
#  '川端鮮魚店',
#  '千取寿し本店',
#  'はせ川',
#  'かた田',
#  '川き',
#  '鮨十兵衛',
#  'めん屋さる',
#  '泰平',
#  'ふるさとの宿 こばせ',
#  '望洋楼',
#  'いわし屋',
#  'けんぞう蕎麦',
#  '地魚もてなし 滝の川',
#  'No Data',
#  'la Cuelleitte restaurante frances',
#  '仙人小屋',
#  '湖山亭うぶや',
#  'うなぎ専門店 井筒屋',
#  '古守宿一作',
#  'No Data',
#  '翁',
#  'アフガン',
#  '湖麺屋 リールカフェ',
#  '美味小家',
#  '専心庵',
#  '中華蕎麦うゑず',
#  'レストラン風',
#  'フォリオリーナ・デッラ・ポルタ・フォルトゥーナ',
#  '柚木元',
#  '蕎麦 ふじおか',
#  'ブレストンコート ユカワタン',
#  'せきざわ',
#  '仙仁温泉 岩の湯',
#  'うなぎのまつか',
#  '山の実',
#  '星野リゾート 軽井沢 ホテルブレストンコート',
#  '美ヶ原温泉 鄙の宿 金宇館',
#  '右馬允(うまのじょう)',
#  '明神館',
#  '蕎麦処 うずら家',
#  '職人館',
#  '鮨 いぬかい',
#  'うなぎ小林',
#  '拉麺酒房 熊人',
#  '旅館すぎもと',
#  'わらび野',
#  'レストランクララ',
#  '麺道 麒麟児',
#  '磊庵はぎわら',
#  '星野リゾート 界 松本／Hoshino Resorts KAI Matsumoto',
#  'そばの実',
#  '丸富',
#  '極楽坊',
#  'エルミタージュ・ドゥ・タムラ',
#  'No Data',
#  'エスパース・ソシアル・ル・サロン',
#  '野沢温泉 村のホテル 住吉屋',
#  'ヴィラデストガーデンファーム アンド ワイナリー',
#  'とんかつ 力亭',
#  'No Data',
#  'haluta karuizawa',
#  '蕎麦倶楽部 佐々木',
#  '山本小屋ふる里館',
#  '布半',
#  '和の心を愉しむ 渋温泉 春蘭の宿 さかえや',
#  '川上庵',
#  'エンボカ軽井沢旧軽井沢店',
#  'メインバーコート',
#  'TOEDA',
#  '柳家',
#  '開化亭',
#  '摘草料理かたつむり',
#  '仲佐',
#  ...]

# %%
# concat

# %%
import pandas as pd
original = pd.read_csv("/Users/yosuke/Github/FindGooglePlaceIDbyAddress/data/tabelog_over_3.6.csv")

added = pd.DataFrame({ 'google_name': name, 'place_id': place_id})


original.head()


concat = pd.concat([original, added], axis=1)

concat.to_csv("500.csv")

# %%
#DataFrameを定義　nameとplace_id
# df = pd.DataFrame(data=[[1, 2, 3], [4, 5, 6]], columns=['a', 'b', 'c'])

# df = pd.DataFrame({ 'name': name, 'place_id': place_id})

# df = pd.DataFrame(data=[name, place_id], columns=['name','place_id'])
# df


# df = pd.DataFrame({ 'A' : 1.,
#                       'B' : pd.Timestamp('20130102'),
#                        'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
#                    'D' : np.array([3] * 4,dtype='int32'),
#                   'E' : pd.Categorical(["test","train","test","train"]),
#                         'F' : 'foo' })

s = pd.Series([10 , 4, 7, 34, 6])
s
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-82901ab1208a> in <module>()
#      15 #                         'F' : 'foo' })
#      16
# ---> 17 s = pd.Series([10 , 4, 7, 34, 6])
#      18 s
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Series'

# %%
YOUR_API_KEY = 'AIzaSyDEbvcLE_om08N47ahjrJW1vEFpzAAwxfk'

google_places = GooglePlaces(APIKEY)
# query_result = google_places.nearby_search(
#         location='London, England', keyword='Fish and Chips',
#         radius=2000, types=[types.TYPE_FOOD])

query_result = google_places.nearby_search(
        lat_lng={'lat': 43.05527, 'lng': 141.353447},
        radius=100,keyword = '寿司', types=[types.TYPE_FOOD])

print(query_result)
# Out:
# <GooglePlacesSearchResult with 20 result(s)>

# %%
print("aa")
# Out:
# aa

# %%
# Out:
# [name         None
# latitude     None
# longitude    None
# Name: 0, dtype: object]

# %%
import pandas as  pd

file = open('/Users/yosuke/Github/FindGooglePlaceIDbyAddress/data/copyGoogleID.txt', 'r')  
googleID = file.read() 

name
place_id

splited = googleID.split("\n")
# print(splited)

for i in splited:
    number = splited.index(i)
    if number%4 == 0:
        print(i)
