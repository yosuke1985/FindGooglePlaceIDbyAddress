# %% [markdown]
# ## Google Place API
#
# ### https://developers.google.com/places/web-service/intro?hl=ja
# ### https://developers.google.com/places/web-service/search?authuser=1&hl=ja
#
# ### https://developers.google.com/places/ios-api/place-id?authuser=1&hl=ja
#
# ### https://console.cloud.google.com/
#
#
# ## Python Google Place
#
# ### https://github.com/slimkrazy/python-google-places

# %% [markdown]
# # 初期設定

# %%
import pandas as  pd
from googleplaces import GooglePlaces, types, lang
file = open('/Users/yosuke/Github/FindGooglePlaceIDbyAddress/data/GooglePlaceAPIKey.txt', 'r')  
APIKEY = file.read() 

pd = pd.read_csv("/Users/yosuke/Github/FindGooglePlaceIDbyAddress/data/tabelog_over_3.6.csv")
name = []
place_id = []
google_places = GooglePlaces(APIKEY)

# %%
query_result.raw_response
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CrQCJgEAAPObHrY3YzUG6_WQl9qvRgHFkg7hXhs8xUUboqyDCkgf3ukEE2aklZ6D3s4HOfCAjJtWDlqVUGRgHgKkDT6fLnsT7kzdzvLI53BLTPBVY4mKb8ywffg6z8QBMjEoZMtaWBaHjBxkIaZ15AKyt8fndof40mWcm5dUrdMxs9ZcMoyLIdbEDNAwIoBW_C7E0Jqk2WVeMbFCSCkARCGh1i_xuJ-O3iVpqgABsxUvrqvmWLLoXQO3U4Sb2-BOEOr7I9knBA1iQBCD2rYDg0it69oaWPRSE44La2KGlxSH_EUqbSg2kx2dr5gTAX_5i5nnn5usuQY2jxn2PVcP-tn4toGImX4AzF3Tv2_KqmOm-oXN90zN7HcRlahzEaF6pN7_7MRPbe9PBcUQPagoSejjd7z0lFISEPzeSw8NI_d421SUCehNiFEaFB4xNImxA78LnsuG87qDI3isznYN',
#  'results': [{'geometry': {'location': {'lat': Decimal('51.5202235'),
#      'lng': Decimal('-0.0740232')},
#     'viewport': {'northeast': {'lat': Decimal('51.52161052989272'),
#       'lng': Decimal('-0.07268012010727777')},
#      'southwest': {'lat': Decimal('51.51891087010728'),
#       'lng': Decimal('-0.07537977989272221')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'acfa9a465c3081aec87cf46e06d1d04cdcaa7c77',
#    'name': 'Poppies Fish & Chips, Spitalfields',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 800,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113720139114503177031/photos">Poppies Fish &amp; Chips, Spitalfields</a>'],
#      'photo_reference': 'CmRaAAAA-tuQ3bBMf9mgVRW_T6QZBZsOvUfC2O8hQribWkuFgPprgY3S8lSz6xvRx2_6Ma6BQdaHdalaz8j6hpEFOHcSeyZPtbd5f1VjiFH6zF7NQdi8luOq60YHqHBf98qIZEwbEhAXpigGmStKFRHQvX_TQH6OGhT4TLDQB97yGBiiWwjDkW7U9p8_ng',
#      'width': 1200}],
#    'place_id': 'ChIJX7eIgrYcdkgRJtmJIysIZVc',
#    'plus_code': {'compound_code': 'GWCG+39 London Congestion Charging Zone, London, UK',
#     'global_code': '9C3XGWCG+39'},
#    'price_level': 1,
#    'rating': Decimal('4.3'),
#    'reference': 'CmRbAAAA5RSxYSfdyo7zENmsPjqcRddE75iZYsFbu3Y3QOoT_VdYezj-e5TV8nx8C4fNCZhqEjrOzZkCw90tAUk4GigRsCoGqlvIsR4ULEPfTBupVzYDwKyWGHdDSifvIeBh9lRWEhAhFT8wLBs5rHzA2mJwDfGlGhSyXLLfITRTRv-IY9ALF8zoR1-ipQ',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': '6-8 Hanbury St, London'},
#   {'geometry': {'location': {'lat': Decimal('51.5409757'),
#      'lng': Decimal('-0.1439713')},
#     'viewport': {'northeast': {'lat': Decimal('51.54226062989272'),
#       'lng': Decimal('-0.1425830201072778')},
#      'southwest': {'lat': Decimal('51.53956097010727'),
#       'lng': Decimal('-0.1452826798927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'e0715c3d882f1db32231494d012b7459d7fd8ab9',
#    'name': 'Poppies Fish and Chips Camden',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101703475998391445096/photos">Ivana Mercuriali</a>'],
#      'photo_reference': 'CmRaAAAAW9vKNaSD2nX-hfml1wflalgDe-usnlaiKTfLkMKgfTPt5e8tr_znKN4vjwSzr0au5cc1iie-nDun87Z-hITTJfT7bYH8dCZKeSkaytFefCYZTUV0oNHn7qva4Y1gDAYeEhDZGAqTvcvRoOrh5fg7c1iOGhReMq89_N51S5x4XsC9lLxFbODQcw',
#      'width': 5312}],
#    'place_id': 'ChIJGZ-kgeEadkgRrmwbc4LrXGI',
#    'plus_code': {'compound_code': 'GVR4+9C Camden Town, London, UK',
#     'global_code': '9C3XGVR4+9C'},
#    'price_level': 1,
#    'rating': Decimal('4.3'),
#    'reference': 'CmRbAAAAltZCqf0X_eaAi_WC1Gsevg9yWq0gJ-qnzWz2mIcVoWSRBbalDD-y1qMTYoOmx5JAbkVi7yggUtMG9OpKydBSWFJCrlsSPXbQCzoZFxFmsk9KeUPBgwP7I25UxNs3LHpMEhCeSkmvMthyQnITKxNaG0BLGhSnS08QdTfMgnjd6mSRZmHWg9rxYA',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': '30 Hawley Cres, London'},
#   {'geometry': {'location': {'lat': Decimal('51.516583'),
#      'lng': Decimal('-0.187945')},
#     'viewport': {'northeast': {'lat': Decimal('51.51795807989272'),
#       'lng': Decimal('-0.1865039201072778')},
#      'southwest': {'lat': Decimal('51.51525842010728'),
#       'lng': Decimal('-0.1892035798927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'a3ffdcb1013a65fb4b4f2937eaf73b842afa1e32',
#    'name': "Hobson's Fish & Chips",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3307,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108347313474104880678/photos">Hobson&#39;s Fish &amp; Chips</a>'],
#      'photo_reference': 'CmRaAAAAx8eBcgmJ8_QZe8bqKPE10ia8KUMgg6UhC8COu4t6fr36WzMuFCvZ20V7qehzC71YzheJcg_PUQ7fs9cxsozYmaVstC3z3m3OnwbRKV7tnla5yGg6_PwFuZ1FYhiT6KRNEhAzqIxk7fTPk64rTalkl_a9GhTtJub79V2q3UBHt6LI9qgkMU01HQ',
#      'width': 5022}],
#    'place_id': 'ChIJi1a_naoadkgRpmgQ8gWTT54',
#    'plus_code': {'compound_code': 'GR86+JR Hallfield Estate, London, UK',
#     'global_code': '9C3XGR86+JR'},
#    'rating': Decimal('4.3'),
#    'reference': 'CmRbAAAAIOuts8A3CbBORAYY-1jDjm7lOI4kRkM8G6-XlBpqemlOUJH7ilpOsa-p896DmLxhlky8mofCb2SFDp74AG0G5Hm5jRIdm0pS4TaH-MpF5OeGtJ1agrFvbQ7GFbTwe3f6EhBz3kZGT6DMbo6CgxWAIxEUGhRsrlX9Ba-vQ3hYIFg5gKLVNdLdBw',
#    'scope': 'GOOGLE',
#    'types': ['meal_delivery',
#     'meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': '9 Porchester Rd, London'},
#   {'geometry': {'location': {'lat': Decimal('51.470954'),
#      'lng': Decimal('-0.210788')},
#     'viewport': {'northeast': {'lat': Decimal('51.47228547989272'),
#       'lng': Decimal('-0.2095138701072778')},
#      'southwest': {'lat': Decimal('51.46958582010728'),
#       'lng': Decimal('-0.2122135298927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '516c26014819a47f89857f0f7ba3f2700f4a6cea',
#    'name': 'Fishers',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101456829970215111932/photos">A Google User</a>'],
#      'photo_reference': 'CmRaAAAA_POwAhc1Jx-baw0wAMKt2YS-wW8dDwshowYv1jMyB8nCDF3E2SLVB_Mie_QPDi0hinmkdV_NjBNRNY7JXd08KiMN3tNTryHJtIG0fxrQXKT0XvuBUkbjc-zVyJiYCmoGEhDYonhIStxhOP13Hr4iTFpjGhQarar1928-X_pxQJBCyEhgu6QV1g',
#      'width': 4032}],
#    'place_id': 'ChIJbfhNMHUPdkgRuFpD4GATdQQ',
#    'plus_code': {'compound_code': 'FQCQ+9M Fulham, London, UK',
#     'global_code': '9C3XFQCQ+9M'},
#    'rating': Decimal('4.8'),
#    'reference': 'CmRbAAAASbj8ewvdozs-sTbxI8VHEhTKGlZXs1d0NSspub9uWwDiMCPAzC22RfPXBA9RVJtAMTHZmmQzY-k06lLRRraOefk0jYe18d769X5Cq5hdYjdr66_qItm2joCKRqACwTOOEhAnxM6ok0H7BZNP2vRxG4hBGhRYyd51BeAjNr3EzFbHPPN-e-mtkw',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': '19 Fulham High St, London'},
#   {'geometry': {'location': {'lat': Decimal('51.546799'),
#      'lng': Decimal('-0.158716')},
#     'viewport': {'northeast': {'lat': Decimal('51.54819152989272'),
#       'lng': Decimal('-0.1573169701072778')},
#      'southwest': {'lat': Decimal('51.54549187010728'),
#       'lng': Decimal('-0.1600166298927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'bab53620edb6cf4daf2122ee7f47827d963ba0a5',
#    'name': "Oliver's Fish & Chips",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1026,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117775761624809833603/photos">Oliver&#39;s Fish &amp; Chips</a>'],
#      'photo_reference': 'CmRZAAAAMevEyP2k19FPjQcP175DscSLG2imkdAfsq0F_x1EXTDv2yPZAKsmz7esRokQY09UigP5rAJ_uDHFbkl31AV9UVXJ6YQiqDDXRTGlpzoT1YIUGpNyN5qcLWHC-8yzhcpWEhDkyu52gw-qq-HT0Wxaj19bGhT_sVbUA3DAc1Erxxe_PPnkXnIMZQ',
#      'width': 1248}],
#    'place_id': 'ChIJn8hI__EadkgRUaIJ8jj2CuY',
#    'plus_code': {'compound_code': 'GRWR+PG Belsize Park, London, UK',
#     'global_code': '9C3XGRWR+PG'},
#    'rating': Decimal('3.8'),
#    'reference': 'CmRbAAAALEaUTocF0Miww09gcA3e3OnujBMxmkOwvHAJOklIbzsP86XgOL7QZ5BgGk1AaGodmccO7BwGX-SuzjTal5Z9ewIinbZFAXp6GA1qqJ6ImRxMon2zIhqw0mMcAmELDGQfEhA4aLjPfPhFZBq_ZQWeb1UbGhRfSHtnSgiCiKi1rL1WA2gflA_nqw',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': '95 Haverstock Hill, London'},
#   {'geometry': {'location': {'lat': Decimal('51.5154662'),
#      'lng': Decimal('-0.1266079')},
#     'viewport': {'northeast': {'lat': Decimal('51.51682752989272'),
#       'lng': Decimal('-0.1253420701072778')},
#      'southwest': {'lat': Decimal('51.51412787010728'),
#       'lng': Decimal('-0.1280417298927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'd2525112bb835bcababd2bf202bc50fe3f002b17',
#    'name': "Ben's Fish and Chips",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115974245653876916196/photos">Ben&#39;s Fish and Chips</a>'],
#      'photo_reference': 'CmRaAAAAFxWYanEZWNe4xRE65QLtwjXBV4rL-Wb57t61Ku0bCjmxBPqkwzrafk7qCxNFNp3veH5p7ycIBgzwBrYhc9h99uU7DiMAHPWOuMMYD6BfBiqD_UN0VFM5iDHn06lpT7sGEhAifASu8FPEG1sQIm9lOXbZGhSBa8alQo4MdTGT8Lpqbs27sg_YFw',
#      'width': 1280}],
#    'place_id': 'ChIJoa4D0TIbdkgReCX9s-aeLos',
#    'plus_code': {'compound_code': 'GV8F+59 London Congestion Charging Zone, London, UK',
#     'global_code': '9C3XGV8F+59'},
#    'rating': Decimal('4.2'),
#    'reference': 'CmRbAAAA-BiFoIcZqQT8QCBRO0Jcv6OptwUsVgdiOh_RDE7JZ37rf9d6G4QJnVyEzh-B7z2TFJwx85CHRHrePo2NGmt3lPzTQaet4lkHDJgVds5P1RPVR6ogc01MLGuZVCpxXFmVEhBw7CyrPAgT990DDXejvLE-GhS7sJgaZOUIIkfpE_lm5sL8n-h8eQ',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': '200 Shaftesbury Ave, London'},
#   {'geometry': {'location': {'lat': Decimal('51.508576'),
#      'lng': Decimal('-0.0789175')},
#     'viewport': {'northeast': {'lat': Decimal('51.50993752989271'),
#       'lng': Decimal('-0.07761102010727777')},
#      'southwest': {'lat': Decimal('51.50723787010727'),
#       'lng': Decimal('-0.08031067989272221')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'bf5ab88cff71258010409524df3635f1cb7b001e',
#    'name': 'Josef Fish Bar',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107315737977257512093/photos">Aaron Bayes</a>'],
#      'photo_reference': 'CmRaAAAAcJV34wVe9XaZJdkK7sR6H9tqzr0s1CG9qOUswiOy_ph0iU_9WLWC9z2llwssuDq1-nC5dVNvMjJXQNNqwpmhpwOHZ6PeZ2JHbkj0i4UKmWsb1gayoD0oUERbcMHMwkYmEhC_fn9S0ec1zcZEutTNPt3EGhSVnM5OWcAZ_C99GmYsNcBWlJUdDg',
#      'width': 3024}],
#    'place_id': 'ChIJXd72jE4DdkgRcW9HZS_0QTc',
#    'plus_code': {'compound_code': "GW5C+CC St Katharine's & Wapping, London, UK",
#     'global_code': '9C3XGW5C+CC'},
#    'rating': Decimal('3.9'),
#    'reference': 'CmRbAAAATHEJvxkVujpHq1yYTyYjB5flhMAeNe84i8zx_y5tKUqS34TNysF3ALj9M9SUUBAtsuZbeKsIMzUAtRU6VSXobCqiMpjcdAIqAHqvveYN7S5qOPRb3zV-kf7no2QQ-Hp-EhCJENr3ICI13yYQBHHwB_VuGhRe5BwDx2MBZ76OlRlHVEwzIvcgrw',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': 'Petty Wales, London'},
#   {'geometry': {'location': {'lat': Decimal('51.5029253'),
#      'lng': Decimal('-0.1193358')},
#     'viewport': {'northeast': {'lat': Decimal('51.50427512989273'),
#       'lng': Decimal('-0.1179859701072778')},
#      'southwest': {'lat': Decimal('51.50157547010728'),
#       'lng': Decimal('-0.1206856298927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '02c49ec019f35268b224411251bbcdcb6b8f771e',
#    'name': 'Great British Fish and Chips',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1152,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110009474383680176949/photos">Fabian Klasnic</a>'],
#      'photo_reference': 'CmRaAAAAebrL8lMox8EcJFDwgW99yjdeejGLLd7f6z-o9FCZU-fPLmMFkWH-JEN98PfO_h8thbByfq5AbyL4tvZYvySElJotQAxxEQ8rLStiTiP05LEyUvo8U9swcZUmgdbvdn99EhAjpJzvLuLgn-qcsUAxER4vGhTHfDSrvh01IoDZGbnq_8QWe7iuzw',
#      'width': 2048}],
#    'place_id': 'ChIJ45vrx8cEdkgRndjF0KpLsFI',
#    'plus_code': {'compound_code': 'GV3J+57 Lambeth, London, UK',
#     'global_code': '9C3XGV3J+57'},
#    'rating': Decimal('2.8'),
#    'reference': 'CmRbAAAAm1xfCoIPp10oZQ0e3H4Plxwya_TCLNSHSaNMB3n7D4OQIRdsldyknyIk86Ya1FUhkm92oFHp-lrGW01TtZUK5fgMUlJOXQ5gkx8pWrsQFL_O7MyLO1T19eUCK_4_KAIMEhACHV3z16UHz4GtjvwTfZAAGhRnspgnZOyC8wxXI2M_YTD68gKMnA',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': 'Westminster Bridge Rd, London'},
#   {'geometry': {'location': {'lat': Decimal('51.51023199999999'),
#      'lng': Decimal('-0.197502')},
#     'viewport': {'northeast': {'lat': Decimal('51.51159732989272'),
#       'lng': Decimal('-0.1960671201072778')},
#      'southwest': {'lat': Decimal('51.50889767010727'),
#       'lng': Decimal('-0.1987667798927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '6773c4180ef0ec6656cdb7cfd76c1c238b18b665',
#    'name': 'The Fish House Of Notting Hill',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 608,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110631561894058247933/photos">The Fish House Of Notting Hill</a>'],
#      'photo_reference': 'CmRaAAAAGThjm4G8JAKfSoC2YYzedsAbNPd9VRQbrskUrx9BiC5uNamitlyj3lOChFxLCHK6S7fBiwbFCTIOBbV9LEWGW-tAqeIvr1ZzHEqhVF1pNzbv8yfNmy7prtENm4S_smqpEhCA5RGi317hRqY7MN_RiOCTGhTKnKiYZCNnRNg658ZpoW8jURMgjg',
#      'width': 1080}],
#    'place_id': 'ChIJ-STNj_wPdkgRB0P_xZi2YwM',
#    'plus_code': {'compound_code': 'GR62+3X Kensington, London, UK',
#     'global_code': '9C3XGR62+3X'},
#    'rating': Decimal('4.4'),
#    'reference': 'CmRbAAAA4Vg6hfls7rnj-5jndKAAolrOAZSqmuDirmZAkZGGY6twA1wjqKMhrTA_VPk6fRx893wJeeU41UYX0Lhxe8htX7j6OTF4qv9cWR5G5moE5vtiDlO2cPXH3OQaIt-fqf36EhD3Zqz1pJGemHaTFgeMkH2KGhQnnU8w2BtdbdCXINeVwXoNvZKavQ',
#    'scope': 'GOOGLE',
#    'types': ['meal_delivery',
#     'bakery',
#     'meal_takeaway',
#     'store',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': 'The Fish House, 29 Pembridge Rd, London'},
#   {'geometry': {'location': {'lat': Decimal('51.546569'),
#      'lng': Decimal('-0.055632')},
#     'viewport': {'northeast': {'lat': Decimal('51.54796642989272'),
#       'lng': Decimal('-0.05429007010727779')},
#      'southwest': {'lat': Decimal('51.54526677010728'),
#       'lng': Decimal('-0.05698972989272221')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '3455ebab4e1dc672230a9fe0f290880734f905a2',
#    'name': 'Sutton and Sons Fish & Chips',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2048,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115020626239535731031/photos">Sutton and Sons Fish &amp; Chips</a>'],
#      'photo_reference': 'CmRaAAAAekrXYCqLg11tEDRktE51By2T91wtEpAGsm8fbj2OdZSET-CkOeq6RllwsvJ3KdsaiXjSh5H9BokxHxNzkjA2cdzZZjLoigU-0px0gi2IzQ_KimbgA2nS7ogk6l7_Pvp4EhCS7tv-VOxgyhUySunY6Q52GhSWUNQ2wAQgTBLV9F0Yq6p6y8k7jQ',
#      'width': 1364}],
#    'place_id': 'ChIJGSXWKvscdkgRWK8sRPaQC9M',
#    'plus_code': {'compound_code': 'GWWV+JP Hackney, London, UK',
#     'global_code': '9C3XGWWV+JP'},
#    'rating': 4,
#    'reference': 'CmRbAAAAZ4RFJaWsVkpXOmQtHu2cgR1qQGKXxXrK6Ndn-DaBdCesOBg5uq38KjPbskFpENndcpELAbDv0Eo5vNM5gWkUdK6ihtSmBE_2ErUaqjplwnw4Pq6ZxMNqmwGXC0WF9acMEhBUuHTkxN20ZPbulJSdAkK_GhQOvlyAQ8uIEIHDxHIHdVbR2hMT6g',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': '240 Graham Rd, London'},
#   {'geometry': {'location': {'lat': Decimal('51.514834'),
#      'lng': Decimal('-0.125309')},
#     'viewport': {'northeast': {'lat': Decimal('51.51617292989273'),
#       'lng': Decimal('-0.1238344201072778')},
#      'southwest': {'lat': Decimal('51.51347327010728'),
#       'lng': Decimal('-0.1265340798927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'da51233b8235420861e4a5cf60a98851f13228a7',
#    'name': 'Rock and Sole Plaice',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105345856816834178315/photos">Nundou</a>'],
#      'photo_reference': 'CmRaAAAAHZpY5vCUo45D6ixkjR9g4UZPCMvWYJuWpVgoXoAfnMO_DfUh7h6kQ1qnHPIXPNseFk9nGOTPeEs6SI_jzrBDimGeW_ot2wkT5rCeczvUpuMO1h5leitBOAhtvab03FziEhBjZCb01NY56QTdw4acXNE0GhSyHBccpsUABqjvPkT0nyttVIMYtQ',
#      'width': 4032}],
#    'place_id': 'ChIJ6wsgLTMbdkgRObEIyzQf10g',
#    'plus_code': {'compound_code': 'GV7F+WV London Congestion Charging Zone, London, UK',
#     'global_code': '9C3XGV7F+WV'},
#    'price_level': 1,
#    'rating': 4,
#    'reference': 'CmRbAAAADwCdkahmdwO1aP9-jDs7_V1sDGWLJ7CgCStyFc47ct3XiP2xFtjX_pIw3FDojhC1cWSasICKY-yGNr9-u1fBcCG9Jj-t1Xqw8RGsYhRdzuUVrqvSMHs4gr5xBUWoUL6TEhBdhSPOm9NWLDBSrlw_gSPeGhTxZmw3ikF11XRs2XSlPNpdQwkrlA',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': '45-49 Endell St, London'},
#   {'geometry': {'location': {'lat': Decimal('51.5169125'),
#      'lng': Decimal('-0.1728106')},
#     'viewport': {'northeast': {'lat': Decimal('51.51829112989272'),
#       'lng': Decimal('-0.1714087201072778')},
#      'southwest': {'lat': Decimal('51.51559147010727'),
#       'lng': Decimal('-0.1741083798927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '2d5729301df5f448b6fb7f725f52c3d3005c5b89',
#    'name': "Micky's Fish & Chips",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 413,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111156056387931152354/photos">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAGHFbNBo6VWlO6hP_sfuPkVYZdQQJpaTFA0BSoKjYD72inVlyz7VMEIuSADz7lGA7zimd91kZ6lFjsEylunvqrVY8K_50s8lbsS2AmOv3LijU0A6J6AGZEVtm2MtFyKF4EhA6ASBBBiONuYvXOKhVgwVfGhTqlPQqctXtfFA2AlQczMU5n6Tk9A',
#      'width': 550}],
#    'place_id': 'ChIJuXHeBLMadkgRdaZ33XZZspM',
#    'plus_code': {'compound_code': 'GR8G+QV Paddington, London, UK',
#     'global_code': '9C3XGR8G+QV'},
#    'rating': Decimal('3.9'),
#    'reference': 'CmRbAAAAp78uUIU-tWZCfxl-E1t7zj2COy4H72lCDshPUj7HKLVkBxe7-jN3BeDriD4U4pvrs-DjRHykQguI_-ZZsnz1jUlChTuW045OxI-mdcWGlNMUwbE-AdjPnIxKhR7nPm-IEhDx0Bs25EdcKL08V4hwVX1DGhRIxzs0T0nnQ_DDWTTSzM4GPvF2OQ',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': '29 Norfolk Pl, London'},
#   {'geometry': {'location': {'lat': Decimal('51.5165109'),
#      'lng': Decimal('-0.07496029999999999')},
#     'viewport': {'northeast': {'lat': Decimal('51.51786072989272'),
#       'lng': Decimal('-0.07361047010727777')},
#      'southwest': {'lat': Decimal('51.51516107010728'),
#       'lng': Decimal('-0.07631012989272221')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '43029b78b00c4f252b6197a1035f38412769a8f6',
#    'name': 'Happy Days fish & chips',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1837,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108322329337197298760/photos">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAUtIB8amCkyVeqQRbZkp2BlblnX0h47PZzFV09QN8nLMg5nPT_0S23KPL-VTbs_mdESv0HIr2BAiEBsciCG1QdHaQ3Hc4voq1JtVCvD_Ji197tfyf7qsuKzraYAieOLEdEhB3QKVXUq07xyFKhVkvFjUjGhRMh63mCJ3Gqxcr5PJF8Q8YnHNAGw',
#      'width': 3264}],
#    'place_id': 'ChIJGzBdlrQcdkgRdxWH8XqOP-8',
#    'plus_code': {'compound_code': 'GW8G+J2 London Congestion Charging Zone, London, UK',
#     'global_code': '9C3XGW8G+J2'},
#    'rating': Decimal('4.3'),
#    'reference': 'CmRbAAAAukCmCYW6mGS2WYQTqBlHglxKqXOnnJ7yV9tXKDs-JhSB2WjnC_Y4WWQ_SRhmKaoT_-eX7m-B4DGTRIo60JZRzvbZ67FAKLOqEj3TCmqpopEekb4L3KWImKmADkqvy-hxEhAOv3O4_-o2HT_sRhGFjCFMGhSO0ieloGeEB8LsqkJTyre-Dr36kg',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': '44 -46 Goulston street, London'},
#   {'geometry': {'location': {'lat': Decimal('51.487695'),
#      'lng': Decimal('-0.1411474')},
#     'viewport': {'northeast': {'lat': Decimal('51.48908897989272'),
#       'lng': Decimal('-0.1398142701072778')},
#      'southwest': {'lat': Decimal('51.48638932010728'),
#       'lng': Decimal('-0.1425139298927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'b3e3615f0cc1efba2d22dc4acaf60433a2cb63e8',
#    'name': 'Pimlico Traditional Fish & Chips',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113795129168498000286/photos">Al Bigalex6</a>'],
#      'photo_reference': 'CmRaAAAAnXzyejCYyXCcVdDU-g0-0nkjNXC8EgQM7RBTVX6RpWfc-JwhLGjAKg1C5dj5d5G8SPpug3jhc8-j1NLUeBHA3Rxpt6HjE7mY3efORI02cZW4utGuqcpe3ta9-2o2FNVtEhApQA0vmNyOICVOES30QSsdGhTL-faet7JVVLHze7iqrBqmhCmlcQ',
#      'width': 5312}],
#    'place_id': 'ChIJ13iW7R0FdkgRbeLbYNW0dJA',
#    'plus_code': {'compound_code': 'FVQ5+3G Pimlico, London, UK',
#     'global_code': '9C3XFVQ5+3G'},
#    'rating': Decimal('4.3'),
#    'reference': 'CmRbAAAAN1grj4MqE4t9h7k59vzd7Q_-qMo2abb0MKK44VIHpv5NlVvZGwQXN9SJur9JzHhfls4QZqesEYCA1a3c-5Se110KCpsbC5UabyeIyilYxdS8pf5R04d9PV3xlYK6Q1sAEhAwlyzg6x4bAe0xPtnBDkOUGhTCviCwCJsPOsPm1dCsOo6Nb14SQQ',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': '103 Lupus St, London'},
#   {'geometry': {'location': {'lat': Decimal('51.5216583'),
#      'lng': Decimal('-0.1575309')},
#     'viewport': {'northeast': {'lat': Decimal('51.52302842989273'),
#       'lng': Decimal('-0.1560693201072778')},
#      'southwest': {'lat': Decimal('51.52032877010728'),
#       'lng': Decimal('-0.1587689798927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '11e7c31c4ff5e63f3035a921741aa84300a72a5e',
#    'name': 'Holmes Fish and Chips',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103181796608472089043/photos">Jennie Tu</a>'],
#      'photo_reference': 'CmRaAAAAYG_RL0MyPFM7BZtOAlB5zstwMPcjY1zul3WS8e6xOtu71X3eXcPgNJqdd8vpzSIMOOdW_u8kV3DLem5U284wscrNFU7nxZqnjSR3vdixVVFWhlGax-cKXDgaEn5BZ2zwEhCno-rZOCm6ZDP_Lav7ObcUGhQVCEdkApQw7RbEjeY_VXfmDt4kZQ',
#      'width': 4032}],
#    'place_id': 'ChIJaQTVwM4adkgRIiyjKltNcAE',
#    'plus_code': {'compound_code': 'GRCR+MX Marylebone, London, UK',
#     'global_code': '9C3XGRCR+MX'},
#    'rating': Decimal('2.7'),
#    'reference': 'CmRbAAAAKuMFHvZ3qanFEaoGO-b7RTp0t1dBJIt3oXeCVxWGH9DM85LxE260sZ-uaswgSzyk4tVYeA78-kfPCfCLh99M8x0xcTGtMJYGavfAMGlG-dp-cMEmPK26YAdH1mhUK7ZNEhCq8c7YaGsyUT7FkF_0Nz7lGhTLlswBGGrIKnR-ez3TynqPFGB1ZQ',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': '123 Baker St, London'},
#   {'geometry': {'location': {'lat': Decimal('51.5335543'),
#      'lng': Decimal('-0.1093253')},
#     'viewport': {'northeast': {'lat': Decimal('51.53486087989272'),
#       'lng': Decimal('-0.1079660701072778')},
#      'southwest': {'lat': Decimal('51.53216122010728'),
#       'lng': Decimal('-0.1106657298927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '2436c5da35c23b65acd4399c275e6709401bfcfa',
#    'name': 'The Crown Fish & Chip Bar',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107194509413349445109/photos">Chris Starkey</a>'],
#      'photo_reference': 'CmRZAAAAGAnmNBXnS1fzsibn0z1M3hLpeSCz3KpheomG5Xl6yc5vzqWvFXzD1gFpHBbvWedHfE5EUObGh58Qkg3CtON7npdPDzWchocObqwQOaKIaHmNaRZcyKigPhGyAAlbt-RSEhAo6_q4sxWq78S5wkJ0nVSjGhSf3sj12tdV9q1rCltX96hh1uIWWA',
#      'width': 3120}],
#    'place_id': 'ChIJM3FeUkIbdkgR8rvVJOFqDEY',
#    'plus_code': {'compound_code': 'GVMR+C7 London Congestion Charging Zone, London, UK',
#     'global_code': '9C3XGVMR+C7'},
#    'rating': Decimal('3.7'),
#    'reference': 'CmRbAAAAr3Z0a6EPqlXftUwvqglPdGapzy1s6Ds6mWqu7QgF9ljrLFN6FUrIg611oxWOuWAZwH3MlhjLGhzgrKPsEeHgDr5vtZmW_el1yXnhBig9Wvj_qBqedOZYS4eMCuKRvcKIEhDCGUfPmIJt-ohSMX8igMthGhSQCg5nopymj_7ChAjd3LJSTZhVjg',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': '20 Chapel Market, London'},
#   {'geometry': {'location': {'lat': Decimal('51.5153659'),
#      'lng': Decimal('-0.1375995')},
#     'viewport': {'northeast': {'lat': Decimal('51.51673587989272'),
#       'lng': Decimal('-0.1362170701072778')},
#      'southwest': {'lat': Decimal('51.51403622010728'),
#       'lng': Decimal('-0.1389167298927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'a2b9f1d66f9cbd3ba957b27ae2c6e0512d57c164',
#    'name': 'Golden Union',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113108178010213795598/photos">Tomasz Bobrowski</a>'],
#      'photo_reference': 'CmRaAAAAVERzsAClgjU_303dEHArAlfySceDXNJYvVaXDHe9Fpapg_2gxrOAz5H0Vn71VY1ejGkd2BLrQgGykDeOQ0N3R9Y62mxA62rGgdU7ZuY9NMBqP42TKjj6PBDFd-TgBhaqEhCyFQRZoH33NZBkIXEbr62sGhRVcv_f-311tto9XKxsPZ7KOkVNbQ',
#      'width': 4032}],
#    'place_id': 'ChIJLZnILisbdkgR1ok3oOdfcl4',
#    'plus_code': {'compound_code': 'GV86+4X Soho, London, UK',
#     'global_code': '9C3XGV86+4X'},
#    'rating': Decimal('4.3'),
#    'reference': 'CmRbAAAAbQilGA8saa7cqlddT5OObaEs-z5C4pP3Dl67MrB_O5e9VOq158Lhek3OGtMSSTcttDiF7on6l_NDREuYzReOdcV9RT4RyD3RGdiiDagyuYbUwUDQWk7UuH5OdbHrcthsEhDDxWJr7ZdkC-xwn_ZQs_OFGhS_OaQiQxEP3e00WDxvtReLPaMJCQ',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': '38 Poland St, London'},
#   {'geometry': {'location': {'lat': Decimal('51.398301'),
#      'lng': Decimal('-0.091069')},
#     'viewport': {'northeast': {'lat': Decimal('51.39960582989272'),
#       'lng': Decimal('-0.08968967010727778')},
#      'southwest': {'lat': Decimal('51.39690617010727'),
#       'lng': Decimal('-0.09238932989272221')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '2f28018839047b210884193015afe0626388c904',
#    'name': 'Doneagles Fish and Chip Restaurant',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107162602736311473705/photos">naif iseri</a>'],
#      'photo_reference': 'CmRaAAAAUmb14m5ie6g1fiKhlaWrsVmN8yR3Djzn_XSw7UTO_yvd4f9sbKaNZvEezGAiZGoEFwY_udkKKL0Ri7_gqgrZUuKINkN-Bb54bVL8JbT374g3Ip9jB8Kx0FLOmyBm7uzNEhBKolDUvMw0MMALrdXwuI62GhQ0_8LdM1CLxZ8pQDYv5FTbvqj2zg',
#      'width': 5312}],
#    'place_id': 'ChIJC4sXtTwBdkgRfjAEgGj-gPU',
#    'plus_code': {'compound_code': '9WX5+8H Thornton Heath, United Kingdom',
#     'global_code': '9C3X9WX5+8H'},
#    'rating': Decimal('4.1'),
#    'reference': 'CmRbAAAAxae6xehRTDTkQwQtgkiwVgQ1zb4Ip7cLzoeDquqrKdE22If0Q9fP9qD-w-oIIH5wU3bc2iKbtK9BcWIZ-_kTSFXXCGJFgRQWA0rlJiqQRQD3zR7Lt6HOklpcw9Go-IEhEhBDLGOcbPXxX_0k6IpaL02aGhThz7yVzbdTj0fRBEuNNFbb6rZsMw',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': '31 Whitehorse Ln, London'},
#   {'geometry': {'location': {'lat': Decimal('51.35095459999999'),
#      'lng': Decimal('-0.03804449999999999')},
#     'viewport': {'northeast': {'lat': Decimal('51.35230442989271'),
#       'lng': Decimal('-0.03669467010727778')},
#      'southwest': {'lat': Decimal('51.34960477010727'),
#       'lng': Decimal('-0.03939432989272221')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '904d8085ada13dd7d4b7d5ce64fb5fff656b668c',
#    'name': 'McDermotts Fish & Chips Ltd',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106206299887312619326/photos">Katryna Craigen</a>'],
#      'photo_reference': 'CmRaAAAAW71ONegUrKYmlA0zgAIOkZh17-Vm8ESx3jNlB9zQCUcAT1p0cqRJ0BUWjrf5zPTykpIFctRiFIPs0eAYVsYa7QSv0zb-CYCdBY71wh6NSV3lTdmf5mgOJ42FSfR0dYCGEhAsQ2nsK7veZKYs414YOr0mGhQskMyECIZaXj768Cj9TuRFqc9-mw',
#      'width': 4032}],
#    'place_id': 'ChIJaZzBCnkAdkgRNHOs5snGmcE',
#    'plus_code': {'compound_code': '9X26+9Q Croydon, United Kingdom',
#     'global_code': '9C3X9X26+9Q'},
#    'rating': Decimal('4.7'),
#    'reference': 'CmRbAAAA9FUlrBwZPJ_61ebFTGxohmlWy1QkJ3utETjwKsAFbvJBZ3WDYeeoA12pWHkunp-HtXpy1l3s4iWwNRRe7f4p1ZuHCrqoXigYhsgI8UcEbMqIVQ_GeKxJmoM6ooW3x6FoEhBgHon1cuFLcWdmmhu9RShcGhQFgtBsdQ22jFtjyTxfVzkt3HoJag',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': '5-7 The Forestdale Centre, Featherbed Lane, Croydon'},
#   {'geometry': {'location': {'lat': Decimal('51.5227185'),
#      'lng': Decimal('-0.165802')},
#     'viewport': {'northeast': {'lat': Decimal('51.52410552989272'),
#       'lng': Decimal('-0.1643835701072778')},
#      'southwest': {'lat': Decimal('51.52140587010727'),
#       'lng': Decimal('-0.1670832298927222')}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '13f96a067610d08b4cf2d87f3f93baeef419d759',
#    'name': 'The Sea Shell of Lisson Grove',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1586,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115644855879760634317/photos">The Sea Shell of Lisson Grove</a>'],
#      'photo_reference': 'CmRaAAAAEDNMkYasviFAfFLXrXKhgXUnESRQyMrD7XXMket9tB1WyMSo6lcuEZInZTdnUjNyy0GoXEnY8XC5esTz79qdQwuWzA3hrMdCVL6_zwza8qNlnr7NlGtXy2RJ6iAI66tTEhAeTGRsaGzlJ7O2rMvsec-IGhQlkr2PTVW-juI0XBHIwRtXSI7wkA',
#      'width': 2378}],
#    'place_id': 'ChIJZ7rcNLYadkgR9MFSAbGgQu4',
#    'plus_code': {'compound_code': 'GRFM+3M Marylebone, London, UK',
#     'global_code': '9C3XGRFM+3M'},
#    'price_level': 1,
#    'rating': Decimal('4.2'),
#    'reference': 'CmRbAAAAPPG_NoTb8tQGnXssQKxOrVTaVDIHfzengSB_TuzBw0olqd2lp0jLFfG5eBRnDNbLowOAmnkTDEBJUlJLzYZYc-vBBN_rD_7iK00u3U8FfpZptZOC1CzF1Pldr3DakjAWEhCLUCzpzc1mnRGxHZz9FiUHGhRsO2AxFbVN1jYnSqlBuh4D3PyaMQ',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': '49-51 Lisson Grove, London'}],
#  'status': 'OK'}

# %% [markdown]
# # Google Place API

# %%
def get(s):
    info = []
    for i, v in s.iteritems():
        info.append(v)
#     parametors => https://developers.google.com/places/web-service/search?authuser=1&hl=ja

    print(info)
    print("yes")
    query_result = google_places.nearby_search(lat_lng = {'lat': info[1], 'lng': info[2]},\
                                              radius=1000,keyword = info[0],language = 'ja',\
                                              types=[types.TYPE_FOOD])
    
    if len(query_result.places) == 1:
        print(query_result.raw_response['results'][0]["name"])
        name.append(query_result.raw_response['results'][0]["name"])
        print(query_result.raw_response['results'][0]["place_id"])
        place_id.append(query_result.raw_response['results'][0]["place_id"])

    else:
        name.append("No Data")
        print("couldn't get")
        place_id.append("No Data")
        print("couldn't get")
    
    
    
pd.iloc[5000:5211][["name","latitude","longitude"]].apply(lambda x: get(x), axis=1)

original = pd.head()
# Out:
# ['チャイブレイク', 35.69856333, 139.57959830000001]
# yes
# チャイブレイク
# ChIJKbG7LEjuGGAR6jg7XGQVbuk
# ['ビストロ ハッチ', 35.70103686, 139.5790879]
# yes
# ビストロ ハッチ
# ChIJf7tNGknuGGAROlvqrqZtBfc
# ['リュモンコーヒースタンド', 35.69805389, 139.5867039]
# yes
# リュモン コーヒースタンド
# ChIJITxLMDnuGGARKgK4ZPMbbyA
# ['阿部', 35.69417851, 139.58539050000002]
# yes
# couldn't get
# couldn't get
# ['トニーズピザ', 35.69811722, 139.58433]
# yes
# トニーズ ピザ
# ChIJP2MkUTjuGGARWL7kqqCQgQo
# ['支那そば あおば', 35.71238472, 139.5511553]
# yes
# 支那そば あおば
# ChIJMRu40XLvGGAR9w2SXx3eDig
# ['鳥長', 35.73138417, 139.65999580000002]
# yes
# 鳥長
# ChIJrZ5BxgztGGARE9a_G8peFHk
# ['手打蕎麦 じゆうさん', 35.726715000000006, 139.6803483]
# yes
# 手打蕎麦 じゆうさん
# ChIJ_2IBmFvtGGARb3WhjtdAqvA
# ['焼肉問屋 牛蔵', 35.73282583, 139.63212439999998]
# yes
# 焼肉問屋 牛蔵
# ChIJkxBr9MntGGARFRjZTFiwF_c
# ['鰻家', 35.72482667, 139.68546640000002]
# yes
# 鰻家
# ChIJkUyxClftGGAR-iGA0vVDmm0
# ['玄蕎麦 野中', 35.72930972, 139.64830890000002]
# yes
# 玄蕎麦 野中
# ChIJp4za36PtGGARpdNRbnOaMBs
# ['らぁ麺 すぎ本', 35.71988333, 139.6408636]
# yes
# らぁ麺 すぎ本
# ChIJvZ45HZftGGARP7vywTT11IA
# ['パーラー江古田', 35.73663204, 139.67421230000002]
# yes
# パーラー江古田
# ChIJT43p-z_tGGAR64bRfvHT_pM
# ['秋元屋', 35.71624222, 139.65635559999998]
# yes
# couldn't get
# couldn't get
# ['洋食 三浦亭', 35.72399964, 139.5763013]
# yes
# 三浦亭
# ChIJfZaVsfzuGGARdUeu5IrVWW0
# ['レストラン セビアン', 35.72538806, 139.68602140000002]
# yes
# Restaurant C’EST BIEN
# ChIJ5fJwD1ftGGARQuymw_ItOpE
# ['まちのパーラー', 35.74031167, 139.67857080000002]
# yes
# まちのパーラー
# ChIJs2hk1j7tGGARHuXnX304wxo
# ['ピッツェリア\u3000ジターリア\u3000ダ\u3000フィリッポ 石神井公園', 35.74122167, 139.61210690000001]
# yes
# pizzeria gtalia da filippo
# ChIJLTHXgp3uGGARAVtXDJA1luo
# ['うな藤', 35.71204611, 139.60151169999997]
# yes
# うな藤
# ChIJEVrQDW7uGGAR0zDPJtEivR0
# ['そば 法師人', 35.7274, 139.6633661]
# yes
# そば 法師人
# ChIJd4AHAnLtGGARhr0X0AI03yA
# ['牛蔵 しゃぶしゃぶ すき焼き店', 35.73280833, 139.6322047]
# yes
# 焼肉問屋 牛蔵
# ChIJkxBr9MntGGARFRjZTFiwF_c
# ['大貫', 35.7332675, 139.6275478]
# yes
# 大貫
# ChIJ8zJ6e8ztGGARBsi6w-ba64s
# ['ダ・アオキ・タッポスト', 35.74461333, 139.6526369]
# yes
# ダ・アオキ・タッポスト
# ChIJAQCRlqrtGGAR17hxntpInd4
# ['手打うどん長谷川', 35.74755833, 139.5883694]
# yes
# 手打ちうどん長谷川
# ChIJO2ze9ujuGGARZXN5RI7UFzY
# ['ロートンヌ 中野店', 35.72898556, 139.6737675]
# yes
# ロートンヌ 中野店
# ChIJqToqKmjtGGARZZwNDca8HGQ
# ['RAMEN GOTTSU', 35.73621972, 139.6599875]
# yes
# RAMEN GOTTSU (らーめん ごっつ)
# ChIJHegNlQ7tGGARjEk-HOVAitI
# ['酒膳 蔵四季', 35.73366194, 139.65396]
# yes
# 酒膳 蔵四季
# ChIJUTkA9NS8JhURs1qyiOUYQD8
# ['マルヤマ', 35.73572444, 139.6650886]
# yes
# couldn't get
# couldn't get
# ['カネキッチン ヌードル', 35.72575583, 139.6859236]
# yes
# カネキッチン ヌードル
# ChIJQ-HEEFftGGARRkV6O0tf2ZM
# ['デザミ', 35.72391775, 139.5971632]
# yes
# デザミ
# ChIJ6_gRBYruGGAR1BKTnW12URA
# ['練馬\u3000江戸銀', 35.7332506, 139.6577904]
# yes
# 江戸銀 練馬店
# ChIJ75q57AvtGGAREQIGl4Av8Cc
# ['源烹輪', 35.73198778, 139.63287780000002]
# yes
# 源烹輪
# ChIJr0ex3sntGGARuEL4Oe1iRus
# ['green glass', 35.71007833, 139.68561169999998]
# yes
# green glass
# ChIJKe5A6rDyGGARstb2LQnd7RE
# ['食堂七彩', 35.71999722, 139.6471317]
# yes
# 食堂 七彩
# ChIJfeUHwpvtGGARbegEeDrTU60
# ['甘味処 華樓', 35.74557806, 139.5906669]
# yes
# 甘味処 華樓
# ChIJ_XY7EsfuGGAR8Z4JebYvr5g
# ['ブロンディール', 35.74694111, 139.6044044]
# yes
# ブロンディール
# ChIJLYW0NsHcGGARMa3gcSDNGUk
# ['美志満', 35.73531972, 139.66754219999999]
# yes
# 桜台らぁ麺 美志満
# ChIJ7R1TbRPtGGARSRlVK2NynzU
# ['手打ちそば にはち', 35.72549444, 139.5812317]
# yes
# にはち
# ChIJy6ReufruGGARM8byjqtfweQ
# ['龍の翼', 35.73194222, 139.6539625]
# yes
# 龍の翼
# ChIJIw-PDgrtGGARfu7mUTnp9NQ
# ['アイラ', 35.73265639, 139.65785669999997]
# yes
# モルトハウスアイラ
# ChIJu_VlkAvtGGARcr8AGRZxMJg
# ['味噌麺処 花道', 35.71916778, 139.6555883]
# yes
# 味噌麺処 花道
# ChIJO2UBLnjtGGARYL7YVBfuBME
# ['麺や金時', 35.73519472, 139.6815097]
# yes
# 麺や 金時
# ChIJWYsKh0btGGARZgbrW3jlYTM
# ['麺処 まるよし商店', 35.73542524, 139.66612460000002]
# yes
# 麺処 まるよし商店
# ChIJzVVNVRLtGGARmjHpZ6PNXW8
# ['麺 酒 やまの', 35.73272028, 139.657415]
# yes
# 麺酒やまの
# ChIJwYoJlgvtGGARaCS6QETYthY
# ['秋元屋 桜台店', 35.73523667, 139.6655822]
# yes
# 秋元屋 桜台店
# ChIJo6BBWBLtGGARNvMkol9gjGA
# ['ふんだりけ', 35.72554167, 139.5924547]
# yes
# ふんだりけ
# ChIJoQr6TIvuGGARc5CxQcZMWtc
# ['暁', 35.733172499999995, 139.6739542]
# yes
# couldn't get
# couldn't get
# ['中華ソバ 伊吹', 35.76946111, 139.6957281]
# yes
# 中華ソバ 伊吹
# ChIJx5rjlVKNGGARUGxWrmh9aGM
# ['中華そば べんてん', 35.77295282, 139.63245619999998]
# yes
# 中華そば べんてん
# ChIJq6qFxQrsGGAR1kp6SWd5TCE
# ['手打ちそば 菊谷 巣鴨本店', 35.73481306, 139.7345892]
# yes
# 手打ちそば 菊谷
# ChIJE9nvbniNGGARUtX2yi_JlFc
# ['麺処 篠はら', 35.72980694, 139.7053983]
# yes
# 麺処 篠はら
# ChIJizAJEViNGGARfD70OfhYppE
# ['マテリエル', 35.7450475, 139.7019733]
# yes
# マテリエル
# ChIJ_Uss_raSGGARJ2FBV_SpLHk
# ['中華そば しながわ', 35.727055, 139.7020644]
# yes
# 中華そば しながわ
# ChIJAQAxq1eNGGARfeB0R3ZIbhk
# ['クリオロ 東京本店', 35.74130639, 139.6855169]
# yes
# クリオロ本店
# ChIJvdMJ3TftGGAR3zNyoIeOWO4
# ['鮨\u3000まつ本', 35.74442333, 139.7223483]
# yes
# 鮨 まつ本
# ChIJdWDwVZqSGGARi-51z1-Wt74
# ['中華めん処 道頓堀', 35.77341389, 139.63497030000002]
# yes
# 中華めん処 道頓堀
# ChIJ8yKRHHXsGGARvVGUyQC9-6Q
# ['かえる食堂', 35.73056222, 139.7061281]
# yes
# かえる食堂
# ChIJzTUYdFiNGGARra403wgsp4Y
# ['パン工房 ブランジェリーケン', 35.76794667, 139.6487811]
# yes
# ブランジェリーケン
# ChIJr8k092PsGGARzFWofzMJXP0
# ['つけそば 周', 35.7466875, 139.7132503]
# yes
# つけそば 周
# ChIJ5-SXw72SGGARPbbpM01S2vk
# ['愚直', 35.74982417, 139.6940131]
# yes
# 愚直
# ChIJLxpiSTPtGGARXciZmt20-hc
# ['スタミナ苑', 35.77667917, 139.7556083]
# yes
# スタミナ苑
# ChIJAQndiUeSGGAR-6DRWxrNuDY
# ['活鰻の店 つぐみ庵', 35.73464333, 139.7559786]
# yes
# couldn't get
# couldn't get
# ['中勢以 内店', 35.71293417, 139.7438842]
# yes
# 中勢以 内店
# ChIJI9c-wa2NGGAR7gQHnk3mTT8
# ['カッチャル バッチャル', 35.72405167, 139.73263889999998]
# yes
# カッチャルバッチャル
# ChIJKeJf33SNGGAREiG6980xtdI
# ['豊栄', 35.714925, 139.7464811]
# yes
# 中国料理 豊栄
# ChIJD8d49bGNGGARhDfP5CU2HhA
# ['竹政', 35.72762976, 139.7303319]
# yes
# 竹政
# ChIJSauMs3aNGGARtPvhaQ_lelg
# ['ヴォーロ・コズィ', 35.72111889, 139.7492467]
# yes
# ヴォーロ・コズィ
# ChIJQeQtDbqNGGARS3A2KaT00OQ
# ['シチリア屋', 35.7125185, 139.7557211]
# yes
# シチリア屋
# ChIJKd5BYjWMGGARvicC_mM58q0
# ['Japanese Soba Noodles 蔦', 35.72971028, 139.74381]
# yes
# 蔦
# ChIJVVWIS5iNGGARlYlmEEFAZYg
# ['中華そば屋 伊藤', 35.76003361, 139.749125]
# yes
# 中華そば屋 伊藤
# ChIJ6-Xn8m6SGGARv3qty7sYNU8
# ['蒼天 南口店', 35.72632194, 139.73063280000002]
# yes
# 蒼天 南口店
# ChIJBUOsBXSNGGARENzTEUN5Sb8
# ['モンプチコションローズ', 35.72542252, 139.74521230000002]
# yes
# モンプチコションローズ
# ChIJ-1KwLaONGGARAVqcZYE3qTU
# ['麺処ほん田', 35.75949333, 139.7338253]
# yes
# 麺処ほん田
# ChIJkUlCx4qSGGARdY1TcvrzRkg
# ['レゼールデカー', 35.71438028, 139.74117809999998]
# yes
# Les Ailes des K
# ChIJDYv0xK6NGGARInt6eevvfXs
# ['一幸庵', 35.71325167, 139.74245439999999]
# yes
# 一幸庵
# ChIJSePbKayNGGAR6RJ6V-4zWpU
# ['大塚高勢', 35.72674222, 139.7358094]
# yes
# 高勢
# ChIJKx08zZ-NGGARQo5Axzq02Zg
# ['すし処 みや古分店', 35.77358222, 139.7238594]
# yes
# すし処 みや古分店
# ChIJO-lZv-KSGGARsSEj-rUvl9M
# ['くう', 35.72602667, 139.73472080000002]
# yes
# くう
# ChIJFa43eHWNGGARsatWIa1ZpxU
# ['埼玉屋', 35.75998972, 139.7331872]
# yes
# 埼玉屋
# ChIJORoC04qSGGAR6FALI_Z9SQw
# ['手打うどん すみた', 35.77728361, 139.7298508]
# yes
# 手打ちうどん すみた
# ChIJ56wJAQKTGGARHV2IHb4KpGo
# ['燦燦斗', 35.76135194, 139.7289836]
# yes
# 燦燦斗
# ChIJ691ZlvOSGGARMgy5saZdwmA
# ['一東菴', 35.75990639, 139.7320625]
# yes
# 一東菴
# ChIJPcnhyPSSGGAROJw86Rs4VQY
# ['川栄', 35.77683028, 139.72339250000002]
# yes
# couldn't get
# couldn't get
# ['大塚\u3000みや穂', 35.72728806, 139.73061940000002]
# yes
# 和食と日本酒 大塚・みや穂
# ChIJf1MQr3aNGGARDGzKF7KRuQE
# ['群林堂', 35.71430749, 139.7316743]
# yes
# 群林堂
# ChIJAQCQkAiNGGARQRAnVUUR7MM
# ['なんどり', 35.74744944, 139.75879750000001]
# yes
# なんどり
# ChIJCZIFePSNGGAROw3_cOEfIbs
# ['プルジャ ダイニング', 35.72893778, 139.74044030000002]
# yes
# プルジャダイニング
# ChIJ3-3wLJmNGGARkMGtS3228hE
# ['MENSHO', 35.71304306, 139.7317397]
# yes
# MENSHO
# ChIJublUIwaNGGARGI0SGt-pwu8
# ['そば工房 玉江', 35.72942056, 139.7561211]
# yes
# そば工房 玉江
# ChIJGe4gUAqNGGAR4t4aFsBlcWE
# ['Nomka', 35.77418806, 139.7217219]
# yes
# ワイン+つまみ Nomka（ノムカ）
# ChIJW48MgOKSGGARCQRW7VcwEVs
# ['トラットリア ダディーニ', 35.71727917, 139.7541486]
# yes
# トラットリア ダディーニ
# ChIJr98Jw7WNGGAR9zOY-1rwFFE
# ['だるまや餅菓子店', 35.75902639, 139.7246717]
# yes
# だるまや餅菓子店
# ChIJhW1Hgu2SGGART78RBt2LqFY
# ['草月', 35.76007889, 139.7322889]
# yes
# 黒松本舗 草月
# ChIJIfzR0PSSGGARFpX3S4rWS94
# ['麦酒庵 大塚店', 35.72911889, 139.7331531]
# yes
# 麦酒庵
# ChIJeWNxXXaNGGARdtNQGWj_3mM
# ['麺屋KABOちゃん', 35.73663778, 139.7497394]
# yes
# カボちゃん
# ChIJxTgnd5GNGGARbwY0Hl_sXOk
# ['新潟屋', 35.76034667, 139.7329744]
# yes
# 新潟屋
# ChIJI-pHKfWSGGARlR8G-rT0XKA
# ['やっぱり インディア', 35.72701944, 139.7312481]
# yes
# やっぱりインディア 大塚本店
# ChIJ9x90H3SNGGARNWE-LitRFsg
# ['串駒房', 35.73106972, 139.7333861]
# yes
# 串駒房
# ChIJtbERu3eNGGARI7LIkww5Hlc
# ['ぼんご', 35.72988889, 139.7321842]
# yes
# 大塚おにぎり ぼんご
# ChIJ0U1eAneNGGAR33DgoDIt0cA
# ['創作麺工房 鳴龍', 35.72545194, 139.73355]
# yes
# 創作麺工房 鳴龍 NAKIRYU
# ChIJQ7G7DnWNGGARB3r1SP30PMk
# ['煮干そば 流。', 35.75779972, 139.7256281]
# yes
# 煮干そば 流。
# ChIJYaarvPKSGGARdy6Q0enB4j4
# ['讃岐うどん いわい', 35.75829222, 139.7220178]
# yes
# 讃岐うどん いわい
# ChIJawqjUeySGGARbJroKjWZiEM
# ['生粋 花のれん', 35.71645667, 139.7373939]
# yes
# 生粋 花のれん
# ChIJVVUB0qeNGGARk7lzKprcocw
# ['パティスリートレカルム', 35.72537556, 139.7456253]
# yes
# パティスリーTRES CALME（トレ カルム）
# ChIJh2BGLaONGGARldNNJcLGUrE
# ['富士松', 35.74736194, 139.7594875]
# yes
# 麺処 富士松
# ChIJE1hPi_ONGGARnDZ35pc19BM
# ['自家製麺 伊藤', 35.77508611, 139.72473469999997]
# yes
# 自家製麺 伊藤 赤羽店
# ChIJwUnGVR2TGGARNAEaZNumYhQ
# ['グリルK', 35.72631611, 139.74577280000003]
# yes
# グリルＫ
# ChIJjZb7K72NGGARZw9h_d0Pzf0
# ['東京苑 大塚', 35.72977972, 139.73056330000003]
# yes
# 東京苑
# ChIJA2S5MXeNGGARTnZI5LGgV90
# ['うなぎ 魚政', 35.72886417, 139.83877280000002]
# yes
# うなぎ魚政
# ChIJl9ErrM-8JhUR45MS6E-Ssgw
# ['尾花', 35.72834278, 139.8001183]
# yes
# 尾花
# ChIJ0R4dQvSOGGARu_xPpzle2nU
# ['吟八亭 やざ和', 35.759675, 139.8495819]
# yes
# 吟八亭やざ和
# ChIJpTZfDYWPGGARa6GvdlRRTWE
# ['つけ麺 道', 35.76468417, 139.8500433]
# yes
# つけ麵 道
# ChIJGWRlYY6PGGARG16oXcPX1JM
# ['徳多和良', 35.74641944, 139.8046125]
# yes
# 徳多和良
# ChIJWctFyUWOGGARA5TmpxvQJvw
# ['正泰苑 総本店', 35.74445278, 139.78827969999998]
# yes
# 正泰苑 本店
# ChIJB6BGI22OGGARZnOvTMz2lh8
# ['田中商店 本店', 35.78144917, 139.8141436]
# yes
# couldn't get
# couldn't get
# ['宇豆基野 本店', 35.74262028, 139.8086719]
# yes
# お食事処 宇豆基野本店
# ChIJb3H9RFCOGGARIlb0xYl6nzs
# ['宇ち多゛', 35.73487222, 139.8521469]
# yes
# もつ焼き宇ち多゛
# ChIJhdMTW2ePGGARgQAoTtVkNu8
# ['陽はまたのぼる', 35.75482417, 139.82935969999997]
# yes
# 陽はまたのぼる
# ChIJuRYS-bqPGGAR3FoQkMYp3Uw
# ['かがやき', 35.72314719, 139.792727]
# yes
# かがやき
# ChIJY9McQIyOGGAR6kUtyzJYkcA
# ['手打式超多加水麺 ののくら', 35.76085417, 139.850795]
# yes
# ののくら 手打式超多加水麺
# ChIJsXR0hYWPGGARZlqN69LN1Fg
# ['ラーメン屋 トイ・ボックス', 35.72793444, 139.7952803]
# yes
# ラーメン屋 トイ・ボックス
# ChIJ-XBj54qOGGARmnKgcf30kwA
# ['丸千葉', 35.72280401, 139.80352390000002]
# yes
# 丸千葉
# ChIJbRqHR-6OGGAR71SqeqTvuZs
# ['千寿 竹やぶ', 35.74125833, 139.8005986]
# yes
# 竹やぶ
# ChIJ4_HRSkOOGGARe7f_Vw3t0r0
# ['い志い', 35.75459639, 139.8798853]
# yes
# い志い
# ChIJ72Eey6KFGGARBlYBLKKK1GU
# ['Puja', 35.74289167, 139.78543059999998]
# yes
# プージャー
# ChIJHYUykXKOGGAR5vy0mmEa34I
# ['バード コート', 35.74819361, 139.8064983]
# yes
# バードコート
# ChIJhQueAEaOGGAR6UP3HPHNXJ4
# ['そばきり 日曜庵', 35.75587167, 139.88180780000002]
# yes
# 日曜庵
# ChIJMZKQMKOFGGARwxLDvHA7E1k
# ['RAMEN\u3000にじゅうぶんのいち', 35.74132722, 139.7761489]
# yes
# RAMEN にじゅうぶんのいち
# ChIJceBzpwqOGGAR5TdjVZ8ulBQ
# ['鮨 なかや', 35.75958444, 139.8523158]
# yes
# なかや鮨
# ChIJM-gzLYSPGGARLT6l5LBT_xc
# ['土手の伊勢屋', 35.72182556, 139.80026830000003]
# yes
# 土手の伊勢屋
# ChIJZZRwk-2OGGARX2mMuPGhmPc
# ['茶香', 35.74428634, 139.80487050000002]
# yes
# 茶香
# ChIJrWMLF0WOGGARh2h03CLRIA4
# ['餃子の店 蘭州', 35.73525806, 139.8516111]
# yes
# 餃子の店 蘭州
# ChIJUTmFQGePGGARHdk4vS5vAd8
# ['Cafe Bach', 35.72358583, 139.8035961]
# yes
# 自家焙煎珈琲屋 バッハ
# ChIJlfuRL-6OGGARgq63qSHI-nY
# ['麺屋 音', 35.74891583, 139.8067828]
# yes
# 麺屋 音
# ChIJNbnsrkiOGGAR7bktdCCg3fg
# ['博多長浜らーめん いっき', 35.78262472, 139.76629219999998]
# yes
# いっき 博多長浜ラーメン
# ChIJrwnm-C-SGGAR_j1wylSLG60
# ['桜なべ 中江', 35.72191096, 139.80024630000003]
# yes
# 桜なべ 中江
# ChIJZZRwk-2OGGAR2PU-fl-uvN4
# ['とらやベーカリー', 35.76750389, 139.8759561]
# yes
# とらやベーカリー
# ChIJLVdKdnOFGGARJtN3nFmZJlk
# ['ル・コントワール・ドゥ・レジオン', 35.74688806, 139.8051542]
# yes
# ル・コントワール・ドゥ・レジオン
# ChIJ_1Z5xEWOGGAR6LeCw_nXXvQ
# ['是屋', 35.74312694, 139.8093681]
# yes
# 是屋
# ChIJnazQslGOGGARW2ygZ_7ZU8Y
# ['広島お好み焼き おこたろう', 35.76211861, 139.85205919999999]
# yes
# おこたろう広島お好み焼き店
# ChIJ4SvpWY-PGGARortiaFGRN6I
# ['牛骨らぁ麺マタドール', 35.74356778, 139.8087428]
# yes
# couldn't get
# couldn't get
# ['鳥房', 35.73560652, 139.85253219999998]
# yes
# 鳥房
# ChIJ16_lSWePGGARA9vOuj9CNVg
# ['Le Ciel', 35.69467333, 139.4470011]
# yes
# Le Ciel
# ChIJe_DnK_njGGAR_9aiJmxRCs8
# ['鶏そば  ムタヒロ 2号店', 35.69766694, 139.48614560000001]
# yes
# 鶏そば ムタヒロ2号店
# ChIJ6x7T7zXkGGAR1C1m9j1L2Ts
# ['治鮨', 35.69759833, 139.4816519]
# yes
# 治鮨
# ChIJydOaCzfkGGARAeVTTWF_8eA
# ['クルミドコーヒー', 35.69579056, 139.46772190000002]
# yes
# クルミドコーヒー
# ChIJt2WA_BbkGGARhzX4yjs_Zxw
# ['とんかつ桂', 35.70552639, 139.4812886]
# yes
# とんかつ桂
# ChIJHat-lC_kGGARFPHlWTWHDK8
# ['中華そば ムタヒロ  1号店', 35.69564306, 139.4834294]
# yes
# couldn't get
# couldn't get
# ['プーさん', 35.69511167, 139.5093364]
# yes
# カレーの店 プーさん
# ChIJKfi49aLlGGARJVEXEI5nIQ0
# ['くじら食堂', 35.69893056, 139.52874219999998]
# yes
# くじら食堂
# ChIJSyfs4oDlGGARz9XqYURXPq4
# ['洋菓子舗 茂右衛門', 35.69646639, 139.48562859999998]
# yes
# 洋菓子舗 茂右衛門
# ChIJ1W2WA0rkGGARNc-yYgAzYPA
# ['岳志', 35.69632611, 139.5280549]
# yes
# 肴処 岳志
# ChIJGzyAxYHlGGAReImQa1ahKZg
# ['うなちゃん', 35.69619444, 139.4513567]
# yes
# うなちゃん
# ChIJea01NwfkGGAR-D6qvS3nEX4
# ['鈴木', 35.64862833, 139.5496831]
# yes
# couldn't get
# couldn't get
# ['ドンブラボー', 35.64498083, 139.56282]
# yes
# ドンブラボー
# ChIJvQ_hGVDwGGARBx4X-FL2Wb0
# ['中華そば しば田', 35.65310139, 139.5930211]
# yes
# しば田
# ChIJk_tBTZ_xGGARqrMDFbzZrdU
# ['中華そば ふくみみ', 35.67033556, 139.47295559999998]
# yes
# 中華そば ふくみみ
# ChIJn-VCV_TkGGARYs-ZpJAKl1M
# ['柴崎亭', 35.65434556, 139.57697439999998]
# yes
# 柴崎亭
# ChIJK40x2rPxGGAR4S3JlYyvTE0
# ['AOSAN', 35.65738167, 139.58616719999998]
# yes
# ＡＯＳＡＮ
# ChIJ30dBnrvxGGARcqWfLtjISQ8
# ['ラーメン英二', 35.67900361, 139.482115]
# yes
# ラーメン英二
# ChIJg8dDrlfkGGARvs4tM5u4rHE
# ['自家製麺つけそば 九六', 35.62225833, 139.57813169999997]
# yes
# 自家製麺 つけそば 九六
# ChIJp9aANiLxGGAR2fL0_IEWasM
# ['堀口珈琲 狛江店', 35.63120111, 139.58211530000003]
# yes
# 堀口珈琲 狛江店
# ChIJMWfYCRrxGGARZKHGorWHtKg
# ['町田汁場 しおらーめん進化', 35.54996944, 139.44159140000002]
# yes
# 進化
# ChIJzdDsMKj-GGARWMxsuVm9NKA
# ['超純水採麺 天国屋', 35.52306472, 139.4684053]
# yes
# 超純水採麺 天国屋
# ChIJ-R1_ut_4GGARZ18RqfQaus8
# ['町田汁場 しおらーめん進化 町田駅前店', 35.54141167, 139.4455906]
# yes
# 進化 町田駅前店
# ChIJF7C5MLL-GGAR-niFah8THzM
# ['アサノ', 35.53838056, 139.45174419999998]
# yes
# カレーの店 アサノ
# ChIJ_3RN5Er5GGARTnhbl2XHxdg
# ['一番いちばん', 35.54615583, 139.4501789]
# yes
# 白河手打中華そば 一番いちばん
# ChIJx60YtlL5GGARC3vB07jm9dQ
# ['すし処金太郎', 35.53823105, 139.4524695]
# yes
# すし処金太郎
# ChIJNy_VWEr5GGARFCyr49mK6FQ
# ['アレグロ コン ブリオ', 35.53795613, 139.45202780000002]
# yes
# アレグロ コン ブリオ
# ChIJb5ry80r5GGARE1nx4OKN5kc
# ['カフェ 中野屋', 35.53978806, 139.4522311]
# yes
# カフェ 中野屋
# ChIJwe-kBUv5GGARioY_wW_vEqo
# ['胡心房', 35.53832167, 139.45003219999998]
# yes
# 胡心房
# ChIJKV-BKUv5GGARivi2BDVKqtQ
# ['鰻屋 三右ヱ門', 35.54402083, 139.44997859999998]
# yes
# 三右ヱ門
# ChIJEaqwS035GGARmdiTF23Gav4
# ['土家', 35.75908472, 139.4661419]
# yes
# 土家
# ChIJ66RGwj7nGGARBW5OCFtf6zI
# ['そばきり すずき', 35.74352944, 139.5756347]
# yes
# そばきりすずき
# ChIJtRnVatfuGGARYHVVlWwjyEw
# ['ロートンヌ 秋津本店', 35.77495583, 139.49765580000002]
# yes
# ロートンヌ 秋津本店
# ChIJ5SvxgpjnGGAR9Rj0pUOMJ70
# ['ラーメン二郎 ひばりヶ丘駅前店', 35.74671278, 139.54673190000003]
# yes
# ラーメン二郎 ひばりヶ丘駅前店
# ChIJc0v31bboGGARRkxBFSjC7cI
# ['手繰りや 玄治', 35.74462556, 139.47331530000002]
# yes
# 手繰りや 玄治
# ChIJQVjUp-HmGGARC_JZU0_JvaY
# ['麺屋 瑞風', 35.72625333, 139.54464309999997]
# yes
# 麺屋 瑞風
# ChIJRceqQkTvGGAR-s0n7SekGHc
# ['手打ち蕎麦と酒 佳蕎庵', 35.72726167, 139.4824111]
# yes
# 佳蕎庵
# ChIJFTLFe47mGGAR3eXs2VpaBs0
# ['アルカション', 35.74570667, 139.5728753]
# yes
# アルカション
# ChIJ2YRtCdbuGGARyAYYudTOz-s
# ['一喜', 35.73940278, 139.56050280000002]
# yes
# 手打そば 一喜
# ChIJrQ7UwDHvGGAR-r-TCeE7pAk
# ['麺屋彩香', 35.74425389, 139.567115]
# yes
# 麺屋彩香
# ChIJObkn9yvvGGARKWiJCiQQR2o
# ['煮干鰮らーめん 圓', 35.65709333, 139.34155969999998]
# yes
# 煮干しラーメン 圓
# ChIJYc-cI3YeGWARVl6dsV4PcD4
# ['大幸園', 35.68421278, 139.37608559999998]
# yes
# 大幸園
# ChIJmeVHK-ThGGARPNycy6y-1Eo
# ['蕎麦 坐忘', 35.65433861, 139.31111330000002]
# yes
# 蕎麦 坐忘
# ChIJSZvoa5ceGWARGBGFrFpufqM
# ['八王子うかい亭', 35.67002722, 139.3373503]
# yes
# 八王子うかい亭
# ChIJX69lPGYeGWARANvvcFWTm3c
# ['うかい竹亭', 35.61555639, 139.26777109999998]
# yes
# うかい竹亭
# ChIJHwAhMugbGWARNkrqt79D0nI
# ['ほっこり中華そば もつけ', 35.64989111, 139.3363725]
# yes
# もつけ
# ChIJk6iNzNAdGWARsFuFxuktq_k
# ['小山', 35.65473221, 139.3386362]
# yes
# couldn't get
# couldn't get
# ['蕎麦懐石 無庵', 35.69632778, 139.41401580000002]
# yes
# 無庵
# ChIJn5MUSnfhGGARnXi32a3FjzU
# ['うかい鳥山', 35.6119725, 139.25992030000003]
# yes
# うかい鳥山
# ChIJTU8SjsQbGWARwKGTaBdm3lw
# ['めだかタンタン', 35.70148611, 139.3863178]
# yes
# めだかタンタン
# ChIJWVykzMfhGGARmOkSLUiwARk
# ['タンタン', 35.64868306, 139.3433217]
# yes
# タンタン
# ChIJWZ_hqNwdGWARMEzj13AjvJE
# ['天ぷら岡本', 35.69680722, 139.4163142]
# yes
# 岡本
# ChIJb_uKhXDhGGARsXxxQnJ0IX8
# ['ラーメン二郎 八王子野猿街道店 ２', 35.62621361, 139.4045167]
# yes
# ラーメン二郎 八王子野猿街道店2
# ChIJzW8ZDd7iGGAR93SMcL6wKi8
# ['アンジュナ', 35.65901944, 139.4155131]
# yes
# インド食堂アンジュナ
# ChIJhXvgIa7jGGARglVSjUdGQeo
# ['チクテベーカリー', 35.60427694, 139.3820567]
# yes
# Cicoute Bakery
# ChIJlS0-2bPiGGAR8cUVCv6c648
# ['ゆるり 中華食堂 癒食同源', 35.69283139, 139.4269425]
# yes
# ゆるり中華食堂・癒食同源
# ChIJid-vTGDhGGARRemswkC20UQ
# ['奥芝商店 八王子田代城', 35.65129306, 139.3383347]
# yes
# 奥芝商店 八王子田代城
# ChIJq6pr0cgdGWARDNSHQvhKGRo
# ['中華そば 吾衛門', 35.65418917, 139.3141864]
# yes
# 中華そば 吾衛門
# ChIJQfUbcpoeGWARdYIrmTwQUIQ
# ['手打そば 車家', 35.62578056, 139.3897608]
# yes
# 車家
# ChIJjTLOWOviGGARnz3oHRYzjjM
# ['ぶーる・ぶーる・ぶらんじぇり', 35.6572875, 139.3369875]
# yes
# ぶーる ぶーる ぶらんじぇり
# ChIJw14eXAS6JhURLuQSE9L1LR4
# ['串焼き鈿', 35.656004700000004, 139.3386429]
# yes
# 串焼き鈿
# ChIJOYPR9HceGWARVKtQoMYZI2c
# ['楽観 立川店', 35.69551694, 139.42114080000002]
# yes
# 楽観 立川店 | 立川駅 ラーメン屋
# ChIJ3Q_I5GThGGAR4Tsgy3xYB3E
# ['とうふ屋うかい 大和田店', 35.66077094, 139.36057240000002]
# yes
# とうふ屋うかい 大和田店
# ChIJQfZAifwdGWARXAo8UBsFbHg
# ['煮干しそば 虎空', 35.62441583, 139.40526530000002]
# yes
# couldn't get
# couldn't get
# ['香川 一福 立川店', 35.69259694, 139.41937080000002]
# yes
# 香川 一福 立川店
# ChIJ6_2YVGPhGGARkv_byOPHDBs
# ['うなぎ大久保', 35.64207417, 139.35459530000003]
# yes
# うなぎ大久保
# ChIJoWzcEpMdGWARNEfLba1EzmU
# ['フレンチ サクラ', 35.74221611, 139.3297008]
# yes
# サクラ
# ChIJlVdZbDUgGWARvAgN61USprA
# ['カッパ64', 35.72963833, 139.32871809999997]
# yes
# カッパ64
# ChIJl7P6pCwgGWARiEmM7bXU-rI
# ['八丈島郷土料理\u3000梁山泊', 33.11704028, 139.8058789]
# yes
# 八丈島郷土料理 梁山泊
# ChIJHQKd0cRxFWARqvpLJB1TcN8

# %%
name
# Out:
# ['オステルリー・スズキ',
#  '多に川 赤坂',
#  'リベルターブル 赤坂',
#  '寿司「鮨一新」',
#  '津やま',
#  'VIEW & DINING THE Sky',
#  'No Data',
#  'かえりやま',
#  '鴨シャブ竹亭',
#  '叙々苑 游玄亭赤坂',
#  '元赤坂ながずみ',
#  'Ｗａｋｉｙａ一笑美茶樓',
#  '赤坂璃宮',
#  'No Data',
#  'しろたえ',
#  'ソラノイロ 本店',
#  '希須林 赤坂店',
#  'SATSUKI',
#  '室町 砂場 赤坂店',
#  'とんかつ まさむね',
#  'やげんぼり 赤坂店',
#  'まるしげ 夢葉家',
#  'チョンギワ 本館',
#  '割烹 和知',
#  '赤坂 丈太郎',
#  '銀座 久兵衛 ホテルニューオータニ タワー店',
#  '赤坂 山ね家。',
#  '燻',
#  'No Data',
#  'アジャンタ',
#  'No Data',
#  'SATSUKI',
#  '天ぷら 逢坂',
#  '天香回味 赤坂別館',
#  'ざくろ TBS店',
#  '會水庵',
#  '重箱',
#  'クレアバックス crear bacchus',
#  'かみやま',
#  '炭火割烹 白坂',
#  '虎白',
#  'No Data',
#  'すし匠',
#  '神楽坂 石かわ',
#  'ル・マンジュ・トゥー',
#  '北島亭',
#  "L'Octave -Hayato KOBAYASHI-",
#  'No Data',
#  '炭火焼肉 なかはら',
#  '石ばし',
#  '曙橋 まる富',
#  '神楽坂ラ・トゥーエル',
#  'リストランテ ラ・バリック トウキョウ',
#  '和食こんどう',
#  'コンヴィーヴィオ',
#  '串揚げはやし',
#  'セクレト',
#  '天ぷら 蕎楽亭',
#  'ラトラス',
#  'うぶか',
#  '神楽坂 鉄板焼 中むら',
#  'No Data',
#  '神楽坂鉄板焼き いわ倉',
#  'アンティカ・オステリア・カルネヤ',
#  'No Data',
#  '懐石 大原',
#  '志ま平',
#  '萬屋おかげさん',
#  '山さき',
#  'Estación (エスタシオン)',
#  'サンルーカルバー',
#  '季旬鈴なり',
#  '鮨 臥龍',
#  '蕎楽亭',
#  'chez Olivier',
#  'No Data',
#  '遊猿',
#  'エノテカラウラ',
#  '鮨 てる',
#  'ルグドゥノム・ブション・リヨネ',
#  '蜀郷香',
#  '荒木町たつや',
#  '青華こばやし',
#  'パティスリー・ カー・ヴァンソン',
#  'あげづき',
#  'アトリエコータ',
#  'ラ・マティエール',
#  '想いの木',
#  'ヴェーリ',
#  '和しょく えびはら',
#  'ピアッティ カステリーナ',
#  '和食 お の 寺',
#  'No Data',
#  'オテル・ドゥ・ミクニ',
#  'ジュー ドゥ マルシェ',
#  '鮨心 -Sushi Kokoro-',
#  'トラットリア グランボッカ',
#  'たん焼 忍',
#  'No Data',
#  '焼鳥茜',
#  '多仁本',
#  'はらまさ',
#  'うなぎ はし本「創業183年」',
#  'No Data',
#  '鮨 わたなべ',
#  '神楽坂 阿部',
#  'ディルセ',
#  '東白庵かりべ',
#  '歯車',
#  'め乃惣',
#  'No Data',
#  'の弥七',
#  'フルーツパーラーフクナガ',
#  '中国菜 膳楽房',
#  'トルッキオ',
#  'バー エルラギート',
#  'レスプリ ミタニ・ア・ゲタリ',
#  'BOLT',
#  '神楽坂 翔山亭 黒毛和牛贅沢重専門店 神楽坂本店',
#  'No Data',
#  'DIRITTO',
#  '神楽坂大和屋 梅助 神楽坂/結納/接待/個室/ランチ/ディナー/和食',
#  'ヘンドリクス カリー バー',
#  'アルボール神楽坂',
#  '焼肉 名門',
#  '中国飯店 市ヶ谷店',
#  'No Data',
#  '好ちゃん飯田橋分家',
#  'うなぎ川勢',
#  'おでんや den',
#  '懐石小室',
#  'たく庵',
#  'Sincere',
#  '津の守坂 小柴',
#  '錦福',
#  '後楽寿司やす秀',
#  'たいやき わかば',
#  'かつれつ四谷たけだ',
#  '釜あげうどん はつとみ',
#  '一条流がんこラーメン 総本家',
#  '焼鳥 おがわ',
#  'Rojiura Curry SAMURAI.神楽坂店',
#  'あほう鳥',
#  '御料理 宮した',
#  '神楽坂 鮨 りん',
#  '日本橋 寿司金',
#  'ふしきの（Fushikino）',
#  '麺や庄の',
#  '葉山',
#  'チャコあめみや',
#  'ラ・プレシューズ 四ツ谷店',
#  '九段下 寿司政',
#  '梅香',
#  'ルブルターニュ バーアシードル レストラン',
#  '十割蕎麦 蕎麦の膳 たかさご',
#  'セシル エリュアール 神楽坂',
#  '居酒屋 純ちゃん',
#  '九段下寿白',
#  '宮わき',
#  'ソンブルイユ',
#  '寿司幸神楽坂',
#  '紀の善',
#  '灯花',
#  '八咫烏',
#  '手打そば 大川や',
#  '焼肉ヒロミヤ',
#  '神楽坂しゅうご',
#  '西洋料理 夏目亭',
#  '恵さき',
#  'No Data',
#  'てんぷら荘司',
#  'トラットリア ラ タルタルギーナ',
#  'すし処志げる',
#  'Yakiniku Jumbo Hanare',
#  '焼肉ジャンボ 本郷店',
#  '天ぷらと和食 山の上',
#  'とんかつ 丸五',
#  'うどん丸香',
#  "CITTA 'ALTA（チッタアルタ）",
#  '鶴八',
#  '饗 くろ㐂',
#  '明神下 神田川本店',
#  'a table',
#  'テロワール・カワバタ TERROIR Kawabata',
#  'とんかつ やまいち',
#  'ククセモワ',
#  'かんだ光壽',
#  '神田 雲林',
#  'Spice Box (スパイスボックス)',
#  '焼肉ランド マルタケ',
#  'とんかつ 万平',
#  '蘭奢待',
#  'アイコウシャ',
#  'あそび割烹さん葉か',
#  'こなから本店',
#  'JB 日本橋',
#  '江戸前 晋作',
#  'もつ焼き じんちゃん',
#  'No Data',
#  '満寿家',
#  '松翁',
#  '西洋料理 Restaurant 七條',
#  '神田 ポンチ軒',
#  '香川一福 神田店',
#  'アヴランシュ ゲネー',
#  'Wine 厨房 tamaya suidobashi',
#  '欧風カレー ボンディ 神保町本店',
#  'ラーメン大至',
#  'ルー・ド・メール',
#  '廚菓子くろぎ',
#  'ディラン',
#  '麺屋 ねむ瑠',
#  'さゝま',
#  'No Data',
#  '眠庵',
#  'くじらのお宿 一乃谷',
#  '蕎麦切森の',
#  '中華蕎麦 にし乃',
#  '松竹庵 ます川',
#  '吾妻家',
#  'コンセール',
#  '神田 まつや',
#  '欧風カレー ボンディ神田小川町店',
#  'Abats.',
#  '桃の実',
#  'くずし鉄板あばぐら',
#  'No Data',
#  'レストラン マ プール',
#  'うどん こくわがた',
#  '室町 砂場',
#  '神田きくかわ 神田店',
#  '鮮魚らーめん五ノ神水産 神田店',
#  '麺巧 潮',
#  'MENSHO TOKYO',
#  '中華料理 味坊',
#  'カレーノトリコ',
#  'かつ吉 水道橋店',
#  'MANNISH',
#  '舞扇',
#  '浜貞',
#  'かんだやぶそば',
#  '青島食堂 秋葉原店',
#  '新世界菜館',
#  '無銘',
#  'あんこう鍋 いせ源',
#  '葡萄舎',
#  'つけそば 神田勝本',
#  'たん清',
#  "STYLE'S CAKES & CO.",
#  'らーめん天神下大喜',
#  'No Data',
#  'No Data',
#  'La Fabbrica della Pasta Quel',
#  'ピッツァバー ON 38TH',
#  '鷹匠寿',
#  'いし橋',
#  '定谷',
#  '鶯谷園',
#  '牧野',
#  '生粋',
#  'ナベノイズム',
#  'オマージュ',
#  '龍圓',
#  'ボナフェスタ',
#  '鳥恵 上野広小路店',
#  '香味屋',
#  'No Data',
#  'じゅうろく 蕎麦',
#  'レストラン ルディック【浅草・フレンチ】',
#  '山介',
#  'ぽん多本家',
#  'No Data',
#  'ヤナカスギウラ',
#  '麺処 晴',
#  '鮨 久いち',
#  'はすの里 新御徒町店',
#  '弁天山 美家古寿司',
#  'No Data',
#  '入谷鬼子母神門前のだや',
#  '蕎亭 大黒屋',
#  'No Data',
#  '鮨松波',
#  '北山珈琲店',
#  'アーンドラ・キッチン',
#  '肉のすずき',
#  'かず味家',
#  'ひみつ堂',
#  'グリルグランド grill GRAND',
#  '吾妻橋やぶそば',
#  '鮨 橋口',
#  'まめたん',
#  'らーめん 改',
#  'やしま',
#  '鳥栄',
#  '根津 雙柿庵',
#  '寿し政 別館',
#  '神名備 （かむなび）',
#  'パンのペリカン',
#  '鳥つね自然洞',
#  'ジョンティ',
#  'レストラン コーダリー',
#  'まさる',
#  '鮨 一新',
#  '味坊鉄鍋荘',
#  '根津 釜竹',
#  '初小川',
#  'アメッツ',
#  '並木藪蕎麦',
#  'No Data',
#  'No Data',
#  '本とさや',
#  '麺 みつヰ',
#  '佐久良',
#  'マノスレストラン',
#  '駒形どぜう 本店',
#  '米久 本店',
#  'ベジキッチン',
#  '468',
#  'No Data',
#  '今半別館',
#  '三忠',
#  '味農家',
#  'BAR DORAS',
#  'デリー 上野店',
#  '和栗や',
#  'とんかつすぎ田',
#  'ろく月',
#  'ビストロタカ',
#  '丹想庵 健次郎 浅草 手打そば',
#  '焼貝うぐいす',
#  'No Data',
#  'パティシエ イナムラショウゾウ',
#  'フルーツパーラーゴトー',
#  'はん亭',
#  '鷹匠',
#  '稲毛屋',
#  '谷中鳥よし',
#  '徳吉',
#  '根津 日本酒 多田',
#  '亀十',
#  '四川担担麺 阿吽 湯島店',
#  '雷門 うなぎ 色川',
#  '千葉屋',
#  'No Data',
#  '浅草浪花家',
#  '浅草今半 国際通り本店',
#  'やきとんま～ちゃん',
#  '稲荷屋',
#  '鮨処 寛八 本店',
#  'タンタンタイガー',
#  '裏サブロン',
#  '肉と日本酒 谷中店',
#  'No Data',
#  'すし屋の野八',
#  'No Data',
#  '黒門町紋屋',
#  '上野 藪そば',
#  'つけめんTETSU 千駄木本店',
#  '讃岐饂飩 根の津',
#  '梅むら',
#  '中国料理 馥香',
#  'めん処 羽鳥',
#  '炭火焼肉 金楽',
#  'アランジャルシ',
#  '菓子工房ルスルス',
#  '紀文寿司',
#  'WINESHOP & DINER FUJIMARU',
#  '中国料理 喜羊門',
#  'carissima カリッスィマ',
#  '幸鮓',
#  'No Data',
#  'オグライズバー',
#  'うを徳',
#  'レストランコバヤシ',
#  'とり喜',
#  '焼肉ジャンボ 篠崎本店',
#  '鳥さわ',
#  '焼鳥 おみ乃',
#  '麺屋 一燈',
#  '鰻禅',
#  'サイフォン',
#  '焼肉 静龍苑',
#  'よねさん',
#  'スパイスカフェ',
#  '炭火焼き 豚小家',
#  '竹末東京プレミアム',
#  '手打ち蕎麦 銀杏',
#  'No Data',
#  '越後屋若狭',
#  '鮨なかがわ',
#  '三代目 まる天',
#  '與兵衛すし',
#  'No Data',
#  '板前 石山光一',
#  'カトリカ',
#  '大三元',
#  '豊田屋',
#  'No Data',
#  'No Data',
#  '割烹 船生',
#  'ベッラ ナポリ',
#  'いなかむら',
#  'No Data',
#  'サンサール',
#  '素揚げや',
#  '珍々',
#  'Hiro Yamamoto',
#  'Spice BAR 猫六',
#  '八べえ',
#  '中華そば 満鶏軒',
#  'No Data',
#  'CLOUD NINE 料理とワイン',
#  'ホルモン平田',
#  'ヴェヌス サウスインディアン ダイニング',
#  '串揚げ 依知川',
#  '江戸蕎麦 ほそ川',
#  'No Data',
#  '真鯛らーめん 麺魚',
#  'アジアカレーハウス',
#  'つけ麺 一燈',
#  '麺屋りゅう',
#  '七伍屋 海鮮居酒屋',
#  '亀戸煮干中華そばつきひ',
#  'ミナミ・キッチン',
#  'いっちゃん',
#  '北斎茶房',
#  'ホルモン青木 2号店',
#  'わくい亭',
#  'No Data',
#  'すし佐竹 - Sushi Satake',
#  '銀座ひらやま',
#  '清壽',
#  'みかわ是山居「予約制」',
#  '鮨 はしもと',
#  '東京チャイニーズ一凛',
#  '味ひろ',
#  'カマルプール',
#  '岸田屋',
#  'Passo a Passo',
#  'ビストロシンバ bistrosimba',
#  'No Data',
#  'かねます',
#  '麺屋 吉左右',
#  "mal D'amour",
#  'イルトラム',
#  '天麩羅 なかがわ',
#  'エクロール',
#  'ふく田',
#  '在市',
#  'ぎんざ 一二岐',
#  'トゥットベーネ',
#  '焼肉・韓国料理 韓灯（ハンドゥン）',
#  '鮨 桂太',
#  'Bar オーパ',
#  '志づ香',
#  '焼肉 凛',
#  'シャテール',
#  '矢もり',
#  'らーめん こうかいぼう',
#  'すし浅尾',
#  'フルーツカフェ フルータス',
#  '沿露目',
#  '築地すず木',
#  'No Data',
#  '木挽町 湯津上屋',
#  'アムダスラビー',
#  'アタゴール',
#  '日本料理 時宜',
#  'LA BETTOLA da Ochiai（ラ・ベットラ・ダ・オチアイ）',
#  'No Data',
#  '秀徳 2号店',
#  'No Data',
#  'まぐろや黒銀築地本店',
#  '新ばし 金田中',
#  '大和寿司',
#  '築地とんかつ小田保',
#  '築地 すし大本館',
#  'オッツィオ',
#  '龍寿司',
#  '肴や 味泉',
#  'ふうすけ',
#  '築地 居酒屋 のどぐろの中俣 築地',
#  '眺遊楼',
#  '築地 パラディーゾ',
#  '成冨',
#  '布恒更科',
#  '有明',
#  'あんこう鍋 ほていさん',
#  'らぁ麺 やまぐち 辣式',
#  '多け乃',
#  '鮨 石島',
#  'あおき',
#  '築地秀徳 本店',
#  'つきじ治作 Tsukiji JISAKU',
#  'さが美',
#  'かつきり',
#  '八千代',
#  'スパイス・ラー麺卍力',
#  '竹葉亭 本店',
#  'ナンディニ',
#  'Shellman',
#  'ラカーヴデランパール',
#  '築地 藤田',
#  'レストラン カンテサンス',
#  '東麻布天本',
#  'レストランクレッセント',
#  '晴山',
#  '宮葉',
#  'くろぎ',
#  '麤皮',
#  '焼肉くにもと 新館',
#  '割烹 牧野',
#  'リストランテ ラ・チャウ',
#  '御田町 桃の木',
#  '野田岩 麻布飯倉本店',
#  'とんかつ大門 檍（あおき）',
#  '正泰苑 芝大門',
#  'のもと家',
#  '焼肉 くにもと 本店',
#  '東京 芝 とうふ屋うかい',
#  '鳥てる',
#  '泉岳寺門前紋屋',
#  'ラーメン二郎三田本店',
#  '濱壹',
#  "MUNCH'S BURGER SHACK 芝公園本店",
#  'Aux Délices de Dodine',
#  '中国飯店三田',
#  '蘭麻 麻布店',
#  'アロマクラシコ',
#  '焼き鳥 瀧口',
#  '北品川',
#  'ブリーズヴェール ザ・プリンス パークタワー東京',
#  'Les pif et dodine （レピフエドディーヌ）',
#  '水炊き 鼓次郎',
#  'ザ・カリ',
#  '松島屋',
#  'しながわ翁',
#  '鯛樹',
#  '中華そば いづる',
#  '倶楽湾',
#  '大助 おおすけ 串焼',
#  'アントニオ デル ポライオーロ',
#  'まき村',
#  'Homemade Ramen 麦苗/MugiNae',
#  'No Data',
#  'No Data',
#  '煮干しつけ麺 宮元',
#  'オステルリー・スズキ',
#  '多に川 赤坂',
#  'リベルターブル 赤坂',
#  '寿司「鮨一新」',
#  '津やま',
#  'VIEW & DINING THE Sky',
#  'No Data',
#  'かえりやま',
#  '鴨シャブ竹亭',
#  '叙々苑 游玄亭赤坂',
#  '元赤坂ながずみ',
#  'Ｗａｋｉｙａ一笑美茶樓',
#  '赤坂璃宮',
#  'No Data',
#  'しろたえ',
#  'ソラノイロ 本店',
#  '希須林 赤坂店',
#  'SATSUKI',
#  '室町 砂場 赤坂店',
#  'とんかつ まさむね',
#  'やげんぼり 赤坂店',
#  'まるしげ 夢葉家',
#  'チョンギワ 本館',
#  '割烹 和知',
#  '赤坂 丈太郎',
#  '銀座 久兵衛 ホテルニューオータニ タワー店',
#  '赤坂 山ね家。',
#  '燻',
#  'No Data',
#  'アジャンタ',
#  'No Data',
#  'SATSUKI',
#  '天ぷら 逢坂',
#  '天香回味 赤坂別館',
#  'ざくろ TBS店',
#  '會水庵',
#  '重箱',
#  'クレアバックス crear bacchus',
#  'かみやま',
#  '炭火割烹 白坂',
#  '虎白',
#  'No Data',
#  'すし匠',
#  '神楽坂 石かわ',
#  'ル・マンジュ・トゥー',
#  '北島亭',
#  "L'Octave -Hayato KOBAYASHI-",
#  'No Data',
#  '炭火焼肉 なかはら',
#  '石ばし',
#  '曙橋 まる富',
#  '神楽坂ラ・トゥーエル',
#  'リストランテ ラ・バリック トウキョウ',
#  '和食こんどう',
#  'コンヴィーヴィオ',
#  '串揚げはやし',
#  'セクレト',
#  '天ぷら 蕎楽亭',
#  'ラトラス',
#  'うぶか',
#  '神楽坂 鉄板焼 中むら',
#  'No Data',
#  '神楽坂鉄板焼き いわ倉',
#  'アンティカ・オステリア・カルネヤ',
#  'No Data',
#  '懐石 大原',
#  '志ま平',
#  '萬屋おかげさん',
#  '山さき',
#  'Estación (エスタシオン)',
#  'サンルーカルバー',
#  '季旬鈴なり',
#  '鮨 臥龍',
#  '蕎楽亭',
#  'chez Olivier',
#  'No Data',
#  '遊猿',
#  'エノテカラウラ',
#  '鮨 てる',
#  'ルグドゥノム・ブション・リヨネ',
#  '蜀郷香',
#  '荒木町たつや',
#  '青華こばやし',
#  'パティスリー・ カー・ヴァンソン',
#  'あげづき',
#  'アトリエコータ',
#  'ラ・マティエール',
#  '想いの木',
#  'ヴェーリ',
#  '和しょく えびはら',
#  'ピアッティ カステリーナ',
#  '和食 お の 寺',
#  'No Data',
#  'オテル・ドゥ・ミクニ',
#  'ジュー ドゥ マルシェ',
#  '鮨心 -Sushi Kokoro-',
#  'トラットリア グランボッカ',
#  'たん焼 忍',
#  'No Data',
#  '焼鳥茜',
#  '多仁本',
#  'はらまさ',
#  'うなぎ はし本「創業183年」',
#  'No Data',
#  '鮨 わたなべ',
#  '神楽坂 阿部',
#  'ディルセ',
#  '東白庵かりべ',
#  '歯車',
#  'め乃惣',
#  'No Data',
#  'の弥七',
#  'フルーツパーラーフクナガ',
#  '中国菜 膳楽房',
#  'トルッキオ',
#  'バー エルラギート',
#  'レスプリ ミタニ・ア・ゲタリ',
#  'BOLT',
#  '神楽坂 翔山亭 黒毛和牛贅沢重専門店 神楽坂本店',
#  'No Data',
#  'DIRITTO',
#  '神楽坂大和屋 梅助 神楽坂/結納/接待/個室/ランチ/ディナー/和食',
#  'ヘンドリクス カリー バー',
#  'アルボール神楽坂',
#  '焼肉 名門',
#  '中国飯店 市ヶ谷店',
#  'No Data',
#  '好ちゃん飯田橋分家',
#  'うなぎ川勢',
#  'おでんや den',
#  '懐石小室',
#  'たく庵',
#  'Sincere',
#  '津の守坂 小柴',
#  '錦福',
#  '後楽寿司やす秀',
#  'たいやき わかば',
#  'かつれつ四谷たけだ',
#  '釜あげうどん はつとみ',
#  '一条流がんこラーメン 総本家',
#  '焼鳥 おがわ',
#  'Rojiura Curry SAMURAI.神楽坂店',
#  'あほう鳥',
#  '御料理 宮した',
#  '神楽坂 鮨 りん',
#  '日本橋 寿司金',
#  'ふしきの（Fushikino）',
#  '麺や庄の',
#  '葉山',
#  'チャコあめみや',
#  'ラ・プレシューズ 四ツ谷店',
#  '九段下 寿司政',
#  '梅香',
#  'ルブルターニュ バーアシードル レストラン',
#  '十割蕎麦 蕎麦の膳 たかさご',
#  'セシル エリュアール 神楽坂',
#  '居酒屋 純ちゃん',
#  '九段下寿白',
#  '宮わき',
#  'ソンブルイユ',
#  '寿司幸神楽坂',
#  '紀の善',
#  '灯花',
#  '八咫烏',
#  '手打そば 大川や',
#  '焼肉ヒロミヤ',
#  '神楽坂しゅうご',
#  '西洋料理 夏目亭',
#  '恵さき',
#  'No Data',
#  'てんぷら荘司',
#  'トラットリア ラ タルタルギーナ',
#  'すし処志げる',
#  'Yakiniku Jumbo Hanare',
#  '焼肉ジャンボ 本郷店',
#  '天ぷらと和食 山の上',
#  'とんかつ 丸五',
#  'うどん丸香',
#  "CITTA 'ALTA（チッタアルタ）",
#  '鶴八',
#  '饗 くろ㐂',
#  '明神下 神田川本店',
#  'a table',
#  'テロワール・カワバタ TERROIR Kawabata',
#  'とんかつ やまいち',
#  'ククセモワ',
#  'かんだ光壽',
#  '神田 雲林',
#  'Spice Box (スパイスボックス)',
#  '焼肉ランド マルタケ',
#  'とんかつ 万平',
#  '蘭奢待',
#  'アイコウシャ',
#  'あそび割烹さん葉か',
#  'こなから本店',
#  'JB 日本橋',
#  '江戸前 晋作',
#  'もつ焼き じんちゃん',
#  'No Data',
#  '満寿家',
#  '松翁',
#  '西洋料理 Restaurant 七條',
#  '神田 ポンチ軒',
#  '香川一福 神田店',
#  'アヴランシュ ゲネー',
#  'Wine 厨房 tamaya suidobashi',
#  '欧風カレー ボンディ 神保町本店',
#  'ラーメン大至',
#  'ルー・ド・メール',
#  '廚菓子くろぎ',
#  'ディラン',
#  '麺屋 ねむ瑠',
#  'さゝま',
#  'No Data',
#  '眠庵',
#  'くじらのお宿 一乃谷',
#  '蕎麦切森の',
#  '中華蕎麦 にし乃',
#  '松竹庵 ます川',
#  '吾妻家',
#  'コンセール',
#  '神田 まつや',
#  '欧風カレー ボンディ神田小川町店',
#  'Abats.',
#  '桃の実',
#  'くずし鉄板あばぐら',
#  'No Data',
#  'レストラン マ プール',
#  'うどん こくわがた',
#  '室町 砂場',
#  '神田きくかわ 神田店',
#  '鮮魚らーめん五ノ神水産 神田店',
#  '麺巧 潮',
#  'MENSHO TOKYO',
#  '中華料理 味坊',
#  'カレーノトリコ',
#  'かつ吉 水道橋店',
#  'MANNISH',
#  '舞扇',
#  '浜貞',
#  'かんだやぶそば',
#  '青島食堂 秋葉原店',
#  '新世界菜館',
#  '無銘',
#  'あんこう鍋 いせ源',
#  '葡萄舎',
#  'つけそば 神田勝本',
#  'たん清',
#  "STYLE'S CAKES & CO.",
#  'らーめん天神下大喜',
#  'No Data',
#  'No Data',
#  'La Fabbrica della Pasta Quel',
#  'ピッツァバー ON 38TH',
#  '鷹匠寿',
#  'いし橋',
#  '定谷',
#  '鶯谷園',
#  '牧野',
#  '生粋',
#  'ナベノイズム',
#  'オマージュ',
#  '龍圓',
#  'ボナフェスタ',
#  '鳥恵 上野広小路店',
#  '香味屋',
#  'No Data',
#  'じゅうろく 蕎麦',
#  'レストラン ルディック【浅草・フレンチ】',
#  '山介',
#  'ぽん多本家',
#  'No Data',
#  'ヤナカスギウラ',
#  '麺処 晴',
#  '鮨 久いち',
#  'はすの里 新御徒町店',
#  '弁天山 美家古寿司',
#  'No Data',
#  '入谷鬼子母神門前のだや',
#  '蕎亭 大黒屋',
#  'No Data',
#  '鮨松波',
#  '北山珈琲店',
#  'アーンドラ・キッチン',
#  '肉のすずき',
#  'かず味家',
#  'ひみつ堂',
#  'グリルグランド grill GRAND',
#  '吾妻橋やぶそば',
#  '鮨 橋口',
#  'まめたん',
#  'らーめん 改',
#  'やしま',
#  '鳥栄',
#  '根津 雙柿庵',
#  '寿し政 別館',
#  '神名備 （かむなび）',
#  'パンのペリカン',
#  '鳥つね自然洞',
#  'ジョンティ',
#  'レストラン コーダリー',
#  'まさる',
#  '鮨 一新',
#  '味坊鉄鍋荘',
#  '根津 釜竹',
#  '初小川',
#  'アメッツ',
#  '並木藪蕎麦',
#  'No Data',
#  'No Data',
#  '本とさや',
#  '麺 みつヰ',
#  '佐久良',
#  'マノスレストラン',
#  '駒形どぜう 本店',
#  '米久 本店',
#  'ベジキッチン',
#  '468',
#  'No Data',
#  '今半別館',
#  '三忠',
#  '味農家',
#  'BAR DORAS',
#  'デリー 上野店',
#  '和栗や',
#  'とんかつすぎ田',
#  'ろく月',
#  'ビストロタカ',
#  '丹想庵 健次郎 浅草 手打そば',
#  '焼貝うぐいす',
#  'No Data',
#  'パティシエ イナムラショウゾウ',
#  'フルーツパーラーゴトー',
#  'はん亭',
#  '鷹匠',
#  '稲毛屋',
#  '谷中鳥よし',
#  '徳吉',
#  '根津 日本酒 多田',
#  '亀十',
#  '四川担担麺 阿吽 湯島店',
#  '雷門 うなぎ 色川',
#  '千葉屋',
#  'No Data',
#  '浅草浪花家',
#  '浅草今半 国際通り本店',
#  'やきとんま～ちゃん',
#  '稲荷屋',
#  '鮨処 寛八 本店',
#  'タンタンタイガー',
#  '裏サブロン',
#  '肉と日本酒 谷中店',
#  'No Data',
#  'すし屋の野八',
#  'No Data',
#  '黒門町紋屋',
#  '上野 藪そば',
#  'つけめんTETSU 千駄木本店',
#  '讃岐饂飩 根の津',
#  '梅むら',
#  '中国料理 馥香',
#  'めん処 羽鳥',
#  '炭火焼肉 金楽',
#  'アランジャルシ',
#  '菓子工房ルスルス',
#  '紀文寿司',
#  'WINESHOP & DINER FUJIMARU',
#  '中国料理 喜羊門',
#  'carissima カリッスィマ',
#  '幸鮓',
#  'No Data',
#  'オグライズバー',
#  'うを徳',
#  'レストランコバヤシ',
#  'とり喜',
#  '焼肉ジャンボ 篠崎本店',
#  '鳥さわ',
#  '焼鳥 おみ乃',
#  '麺屋 一燈',
#  '鰻禅',
#  'サイフォン',
#  '焼肉 静龍苑',
#  'よねさん',
#  'スパイスカフェ',
#  '炭火焼き 豚小家',
#  '竹末東京プレミアム',
#  '手打ち蕎麦 銀杏',
#  'No Data',
#  '越後屋若狭',
#  '鮨なかがわ',
#  '三代目 まる天',
#  '與兵衛すし',
#  'No Data',
#  '板前 石山光一',
#  'カトリカ',
#  '大三元',
#  '豊田屋',
#  'No Data',
#  'No Data',
#  '割烹 船生',
#  'ベッラ ナポリ',
#  'いなかむら',
#  'No Data',
#  'サンサール',
#  '素揚げや',
#  '珍々',
#  'Hiro Yamamoto',
#  'Spice BAR 猫六',
#  '八べえ',
#  '中華そば 満鶏軒',
#  'No Data',
#  'CLOUD NINE 料理とワイン',
#  'ホルモン平田',
#  'ヴェヌス サウスインディアン ダイニング',
#  '串揚げ 依知川',
#  '江戸蕎麦 ほそ川',
#  'No Data',
#  '真鯛らーめん 麺魚',
#  'アジアカレーハウス',
#  'つけ麺 一燈',
#  '麺屋りゅう',
#  '七伍屋 海鮮居酒屋',
#  '亀戸煮干中華そばつきひ',
#  'ミナミ・キッチン',
#  'いっちゃん',
#  '北斎茶房',
#  'ホルモン青木 2号店',
#  'わくい亭',
#  'No Data',
#  'すし佐竹 - Sushi Satake',
#  '銀座ひらやま',
#  '清壽',
#  'みかわ是山居「予約制」',
#  '鮨 はしもと',
#  '東京チャイニーズ一凛',
#  '味ひろ',
#  'カマルプール',
#  '岸田屋',
#  'Passo a Passo',
#  'ビストロシンバ bistrosimba',
#  'No Data',
#  'かねます',
#  '麺屋 吉左右',
#  "mal D'amour",
#  'イルトラム',
#  '天麩羅 なかがわ',
#  'エクロール',
#  'ふく田',
#  '在市',
#  'ぎんざ 一二岐',
#  'トゥットベーネ',
#  '焼肉・韓国料理 韓灯（ハンドゥン）',
#  '鮨 桂太',
#  ...]

# %%
# concat

# %%
import pandas as pd
original = pd.read_csv("/Users/yosuke/Github/FindGooglePlaceIDbyAddress/data/tabelog_over_3.6.csv")

added = pd.DataFrame({ 'google_name': name, 'place_id': place_id})


original.head()


concat = pd.concat([original, added], axis=1)

concat.to_csv("data/5000-5211.csv")

# %%
#DataFrameを定義　nameとplace_id
# df = pd.DataFrame(data=[[1, 2, 3], [4, 5, 6]], columns=['a', 'b', 'c'])

# df = pd.DataFrame({ 'name': name, 'place_id': place_id})

# df = pd.DataFrame(data=[name, place_id], columns=['name','place_id'])
# df


# df = pd.DataFrame({ 'A' : 1.,
#                       'B' : pd.Timestamp('20130102'),
#                        'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
#                    'D' : np.array([3] * 4,dtype='int32'),
#                   'E' : pd.Categorical(["test","train","test","train"]),
#                         'F' : 'foo' })

s = pd.Series([10 , 4, 7, 34, 6])
s
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-82901ab1208a> in <module>()
#      15 #                         'F' : 'foo' })
#      16
# ---> 17 s = pd.Series([10 , 4, 7, 34, 6])
#      18 s
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Series'

# %%
YOUR_API_KEY = 'AIzaSyDEbvcLE_om08N47ahjrJW1vEFpzAAwxfk'

google_places = GooglePlaces(APIKEY)
# query_result = google_places.nearby_search(
#         location='London, England', keyword='Fish and Chips',
#         radius=2000, types=[types.TYPE_FOOD])

query_result = google_places.nearby_search(
        lat_lng={'lat': 43.05527, 'lng': 141.353447},
        radius=100,keyword = '寿司', types=[types.TYPE_FOOD])

print(query_result)
# Out:
# <GooglePlacesSearchResult with 20 result(s)>

# %%
print("aa")
# Out:
# aa

# %%
# Out:
# [name         None
# latitude     None
# longitude    None
# Name: 0, dtype: object]

# %%
import pandas as  pd

file = open('/Users/yosuke/Github/FindGooglePlaceIDbyAddress/data/copyGoogleID.txt', 'r')  
googleID = file.read() 

name
place_id

splited = googleID.split("\n")
# print(splited)

for i in splited:
    number = splited.index(i)
    if number%4 == 0:
        print(i)
